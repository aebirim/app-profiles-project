# %% [markdown]
# # Profitable App Profiles for the App Store and Google Play Markets
#
# The goal of this project is to analyze data in the app stores to help our developers understand what type of apps are likely to attract more users.
#
# I work for a company that builds Android and iOS mobile apps and these apps are available on Google Play and the App Store. The company primarily builds apps that are free to download and install however it's main source of revenue consists of in-app ads. This means that the revenue is driven by the number of users who use the apps - the more users that see and engage with the ads, the better.
#
# * The App Store dataset can be downloaded directly from this [link](https://dq-content.s3.amazonaws.com/350/AppleStore.csv)
#
# * The Google Play dataset can be downloaded directly from this [link](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv)

# %%
# !pip3 install autopep8
# Out:
# Collecting autopep8
#   Using cached https://files.pythonhosted.org/packages/58/e5/a06510cfa9caaaffebf74084f8886a93a96273dbf22a1c920ca1af00997a/autopep8-1.5.5-py2.py3-none-any.whl
# Collecting pycodestyle>=2.6.0 (from autopep8)
#   Using cached https://files.pythonhosted.org/packages/10/5b/88879fb861ab79aef45c7e199cae3ef7af487b5603dcb363517a50602dd7/pycodestyle-2.6.0-py2.py3-none-any.whl
# Collecting toml (from autopep8)
#   Using cached https://files.pythonhosted.org/packages/44/6f/7120676b6d73228c96e17f1f794d8ab046fc910d781c8d151120c3f1569e/toml-0.10.2-py2.py3-none-any.whl
# Installing collected packages: pycodestyle, toml, autopep8
# Successfully installed autopep8-1.5.5 pycodestyle-2.6.0 toml-0.10.2

# %%
# open the App store and Google Play datasets
from csv import reader
import pprint

apple_file = 'datasets/AppleStore.csv'
google_file = 'datasets/googleplaystore.csv'

def open_file(file):
    try:
        opened_file = open(file)
    except OSError as e:
        print("Failure to open file", e)
        
    reader_file = reader(opened_file)
    data = list(reader_file)
    return data

apple_data = open_file(apple_file)  
google_data = open_file(google_file)

# %% [markdown]
# The explore_data function allows you to explore the dataset in a more readable way. The function also lets you count the number of rows and columns for the dataset

# %%
# explore the datasets
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
        
    if rows_and_columns:
        print("Number of rows:", len(dataset))
        print("Number of columns:", len(dataset[0]))
    
explore_data(apple_data, 0, 5)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
        
    if rows_and_columns:
        print("Number of rows:", len(dataset))
        print("Number of columns:", len(dataset[0]))
    
explore_data(apple_data, 0, 5, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# Number of rows: 7198
# Number of columns: 16

# %% [markdown]
# Documentation describing the columns for the iOs App store dataset and Google Play dataset can be found [here](https://kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home) and [here](https://kaggle.com/lava18/google-play-store-apps) respectively

# %%
explore_data(google_data, 0, 5)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']

# %%
explore_data(google_data, 0, 5, True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 10842
# Number of columns: 13

# %%
# show the headers for each dataset

header_apple = apple_data[0]
header_google = google_data[0]

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Check the datasets and ensure each row has the correct number of columns

# %%
def check_dataset(dataset):
    for count, row in enumerate(dataset):
        header_length = len(dataset[0])
        if len(row) != header_length:
            print("row:",count,"has", len(row), "columns instead of", header_length)
            
check_dataset(apple_data)

# %%
check_dataset(google_data)
# Out:
# row: 10473 has 12 columns instead of 13

# %% [markdown]
# This shows that row 10473, of the google dataset, has an incorrect number of columns.

# %%
# delete the row with the missing column(s)

del google_data[10473]

# %%
# number of rows in dataset

len(google_data)
# Out:
# 10841

# %% [markdown]
# Check the Google Play dataset for duplicate app entries

# %%
duplicate_apps = []
unique_apps = []
def check_duplicates(dataset):
    for count, row in enumerate(dataset[1:]):
        app_name = row[0]
        if app_name in unique_apps:
            duplicate_apps.append(row)
        else:
            unique_apps.append(app_name)
    return duplicate_apps, unique_apps

dup_app, uniqs = check_duplicates(google_data)  
print("number of duplicates of google dataset:", len(dup_app))
print("\n")
print("examples of duplicate apps in google dataset:", dup_app[1:10])
number_of_duplicates = len(dup_app)
# Out:
# number of duplicates of google dataset: 1181
#
#
# examples of duplicate apps in google dataset: [['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device'], ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up'], ['ZOOM Cloud Meetings', 'BUSINESS', '4.4', '31614', '37M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 20, 2018', '4.1.28165.0716', '4.0 and up'], ['join.me - Simple Meetings', 'BUSINESS', '4.0', '6989', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 16, 2018', '4.3.0.508', '4.4 and up'], ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device'], ['Zenefits', 'BUSINESS', '4.2', '296', '14M', '50,000+', 'Free', '0', 'Everyone', 'Business', 'June 15, 2018', '3.2.1', '4.1 and up'], ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up'], ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up'], ['Slack', 'BUSINESS', '4.4', '51507', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', 'Varies with device', 'Varies with device']]

# %% [markdown]
# The number of duplicates in the Google dataset are {{number_of_duplicates}}
#
# The above samples, from the Google dataset, clearly show duplicate entries

# %%
# extract the names of the duplicated apps
app_names = []

for row in dup_app:
    name = row[0]
    app_names.append(name)

new_apps = sorted(app_names)
new_apps
# Out:
# ['10 Best Foods for You',
#  '1800 Contacts - Lens Store',
#  '2017 EMRA Antibiotic Guide',
#  '21-Day Meditation Experience',
#  '365Scores - Live Scores',
#  '420 BZ Budeze Delivery',
#  '8 Ball Pool',
#  '8 Ball Pool',
#  '8 Ball Pool',
#  '8 Ball Pool',
#  '8 Ball Pool',
#  '8 Ball Pool',
#  '8fit Workouts & Meal Planner',
#  '95Live -SG#1 Live Streaming App',
#  'A Manual of Acupuncture',
#  'A&E - Watch Full Episodes of TV Shows',
#  'A&E - Watch Full Episodes of TV Shows',
#  'A&E - Watch Full Episodes of TV Shows',
#  'AAFP',
#  'ABC News - US & World News',
#  'AC - Tips & News for Android™',
#  'AP Mobile - Breaking News',
#  'ASCCP Mobile',
#  'ASOS',
#  'Accounting App - Zoho Books',
#  'AccuWeather: Daily Forecast & Live Weather Reports',
#  'Acorns - Invest Spare Change',
#  'AdWords Express',
#  'Ada - Your Health Guide',
#  'Adobe Acrobat Reader',
#  'Adobe Acrobat Reader',
#  'Adobe Photoshop Express:Photo Editor Collage Maker',
#  'Adult Dirty Emojis',
#  'Adult Dirty Emojis',
#  'Advanced Comprehension Therapy',
#  'Agar.io',
#  'Airbnb',
#  'Airway Ex - Intubate. Anesthetize. Train.',
#  'AliExpress - Smarter Shopping, Better Living',
#  'AliExpress - Smarter Shopping, Better Living',
#  'AliExpress - Smarter Shopping, Better Living',
#  'All Football - Latest News & Videos',
#  'All Mental disorders',
#  'All Social Networks',
#  "Alto's Adventure",
#  'Amazon Kindle',
#  'Amazon Shopping',
#  'Amazon Shopping',
#  'Amazon for Tablets',
#  'American Airlines',
#  'American Airlines',
#  'Amino: Communities and Chats',
#  'AnatomyMapp',
#  'Android Messages',
#  'Anger of stick 5 : zombie',
#  'Angry Birds 2',
#  'Angry Birds Classic',
#  'Angry Birds Classic',
#  'Angry Birds Classic',
#  'Angry Birds Classic',
#  'Angry Birds Rio',
#  'Angry Birds Rio',
#  'Angry Birds Rio',
#  'Animal Jam - Play Wild!',
#  'Anthem Anywhere',
#  'Anthem BC Anywhere',
#  'Any.do: To-do list, Calendar, Reminders & Planner',
#  'Any.do: To-do list, Calendar, Reminders & Planner',
#  'Apartment List: Housing, Apt, and Property Rentals',
#  'Apartments & Rentals - Zillow',
#  'Apartments.com Rental Search',
#  'Apex Launcher',
#  'Apex Launcher',
#  'Asana: organize team projects',
#  'Avokiddo Emotions',
#  'B612 - Beauty & Filter Camera',
#  'B612 - Beauty & Filter Camera',
#  'BBC News',
#  'BBC News',
#  'BBC Sport',
#  'BBM - Free Calls & Messages',
#  'BBW Dating & Curvy Singles Chat- LargeFriends',
#  'BBW Dating & Plus Size Chat',
#  'BBW Dating & Plus Size Chat',
#  'BET NOW - Watch Shows',
#  'BET NOW - Watch Shows',
#  'BP Journal - Blood Pressure Diary',
#  'BZWBK24 mobile',
#  'Babbel – Learn Languages',
#  'Babbel – Learn Languages',
#  'Babbel – Learn Languages',
#  'Baby Panda Care',
#  'Backgrounds HD (Wallpapers)',
#  'Badoo - Free Chat & Dating App',
#  'Badoo - Free Chat & Dating App',
#  'Badoo - Free Chat & Dating App',
#  'Banfield Pet Health Tracker',
#  'Barbie™ Fashion Closet',
#  'Beautiful Widgets Free',
#  'Beautiful Widgets Pro',
#  'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  'Best Fiends - Free Puzzle Game',
#  'BeyondMenu Food Delivery',
#  'Bita and the Animals - Pelos Ares',
#  'Black People Meet Singles Date',
#  'Black White Interracial Dating - Interracial Match',
#  'Bleacher Report: sports news, scores, & highlights',
#  'Bleacher Report: sports news, scores, & highlights',
#  'Bleacher Report: sports news, scores, & highlights',
#  'Bleacher Report: sports news, scores, & highlights',
#  'Bleacher Report: sports news, scores, & highlights',
#  'Blendr - Chat, Flirt & Meet',
#  'Block Buddy',
#  'Block Craft 3D: Building Simulator Games For Free',
#  'Block Craft 3D: Building Simulator Games For Free',
#  'Block Puzzle',
#  'Block Puzzle',
#  'Block Puzzle',
#  'Block Puzzle Classic Legend !',
#  'Blood Pressure',
#  'Blood Pressure',
#  'Blood Pressure Companion',
#  'Blood Pressure Log - MyDiary',
#  'Blood Pressure Monitor',
#  'Blood Pressure(BP) Diary',
#  'Blur Image Background',
#  'Booking.com Travel Deals',
#  'Booking.com Travel Deals',
#  'Bowmasters',
#  'Bowmasters',
#  'Bowmasters',
#  'Bowmasters',
#  'Bowmasters',
#  'Box',
#  'Box',
#  'Breastfeeding Tracker Baby Log',
#  'Brilliant',
#  'Brit + Co',
#  'British Airways',
#  'Bubble Shooter',
#  'Bubble Shooter',
#  'Bubble Shooter',
#  'Bubble Shooter',
#  'Bubble Shooter',
#  'Bubble Shooter 2',
#  'BuzzFeed: News, Tasty, Quizzes',
#  'C Programming',
#  'CBS - Full Episodes & Live TV',
#  'CBS Sports App - Scores, News, Stats & Watch Live',
#  'CBS Sports App - Scores, News, Stats & Watch Live',
#  'CBS Sports App - Scores, News, Stats & Watch Live',
#  'CBS Sports App - Scores, News, Stats & Watch Live',
#  'CBS Sports App - Scores, News, Stats & Watch Live',
#  'CBS Sports App - Scores, News, Stats & Watch Live',
#  'CBS Sports App - Scores, News, Stats & Watch Live',
#  'CBS Sports Fantasy',
#  'CJmall',
#  'CM Browser - Ad Blocker , Fast Download , Privacy',
#  'CM FILE MANAGER HD',
#  'CM Flashlight (Compass, SOS)',
#  'CM Launcher 3D - Theme, Wallpapers, Efficient',
#  'CM Locker - Security Lockscreen',
#  'CMB Free Dating App',
#  'CNBC: Breaking Business News & Live Market Data',
#  'CNN Breaking US & World News',
#  'CNN Breaking US & World News',
#  "COOKING MAMA Let's Cook!",
#  'CT Scan Cross Sectional Anatomy',
#  'CW Seed',
#  'Cache Cleaner-DU Speed Booster (booster & cleaner)',
#  'Calculator',
#  'Call Blocker',
#  'CallApp: Caller ID, Blocker & Phone Call Recorder',
#  'Calls & Text by Mo+',
#  'Calm - Meditate, Sleep, Relax',
#  'Calorie Counter & Diet Tracker',
#  'Calorie Counter - Macros',
#  'Calorie Counter - MyFitnessPal',
#  'Calorie Counter - MyFitnessPal',
#  'Calorie Counter - MyFitnessPal',
#  'Calorie Counter - MyFitnessPal',
#  'Calorie Counter - MyNetDiary',
#  'Calorie Counter by FatSecret',
#  'Camera FV-5',
#  'Camera FV-5 Lite',
#  'Camera MX - Free Photo & Video Camera',
#  'Camera for Android',
#  'Camera for Android',
#  'Camera360 Lite - Selfie Camera',
#  'Camera360: Selfie Photo Editor with Funny Sticker',
#  'Camera360: Selfie Photo Editor with Funny Sticker',
#  'Candy Bomb',
#  'Candy Camera - selfie, beauty camera, photo editor',
#  'Candy Camera - selfie, beauty camera, photo editor',
#  'Candy Crush Jelly Saga',
#  'Candy Crush Saga',
#  'Candy Crush Saga',
#  'Candy Crush Saga',
#  'Candy Crush Saga',
#  'Candy Crush Saga',
#  'Candy Crush Saga',
#  'Candy Crush Soda Saga',
#  'Candy Crush Soda Saga',
#  'Capital One® Mobile',
#  'Cardboard',
#  'Cardi B Live Stream Video Chat - Prank',
#  'Cardiac diagnosis (heart rate, arrhythmia)',
#  'Cardiac diagnosis (heart rate, arrhythmia)',
#  'Carousell: Snap-Sell, Chat-Buy',
#  'Cartoon Network App',
#  'Castle Clash: Heroes of the Empire US',
#  'Casual Dating & Adult Singles - Joyride',
#  'Chat Kids - Chat Room For Kids',
#  'Chat Rooms, Avatars, Date - Galaxy',
#  'Cheapflights – Flight Search',
#  'Checkout 51: Grocery coupons',
#  'Checkout 51: Grocery coupons',
#  'Chess Free',
#  'Chick-fil-A',
#  'Chick-fil-A',
#  'Chictopia',
#  'Chispa, the Dating App for Latino, Latina Singles',
#  'Choices: Stories You Play',
#  'Christian Dating For Free App',
#  'Chrome Beta',
#  'Chrome Dev',
#  'Clash Royale',
#  'Clash Royale',
#  'Clash Royale',
#  'Clash of Clans',
#  'Clash of Clans',
#  'Clash of Clans',
#  'ClassDojo',
#  'ClassDojo',
#  'Clover Dating App',
#  'Color by Number – New Coloring Book',
#  'ColorNote Notepad Notes',
#  'Colorfy: Coloring Book for Adults - Free',
#  'Coloring book moana',
#  'Comedy Central',
#  'Cooking Fever',
#  'Cougar Dating Life : Date Older Women Sugar Mummy',
#  'Couple - Relationship App',
#  'Coursera: Online courses',
#  'CppDroid - C/C++ IDE',
#  'Crackle - Free TV & Movies',
#  'Crackle - Free TV & Movies',
#  'Credit Karma',
#  'Credit Karma',
#  'Crew - Free Messaging and Scheduling',
#  'Cricbuzz - Live Cricket Scores & News',
#  'Crossy Road',
#  'Crunchyroll - Everything Anime',
#  'Crunchyroll - Everything Anime',
#  'Curriculum vitae App CV Builder Free Resume Maker',
#  'Cut the Rope FULL FREE',
#  'Cut the Rope FULL FREE',
#  'Cymera Camera- Photo Editor, Filter,Collage,Layout',
#  'Cymera Camera- Photo Editor, Filter,Collage,Layout',
#  'Cymera Camera- Photo Editor, Filter,Collage,Layout',
#  'DC Comics',
#  'DC Super Hero Girls™',
#  'DC Super Hero Girls™',
#  'DC Super Hero Girls™',
#  'DEAD TARGET: FPS Zombie Apocalypse Survival Games',
#  'DEER HUNTER 2018',
#  'DINO HUNTER: DEADLY SHORES',
#  'DRAGON BALL LEGENDS',
#  'DRAGON BALL LEGENDS',
#  'DRAGON BALL LEGENDS',
#  'DU Browser—Browse fast & fun',
#  'Daily Manga - Comic & Webtoon',
#  'Daily Yoga - Yoga Fitness Plans',
#  'Daily Yoga - Yoga Fitness Plans',
#  'Dairy Queen',
#  'Dating App, Flirt & Chat : W-Match',
#  'Dating for 50 plus Mature Singles – FINALLY',
#  'Diabetes & Diet Tracker',
#  'Diabetes:M',
#  'Diary with lock',
#  'Dictionary - Merriam-Webster',
#  'Digit Save Money Automatically',
#  'Disney Magic Kingdoms: Build Your Own Magical Park',
#  'DisneyNOW – TV Shows & Games',
#  'DisneyNOW – TV Shows & Games',
#  'Do It Later: Tasks & To-Dos',
#  'Docs To Go™ Free Office Suite',
#  'Dog Run - Pet Dog Simulator',
#  'Dog Run - Pet Dog Simulator',
#  "Domino's Pizza USA",
#  "Dr. Panda & Toto's Treehouse",
#  "Dr. Panda & Toto's Treehouse",
#  'Dream League Soccer 2018',
#  'Dream League Soccer 2018',
#  'DreamWorks Friends',
#  'Dropbox',
#  'Dropbox',
#  'Dude Perfect 2',
#  'Dungeon Hunter Champions: Epic Online Action RPG',
#  "Dunkin' Donuts",
#  'Duolingo: Learn Languages Free',
#  'Duolingo: Learn Languages Free',
#  'Duolingo: Learn Languages Free',
#  'Duolingo: Learn Languages Free',
#  'Duolingo: Learn Languages Free',
#  'Duolingo: Learn Languages Free',
#  'E*TRADE Mobile',
#  'EMT PASS',
#  'EMT Review Plus',
#  'EMT Tutor NREMT-B Study Guide',
#  'EMT-B Pocket Prep',
#  'ES File Explorer File Manager',
#  'ES File Explorer File Manager',
#  'ESPN',
#  'ESPN',
#  'ESPN',
#  'ESPN',
#  'ESPN',
#  'ESPN',
#  'ESPN Fantasy Sports',
#  'ESPN Fantasy Sports',
#  'ESPN Fantasy Sports',
#  'Earn to Die 2',
#  'Ebook Reader',
#  'Edmodo',
#  'EliteSingles – Dating for Single Professionals',
#  'Elmo Calls by Sesame Street',
#  'Elmo Calls by Sesame Street',
#  'Endomondo - Running & Walking',
#  'English Dictionary - Offline',
#  'English Grammar Test',
#  'Episode - Choose Your Story',
#  'Equestria Girls',
#  'Equestria Girls',
#  'Essential Anatomy 3',
#  'Etsy: Handmade & Vintage Goods',
#  'Evernote – Organizer, Planner for Notes & Memos',
#  'Evernote – Organizer, Planner for Notes & Memos',
#  'Evernote – Organizer, Planner for Notes & Memos',
#  'Expedia Hotels, Flights & Car Rental Travel Deals',
#  'Expedia Hotels, Flights & Car Rental Travel Deals',
#  'Expedia Hotels, Flights & Car Rental Travel Deals',
#  'Extreme Coupon Finder',
#  'Extreme Coupon Finder',
#  'FIFA - Tournaments, Soccer News & Live Scores',
#  'FOX',
#  'FOX NOW - On Demand & Live TV',
#  'FOX NOW - On Demand & Live TV',
#  'FOX Sports: Live Streaming, Scores & News',
#  'FP Notebook',
#  'Fabulous: Motivate Me! Meditate, Relax, Sleep',
#  'Face Filter, Selfie Editor - Sweet Camera',
#  'Facebook',
#  'Facebook Ads Manager',
#  'Facebook Lite',
#  'Facebook Pages Manager',
#  'Facetune - For Free',
#  'Facetune - For Free',
#  'Fallout Shelter',
#  'Fancy',
#  'Fancy',
#  'Fandango Movies - Times + Tickets',
#  'Fantasy Football',
#  'Farm Heroes Saga',
#  'Farm Heroes Saga',
#  'Farm Heroes Saga',
#  'Farm Heroes Saga',
#  'FarmersOnly Dating',
#  'Farming Simulator 14',
#  'Fashion in Vogue',
#  'Fashion in Vogue',
#  'Fast Scanner : Free PDF Scan',
#  'FastMeet: Chat, Dating, Love',
#  'FilterGrid - Cam&Photo Editor',
#  'Final Fantasy XV: A New Empire',
#  'Find Real Love — YouLove Premium Dating',
#  'Firefox Browser fast & private',
#  'Firefox Browser fast & private',
#  'Firefox Focus: The privacy browser',
#  'Firefox Focus: The privacy browser',
#  'Fishdom',
#  'Fishdom',
#  'Fitbit Coach',
#  'Flashlight',
#  'Flickr',
#  'Flipboard: News For Our Time',
#  'Flipboard: News For Our Time',
#  'Flipkart Online Shopping App',
#  'Flipp - Weekly Shopping',
#  'FlirtChat - ♥Free Dating/Flirting App♥',
#  'Flow Free',
#  'Flow Free',
#  'Flow Free',
#  'Flow Free',
#  'Fly Delta',
#  'Food Calorie Calculator',
#  'Food Network',
#  'Food Network',
#  'FotMob - Live Soccer Scores',
#  'Fox News – Breaking News, Live Video & News Alerts',
#  'Fox News – Breaking News, Live Video & News Alerts',
#  'Free Blood Pressure',
#  'Free Blood Pressure',
#  'Free Cam Girls - Live Webcam',
#  'Free Dating & Flirt Chat - Choice of Love',
#  'Free Dating App - Meet Local Singles - Flirt Chat',
#  'Free Dating App - YoCutie - Flirt, Chat & Meet',
#  'Free Dating Hook Up Messenger',
#  'Free phone calls, free texting SMS on free number',
#  'FreshBooks Classic',
#  'Frozen Free Fall',
#  'Frozen Free Fall',
#  'Fruits Bomb',
#  'Fun Kid Racing - Motocross',
#  'Fuzzy Numbers: Pre-K Number Foundation',
#  'G Cloud Backup',
#  'GO Keyboard - Emoticon keyboard, Free Theme, GIF',
#  'Galaxy Attack: Alien Shooter',
#  'Galaxy Attack: Alien Shooter',
#  "Game for KIDS: KIDS match'em",
#  'Gardenscapes',
#  'Garena Free Fire',
#  'Garena Free Fire',
#  'Garena Free Fire',
#  'Gay Sugar Daddy Dating & Hookup – Sudy Gay',
#  'Gboard - the Google Keyboard',
#  'Gboard - the Google Keyboard',
#  'Genius Scan - PDF Scanner',
#  'Geometry Dash World',
#  'Girls Live Chat - Free Text & Video Chat',
#  'Glide - Video Chat Messenger',
#  'Gmail',
#  'Gmail',
#  'Golfshot: Golf GPS + Tee Times',
#  'Google',
#  'Google Ads',
#  'Google Ads',
#  'Google Allo',
#  'Google Allo',
#  'Google Analytics',
#  'Google Calendar',
#  'Google Calendar',
#  'Google Chrome: Fast & Secure',
#  'Google Chrome: Fast & Secure',
#  'Google Classroom',
#  'Google Classroom',
#  'Google Docs',
#  'Google Docs',
#  'Google Drive',
#  'Google Drive',
#  'Google Drive',
#  'Google Duo - High Quality Video Calls',
#  'Google Earth',
#  'Google Keep',
#  'Google Keep',
#  'Google Keep',
#  'Google My Business',
#  'Google My Business',
#  'Google News',
#  'Google News',
#  'Google News',
#  'Google PDF Viewer',
#  'Google PDF Viewer',
#  'Google Pay',
#  'Google Pay',
#  'Google Pay',
#  'Google Photos',
#  'Google Photos',
#  'Google Photos',
#  'Google Play Games',
#  'Google Sheets',
#  'Google Street View',
#  'Google Translate',
#  'Google Voice',
#  'Google Voice',
#  'Google+',
#  'Granny',
#  'Granny',
#  'Granny',
#  'Granny',
#  'Groupon - Shop Deals, Discounts & Coupons',
#  'Groupon - Shop Deals, Discounts & Coupons',
#  'Groupon - Shop Deals, Discounts & Coupons',
#  'Grubhub: Food Delivery',
#  'Gyft - Mobile Gift Card Wallet',
#  'Gyft - Mobile Gift Card Wallet',
#  'H TV',
#  'H&M',
#  'HBO GO: Stream with TV Package',
#  'HBO NOW: Stream TV & Movies',
#  'HBO NOW: Stream TV & Movies',
#  'HBO NOW: Stream TV & Movies',
#  'HD Camera for Android',
#  'HD Widgets',
#  'HISTORY: Watch TV Show Full Episodes & Specials',
#  'HISTORY: Watch TV Show Full Episodes & Specials',
#  'Hangouts',
#  'Hangouts',
#  'Hangouts',
#  'Hangouts Dialer - Call Phones',
#  'Harry Potter: Hogwarts Mystery',
#  'Haystack TV: Local & World News - Free',
#  'Headspace: Meditation & Mindfulness',
#  'Health and Nutrition Guide',
#  'Helix Jump',
#  'Helix Jump',
#  'Helix Jump',
#  'Helix Jump',
#  'Helix Jump',
#  'Hello Kitty Nail Salon',
#  'HelloTalk — Chat, Speak & Learn Foreign Languages',
#  'Hide App, Private Dating, Safe Chat - PrivacyHider',
#  'High Blood Pressure Symptoms',
#  'Hill Climb Racing',
#  'Hill Climb Racing',
#  'Hill Climb Racing',
#  'Hill Climb Racing 2',
#  'Hily: Dating, Chat, Match, Meet & Hook up',
#  'Hily: Dating, Chat, Match, Meet & Hook up',
#  'Hinge: Dating & Relationships',
#  'HipChat - Chat Built for Teams',
#  'Hole19: Golf GPS App, Rangefinder & Scorecard',
#  'Home Security Camera WardenCam - reuse old phones',
#  'Home Workout - No Equipment',
#  'Homescapes',
#  'Honkai Impact 3rd',
#  'Hopper - Watch & Book Flights',
#  'Hospitalist Handbook',
#  'Hostelworld: Hostels & Cheap Hotels Travel App',
#  'Hot Wheels: Race Off',
#  'Hot or Not - Find someone right now',
#  'Hot or Not - Find someone right now',
#  'HotelTonight: Book amazing deals at great hotels',
#  'HotelTonight: Book amazing deals at great hotels',
#  'Hotels.com: Book Hotel Rooms & Find Vacation Deals',
#  'Houzz Interior Design Ideas',
#  'Houzz Interior Design Ideas',
#  'Houzz Interior Design Ideas',
#  'Howlr',
#  'Hulu: Stream TV, Movies & more',
#  'Hulu: Stream TV, Movies & more',
#  'Hulu: Stream TV, Movies & more',
#  'Human Anatomy Atlas 2018: Complete 3D Human Body',
#  'Human Anatomy Atlas 2018: Complete 3D Human Body',
#  'Hungry Shark Evolution',
#  'Hungry Shark Evolution',
#  'Hungry Shark World',
#  'IBM Micromedex Drug Info',
#  'IMDb Movies & TV',
#  'IMDb Movies & TV',
#  'Ibotta: Cash Back Savings, Rewards & Coupons App',
#  'Idle Heroes',
#  'Inside Out Thought Bubbles',
#  'Insightly CRM',
#  'InstaBeauty -Makeup Selfie Cam',
#  'InstaSize Photo Filters & Collage Editor',
#  'Instagram',
#  'Instagram',
#  'Instagram',
#  'Invoice & Time Tracking - Zoho',
#  'Invoice 2go — Professional Invoices and Estimates',
#  'I’m Expecting - Pregnancy App',
#  'JH Blood Pressure Monitor',
#  'JOANN - Crafts & Coupons',
#  "JackThreads: Men's Shopping",
#  "JackThreads: Men's Shopping",
#  'Jaumo Dating, Flirt & Live Video',
#  'Jetpack Joyride',
#  'Jewels Star: OZ adventure',
#  'Journal Club: Medicine',
#  'Jurassic World™ Alive',
#  'Just She - Top Lesbian Dating',
#  'Just She - Top Lesbian Dating',
#  'K PLUS',
#  'KAYAK Flights, Hotels & Cars',
#  'KAYAK Flights, Hotels & Cars',
#  'KakaoTalk: Free Calls & Text',
#  'KakaoTalk: Free Calls & Text',
#  'Khan Academy',
#  'Khan Academy',
#  'Kick the Buddy',
#  'Kick the Buddy',
#  'Kick the Buddy',
#  'Kids Balloon Pop Game Free 🎈',
#  'Knife Hit',
#  'LEGO® Juniors Create & Cruise',
#  'LEGO® TV',
#  'LINE Camera - Photo editor',
#  'LINE WEBTOON - Free Comics',
#  'LINE: Free Calls & Messages',
#  'LINE: Free Calls & Messages',
#  'LOVOO',
#  'Lark - 24/7 Health Coach',
#  'Last Day on Earth: Survival',
#  'Learn 50 languages',
#  'Learn C++',
#  'Learn English with Wlingua',
#  'Learn languages, grammar & vocabulary with Memrise',
#  'Learn languages, grammar & vocabulary with Memrise',
#  'Learn languages, grammar & vocabulary with Memrise',
#  'Lifetime - Watch Full Episodes & Original Movies',
#  'Lifetime - Watch Full Episodes & Original Movies',
#  'LinkedIn',
#  'Live Girls Talk - Free Video Chat',
#  'Live Talk - Free Text and Video Chat',
#  'LiveMe - Video chat, new friends, and make money',
#  'LivingSocial - Local Deals',
#  'LivingSocial - Local Deals',
#  'Lose It! - Calorie Counter',
#  'Lose It! - Calorie Counter',
#  'Love Balls',
#  'Lumosity: #1 Brain Games & Cognitive Training App',
#  'Lynda - Online Training Videos',
#  'MARVEL Contest of Champions',
#  'MARVEL Strike Force',
#  'MARVEL Strike Force',
#  'MEGA',
#  'MLB At Bat',
#  'MLB At Bat',
#  'MLB At Bat',
#  'MLB At Bat',
#  'MLB Ballpark',
#  'MTV',
#  'MX Player',
#  'MX Player',
#  'Magic Tiles 3',
#  'Magic Tiles 3',
#  'Magic Tiles 3',
#  'MailChimp - Email, Marketing Automation',
#  'Manga AZ - Manga Comic Reader',
#  'Mango Languages: Lovable Language Courses',
#  'Maps & GPS Navigation — OsmAnd',
#  'Maps - Navigate & Explore',
#  'Maps - Navigate & Explore',
#  'Mapy.cz - Cycling & Hiking offline maps',
#  'Maricopa AH',
#  'Masha and the Bear Child Games',
#  "McDonald's",
#  'Mcqueen Coloring pages',
#  'MealLogger-Photo Food Journal',
#  'Medical ID - In Case of Emergency (ICE)',
#  'Meditation Music - Relax, Yoga',
#  'Meet24 - Love, Chat, Singles',
#  'Meet4U - Chat, Love, Singles!',
#  'MeetMe: Chat & Meet New People',
#  'MeetMe: Chat & Meet New People',
#  'MeetMe: Chat & Meet New People',
#  'MeetMe: Chat & Meet New People',
#  'Meetup',
#  'Meetup',
#  'Meetup',
#  'Merge Dragons!',
#  'Messages, Text and Video Chat for Messenger',
#  'Messenger Lite: Free Calls & Messages',
#  'Messenger – Text and Video Chat for Free',
#  'Messenger – Text and Video Chat for Free',
#  'Metal Soldiers 2',
#  'Microsoft Edge',
#  'Microsoft Excel',
#  'Microsoft OneDrive',
#  'Microsoft OneNote',
#  'Microsoft OneNote',
#  'Microsoft Outlook',
#  'Microsoft PowerPoint',
#  'Microsoft Word',
#  'Microsoft Word',
#  'Millionaire Match: Rich Singles Dating App',
#  'Minecraft',
#  'Minion Rush: Despicable Me Official Game',
#  'Minion Rush: Despicable Me Official Game',
#  'Minion Rush: Despicable Me Official Game',
#  'Mint: Budget, Bills, Finance',
#  'Mint: Budget, Bills, Finance',
#  'Miraculous Ladybug & Cat Noir - The Official Game',
#  'Miraculous Ladybug & Cat Noir - The Official Game',
#  'Mobi Calculator free & AD free!',
#  'Mobile Doc Scanner (MDScan) Lite',
#  'Moco - Chat, Meet People',
#  'Moco - Chat, Meet People',
#  'Moco+ - Chat, Meet People',
#  "Modcloth – Unique Indie Women's Fashion & Style",
#  'Monash Uni Low FODMAP Diet',
#  'Money Lover: Expense Tracker, Budget Planner',
#  'Moneycontrol – Stocks, Sensex, Mutual Funds, IPO',
#  'Monster High™',
#  'Monster Truck Driver & Racing',
#  'MoodSpace',
#  'Moovit: Bus Time & Train Time Live Info',
#  'Mortgage by Zillow: Calculator & Rates',
#  'Moto File Manager',
#  'Motorola FM Radio',
#  'MouseMingle',
#  'Movies by Flixster, with Rotten Tomatoes',
#  'Movies by Flixster, with Rotten Tomatoes',
#  'Muscle Premium - Human Anatomy, Kinesiology, Bones',
#  'Muzy - Share photos & collages',
#  'My Class Schedule: Timetable',
#  'My Diet Diary Calorie Counter',
#  'My Dressing - Fashion closet',
#  'My Little Pony Celebration',
#  'My Little Pony: Harmony Quest',
#  'My Photo Keyboard',
#  'My Talking Angela',
#  'My Talking Angela',
#  'My Talking Angela',
#  'My Talking Tom',
#  'My Talking Tom',
#  'MyPlate Calorie Tracker',
#  'NBC News',
#  'NFL',
#  'NFL',
#  'NOOK App for NOOK Devices',
#  'NOOK: Read eBooks & Magazines',
#  'NPR News',
#  'NYTimes - Latest News',
#  'NYTimes - Latest News',
#  'Netflix',
#  'Netflix',
#  'Netflix',
#  'Netflix',
#  'Newegg Mobile',
#  'Newsroom: News Worth Sharing',
#  'Nextdoor - Local neighborhood news & classifieds',
#  'Nick',
#  'Nick',
#  'Nick',
#  'Nick',
#  'Nick',
#  'Nighty Night Circus',
#  'Nike Training Club - Workouts & Fitness Plans',
#  'Nike Training Club - Workouts & Fitness Plans',
#  'Nike+ Run Club',
#  'Nike+ Run Club',
#  'Nike+ Run Club',
#  'No Crop & Square for Instagram',
#  'No.Draw - Colors by Number 2018',
#  'Notepad & To do list',
#  'Nova Launcher',
#  'Nurse Grid',
#  'O-Star',
#  'O-Star',
#  'OfficeSuite : Free Office + PDF Editor',
#  'Offline Maps & Navigation',
#  'OkCupid Dating',
#  'OkCupid Dating',
#  'Once - Quality Matches Every day',
#  'Open Camera',
#  'Open Camera',
#  'Opera Browser: Fast and Secure',
#  'Opera Browser: Fast and Secure',
#  'Opera Mini - fast web browser',
#  'Opera Mini - fast web browser',
#  'Orbitz - Hotels, Flights & Package Deals',
#  'Overstock – Home Decor, Furniture Shopping',
#  'Ovia Fertility Tracker & Ovulation Calculator',
#  'Oxford Dictionary of English : Free',
#  'PAC-MAN',
#  'PBS KIDS Video',
#  'PGA TOUR',
#  'PJ Masks: Moonlight Heroes',
#  'PJ Masks: Moonlight Heroes',
#  'PMHNP-BC Pocket Prep',
#  'POF Free Dating App',
#  'POF Free Dating App',
#  'PTA Content Master',
#  'PUBG MOBILE',
#  'PUBG MOBILE',
#  'PUBG MOBILE',
#  'Panera Bread',
#  'Papumba Academy - Fun Learning For Kids',
#  'Papumba Academy - Fun Learning For Kids',
#  'Paramedic Protocol Provider',
#  'PayPal',
#  'Peak – Brain Games & Training',
#  'Pedi STAT',
#  'Penn State Health OnDemand',
#  'Period Tracker',
#  'Periscope - Live Video',
#  'Periscope - Live Video',
#  'Phogy, 3D Camera',
#  'Phone Tracker : Family Locator',
#  'Photo Editor',
#  'Photo Editor Pro',
#  'Photo Editor Selfie Camera Filter & Mirror Image',
#  'Photo Editor by Aviary',
#  'Photo Editor-',
#  'PicsArt Photo Studio: Collage Maker & Pic Editor',
#  'Pinterest',
#  'Pinterest',
#  'Pixel Art: Color by Number Game',
#  'Pixel Art: Color by Number Game',
#  'Planner Pro-Personal Organizer',
#  'Plants vs. Zombies FREE',
#  'Plants vs. Zombies FREE',
#  'Plants vs. Zombies FREE',
#  'Plants vs. Zombies FREE',
#  'Plants vs. Zombies™ Heroes',
#  'PlayKids - Educational cartoons and games for kids',
#  'Pocket Yoga',
#  'Podcast App: Free & Offline Podcasts by Player FM',
#  'Pokémon GO',
#  'Polaris Office - Word, Docs, Sheets, Slide, PDF',
#  'Poshmark - Buy & Sell Fashion',
#  'Postmates Food Delivery: Order Eats & Alcohol',
#  'Pou',
#  'Pou',
#  'Pou',
#  'PowerDirector Video Editor App: 4K, Slow Mo & More',
#  'Premier League - Official App',
#  'Priceline Hotel Deals, Rental Cars & Flights',
#  'Priceline Hotel Deals, Rental Cars & Flights',
#  'Princess Coloring Book',
#  'Puffin Web Browser',
#  'Puffin Web Browser',
#  'QR Scanner & Barcode Scanner 2018',
#  'Quick PDF Scanner + OCR FREE',
#  'Quick PDF Scanner + OCR FREE',
#  'QuickBooks Accounting: Invoicing & Expenses',
#  'QuickBooks Accounting: Invoicing & Expenses',
#  'QuickPic - Photo Gallery with Google Drive Support',
#  'QuickPic - Photo Gallery with Google Drive Support',
#  'Quizlet: Learn Languages & Vocab with Flashcards',
#  'Quizlet: Learn Languages & Vocab with Flashcards',
#  'Quizlet: Learn Languages & Vocab with Flashcards',
#  'Quora',
#  'ROBLOX',
#  'ROBLOX',
#  'ROBLOX',
#  'ROBLOX',
#  'ROBLOX',
#  'ROBLOX',
#  'ROBLOX',
#  'ROBLOX',
#  'RT 516 VET',
#  'RULES OF SURVIVAL',
#  'Racing in Car 2',
#  'Random Video Chat',
#  'Random Video Chat App With Strangers',
#  'Real Racing 3',
#  'Realtor.com Real Estate: Homes for Sale and Rent',
#  'Red Bull TV: Live Sports, Music & Entertainment',
#  'Redfin Real Estate',
#  'Relax Meditation: Sleep with Sleep Sounds',
#  'Relax Melodies: Sleep Sounds',
#  'RetailMeNot - Coupons, Deals & Discount Shopping',
#  'RetailMeNot - Coupons, Deals & Discount Shopping',
#  'Reuters News',
#  'Rider',
#  'Ringtone Maker',
#  'Robinhood - Investing, No Fees',
#  'Rosetta Stone: Learn to Speak & Read New Languages',
#  'Rosetta Stone: Learn to Speak & Read New Languages',
#  'Rosetta Stone: Learn to Speak & Read New Languages',
#  'Ruler',
#  'Run Sausage Run!',
#  'Run with Map My Run',
#  'Run with Map My Run',
#  'Runkeeper - GPS Track Run Walk',
#  'Runtastic Running App & Mile Tracker',
#  'Runtastic Running App & Mile Tracker',
#  'Runtastic Sleep Better: Sleep Cycle & Smart Alarm',
#  'SHAREit - Transfer & Share',
#  'SHOWTIME',
#  'SKOUT - Meet, Chat, Go Live',
#  'SONIC Drive-In',
#  'STARZ',
#  'STARZ',
#  'SUBWAY®',
#  'Sago Mini Babies',
#  'Sago Mini Friends',
#  'Sago Mini Friends',
#  'SayHi Chat, Meet New People',
#  'SayHi Chat, Meet New People',
#  'Scarf Fashion Designer',
#  'School of Dragons',
#  'Score! Hero',
#  'Score! Hero',
#  'ScriptSave WellRx Rx Discounts',
#  'Seven - 7 Minute Workout Training Challenge',
#  'Shadow Fight 2',
#  'Share Music & Transfer Files - Xender',
#  'Shopkick: Free Gift Cards, Shop Rewards & Deals',
#  'Shopkins World!',
#  'Shopular: Coupons, Weekly Ads & Shopping Deals',
#  'Showtime Anytime',
#  'Shutterfly: Free Prints, Photo Books, Cards, Gifts',
#  'Shutterfly: Free Prints, Photo Books, Cards, Gifts',
#  'Shutterfly: Free Prints, Photo Books, Cards, Gifts',
#  'SignEasy | Sign and Fill PDF and other Documents',
#  'Simple - Better Banking',
#  'Simple Habit Meditation',
#  'Six Pack in 30 Days - Abs Workout',
#  'Skype - free IM & video calls',
#  'Skype - free IM & video calls',
#  'Skyscanner',
#  'Skyscanner',
#  'Skyscanner',
#  'Skyscanner',
#  'Slack',
#  'Slack',
#  'Slickdeals: Coupons & Shopping',
#  'Slickdeals: Coupons & Shopping',
#  'Smart Launcher 5',
#  'Snapchat',
#  'Snapchat',
#  'Snapchat',
#  'SnipSnap Coupon App',
#  'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  'Socratic - Math Answers & Homework Help',
#  'Solitaire',
#  'Solitaire',
#  'Sonic Dash',
#  'Sounds for Toddlers FREE',
#  'Southwest Airlines',
#  'Spanish English Translator',
#  'Starbucks',
#  'Stocard - Rewards Cards Wallet',
#  'Strawberry Shortcake BerryRush',
#  'Strawberry Shortcake BerryRush',
#  'Strawberry Shortcake Ice Cream Island',
#  'StyleSeat',
#  'Subway Surfers',
#  'Subway Surfers',
#  'Subway Surfers',
#  'Subway Surfers',
#  'Subway Surfers',
#  'Sudy – Meet Elite & Rich Single',
#  'Super ABC! Learning games for kids! Preschool apps',
#  'Super Hearing Super Ear Amplifier',
#  'Super Jim Jump - pixel 3d',
#  'Super Jim Jump - pixel 3d',
#  'Swamp Attack',
#  'Sway Medical',
#  'TED',
#  'TED',
#  'TED',
#  'TO-FU Oh!SUSHI',
#  'Tagged - Meet, Chat & Dating',
#  'Talkatone: Free Texts, Calls & Phone Number',
#  'Talking Ben the Dog',
#  'Talking Tom Gold Run',
#  'Talking Tom Gold Run',
#  'Talking Tom Gold Run',
#  'Talkray - Free Calls & Texts',
#  'Tango - Live Video Broadcast',
#  'Tapatalk - 100,000+ Forums',
#  'Target - now with Cartwheel',
#  'Target - now with Cartwheel',
#  'Tee and Mo Bath Time Free',
#  'Teladoc Member',
#  'Telegram',
#  'Telegram',
#  'Telegram X',
#  'Telemundo Now',
#  'Temple Run 2',
#  'Temple Run 2',
#  'Temple Run 2',
#  'Temple Run 2',
#  'Temple Run 2',
#  'Text Free: WiFi Calling App',
#  'Text Free: WiFi Calling App',
#  'Text free - Free Text + Call',
#  'TextNow - free text + calls',
#  'Textgram - write on photos',
#  'The 5th Stand',
#  'The CW',
#  'The CW',
#  'The CW',
#  'The Coupons App',
#  'The Coupons App',
#  'The Coupons App',
#  'The Emirates App',
#  'The Game of Life',
#  'The NBC App - Watch Live TV and Full Episodes',
#  'The Sims™ FreePlay',
#  'The Wall Street Journal: Business & Market News',
#  'Thomas & Friends: Race On!',
#  'TickTick: To Do List with Reminder, Day Planner',
#  'Tiny Scanner - PDF Scanner App',
#  'Tiny Scanner Pro: PDF Doc Scan',
#  'To-Do Calendar Planner',
#  'Toca Kitchen 2',
#  'Toca Kitchen 2',
#  'Toca Life: City',
#  'Todoist: To-do lists for task management & errands',
#  'Todoist: To-do lists for task management & errands',
#  'Toon Blast',
#  'Toon Blast',
#  'Topbuzz: Breaking News, Videos & Funny GIFs',
#  'Toy Blast',
#  'Traffic Racer',
#  'Transenger – Ts Dating and Chat for Free',
#  'Transit: Real-Time Transit App',
#  ...]

# %%
# count frequency of names occurring

apps = {}
for name in new_apps:
    apps[name] = new_apps.count(name)
    
pprint.pprint(apps)
# Out:
# {'10 Best Foods for You': 1,
#  '1800 Contacts - Lens Store': 1,
#  '2017 EMRA Antibiotic Guide': 1,
#  '21-Day Meditation Experience': 1,
#  '365Scores - Live Scores': 1,
#  '420 BZ Budeze Delivery': 1,
#  '8 Ball Pool': 6,
#  '8fit Workouts & Meal Planner': 1,
#  '95Live -SG#1 Live Streaming App': 1,
#  'A Manual of Acupuncture': 1,
#  'A&E - Watch Full Episodes of TV Shows': 3,
#  'AAFP': 1,
#  'ABC News - US & World News': 1,
#  'AC - Tips & News for Android™': 1,
#  'AP Mobile - Breaking News': 1,
#  'ASCCP Mobile': 1,
#  'ASOS': 1,
#  'Accounting App - Zoho Books': 1,
#  'AccuWeather: Daily Forecast & Live Weather Reports': 1,
#  'Acorns - Invest Spare Change': 1,
#  'AdWords Express': 1,
#  'Ada - Your Health Guide': 1,
#  'Adobe Acrobat Reader': 2,
#  'Adobe Photoshop Express:Photo Editor Collage Maker': 1,
#  'Adult Dirty Emojis': 2,
#  'Advanced Comprehension Therapy': 1,
#  'Agar.io': 1,
#  'Airbnb': 1,
#  'Airway Ex - Intubate. Anesthetize. Train.': 1,
#  'AliExpress - Smarter Shopping, Better Living': 3,
#  'All Football - Latest News & Videos': 1,
#  'All Mental disorders': 1,
#  'All Social Networks': 1,
#  "Alto's Adventure": 1,
#  'Amazon Kindle': 1,
#  'Amazon Shopping': 2,
#  'Amazon for Tablets': 1,
#  'American Airlines': 2,
#  'Amino: Communities and Chats': 1,
#  'AnatomyMapp': 1,
#  'Android Messages': 1,
#  'Anger of stick 5 : zombie': 1,
#  'Angry Birds 2': 1,
#  'Angry Birds Classic': 4,
#  'Angry Birds Rio': 3,
#  'Animal Jam - Play Wild!': 1,
#  'Anthem Anywhere': 1,
#  'Anthem BC Anywhere': 1,
#  'Any.do: To-do list, Calendar, Reminders & Planner': 2,
#  'Apartment List: Housing, Apt, and Property Rentals': 1,
#  'Apartments & Rentals - Zillow': 1,
#  'Apartments.com Rental Search': 1,
#  'Apex Launcher': 2,
#  'Asana: organize team projects': 1,
#  'Avokiddo Emotions': 1,
#  'B612 - Beauty & Filter Camera': 2,
#  'BBC News': 2,
#  'BBC Sport': 1,
#  'BBM - Free Calls & Messages': 1,
#  'BBW Dating & Curvy Singles Chat- LargeFriends': 1,
#  'BBW Dating & Plus Size Chat': 2,
#  'BET NOW - Watch Shows': 2,
#  'BP Journal - Blood Pressure Diary': 1,
#  'BZWBK24 mobile': 1,
#  'Babbel – Learn Languages': 3,
#  'Baby Panda Care': 1,
#  'Backgrounds HD (Wallpapers)': 1,
#  'Badoo - Free Chat & Dating App': 3,
#  'Banfield Pet Health Tracker': 1,
#  'Barbie™ Fashion Closet': 1,
#  'Beautiful Widgets Free': 1,
#  'Beautiful Widgets Pro': 1,
#  'BeautyPlus - Easy Photo Editor & Selfie Camera': 4,
#  'Best Fiends - Free Puzzle Game': 1,
#  'BeyondMenu Food Delivery': 1,
#  'Bita and the Animals - Pelos Ares': 1,
#  'Black People Meet Singles Date': 1,
#  'Black White Interracial Dating - Interracial Match': 1,
#  'Bleacher Report: sports news, scores, & highlights': 5,
#  'Blendr - Chat, Flirt & Meet': 1,
#  'Block Buddy': 1,
#  'Block Craft 3D: Building Simulator Games For Free': 2,
#  'Block Puzzle': 3,
#  'Block Puzzle Classic Legend !': 1,
#  'Blood Pressure': 2,
#  'Blood Pressure Companion': 1,
#  'Blood Pressure Log - MyDiary': 1,
#  'Blood Pressure Monitor': 1,
#  'Blood Pressure(BP) Diary': 1,
#  'Blur Image Background': 1,
#  'Booking.com Travel Deals': 2,
#  'Bowmasters': 5,
#  'Box': 2,
#  'Breastfeeding Tracker Baby Log': 1,
#  'Brilliant': 1,
#  'Brit + Co': 1,
#  'British Airways': 1,
#  'Bubble Shooter': 5,
#  'Bubble Shooter 2': 1,
#  'BuzzFeed: News, Tasty, Quizzes': 1,
#  'C Programming': 1,
#  'CBS - Full Episodes & Live TV': 1,
#  'CBS Sports App - Scores, News, Stats & Watch Live': 7,
#  'CBS Sports Fantasy': 1,
#  'CJmall': 1,
#  'CM Browser - Ad Blocker , Fast Download , Privacy': 1,
#  'CM FILE MANAGER HD': 1,
#  'CM Flashlight (Compass, SOS)': 1,
#  'CM Launcher 3D - Theme, Wallpapers, Efficient': 1,
#  'CM Locker - Security Lockscreen': 1,
#  'CMB Free Dating App': 1,
#  'CNBC: Breaking Business News & Live Market Data': 1,
#  'CNN Breaking US & World News': 2,
#  "COOKING MAMA Let's Cook!": 1,
#  'CT Scan Cross Sectional Anatomy': 1,
#  'CW Seed': 1,
#  'Cache Cleaner-DU Speed Booster (booster & cleaner)': 1,
#  'Calculator': 1,
#  'Call Blocker': 1,
#  'CallApp: Caller ID, Blocker & Phone Call Recorder': 1,
#  'Calls & Text by Mo+': 1,
#  'Calm - Meditate, Sleep, Relax': 1,
#  'Calorie Counter & Diet Tracker': 1,
#  'Calorie Counter - Macros': 1,
#  'Calorie Counter - MyFitnessPal': 4,
#  'Calorie Counter - MyNetDiary': 1,
#  'Calorie Counter by FatSecret': 1,
#  'Camera FV-5': 1,
#  'Camera FV-5 Lite': 1,
#  'Camera MX - Free Photo & Video Camera': 1,
#  'Camera for Android': 2,
#  'Camera360 Lite - Selfie Camera': 1,
#  'Camera360: Selfie Photo Editor with Funny Sticker': 2,
#  'Candy Bomb': 1,
#  'Candy Camera - selfie, beauty camera, photo editor': 2,
#  'Candy Crush Jelly Saga': 1,
#  'Candy Crush Saga': 6,
#  'Candy Crush Soda Saga': 2,
#  'Capital One® Mobile': 1,
#  'Cardboard': 1,
#  'Cardi B Live Stream Video Chat - Prank': 1,
#  'Cardiac diagnosis (heart rate, arrhythmia)': 2,
#  'Carousell: Snap-Sell, Chat-Buy': 1,
#  'Cartoon Network App': 1,
#  'Castle Clash: Heroes of the Empire US': 1,
#  'Casual Dating & Adult Singles - Joyride': 1,
#  'Chat Kids - Chat Room For Kids': 1,
#  'Chat Rooms, Avatars, Date - Galaxy': 1,
#  'Cheapflights – Flight Search': 1,
#  'Checkout 51: Grocery coupons': 2,
#  'Chess Free': 1,
#  'Chick-fil-A': 2,
#  'Chictopia': 1,
#  'Chispa, the Dating App for Latino, Latina Singles': 1,
#  'Choices: Stories You Play': 1,
#  'Christian Dating For Free App': 1,
#  'Chrome Beta': 1,
#  'Chrome Dev': 1,
#  'Clash Royale': 3,
#  'Clash of Clans': 3,
#  'ClassDojo': 2,
#  'Clover Dating App': 1,
#  'Color by Number – New Coloring Book': 1,
#  'ColorNote Notepad Notes': 1,
#  'Colorfy: Coloring Book for Adults - Free': 1,
#  'Coloring book moana': 1,
#  'Comedy Central': 1,
#  'Cooking Fever': 1,
#  'Cougar Dating Life : Date Older Women Sugar Mummy': 1,
#  'Couple - Relationship App': 1,
#  'Coursera: Online courses': 1,
#  'CppDroid - C/C++ IDE': 1,
#  'Crackle - Free TV & Movies': 2,
#  'Credit Karma': 2,
#  'Crew - Free Messaging and Scheduling': 1,
#  'Cricbuzz - Live Cricket Scores & News': 1,
#  'Crossy Road': 1,
#  'Crunchyroll - Everything Anime': 2,
#  'Curriculum vitae App CV Builder Free Resume Maker': 1,
#  'Cut the Rope FULL FREE': 2,
#  'Cymera Camera- Photo Editor, Filter,Collage,Layout': 3,
#  'DC Comics': 1,
#  'DC Super Hero Girls™': 3,
#  'DEAD TARGET: FPS Zombie Apocalypse Survival Games': 1,
#  'DEER HUNTER 2018': 1,
#  'DINO HUNTER: DEADLY SHORES': 1,
#  'DRAGON BALL LEGENDS': 3,
#  'DU Browser—Browse fast & fun': 1,
#  'Daily Manga - Comic & Webtoon': 1,
#  'Daily Yoga - Yoga Fitness Plans': 2,
#  'Dairy Queen': 1,
#  'Dating App, Flirt & Chat : W-Match': 1,
#  'Dating for 50 plus Mature Singles – FINALLY': 1,
#  'Diabetes & Diet Tracker': 1,
#  'Diabetes:M': 1,
#  'Diary with lock': 1,
#  'Dictionary - Merriam-Webster': 1,
#  'Digit Save Money Automatically': 1,
#  'Disney Magic Kingdoms: Build Your Own Magical Park': 1,
#  'DisneyNOW – TV Shows & Games': 2,
#  'Do It Later: Tasks & To-Dos': 1,
#  'Docs To Go™ Free Office Suite': 1,
#  'Dog Run - Pet Dog Simulator': 2,
#  "Domino's Pizza USA": 1,
#  "Dr. Panda & Toto's Treehouse": 2,
#  'Dream League Soccer 2018': 2,
#  'DreamWorks Friends': 1,
#  'Dropbox': 2,
#  'Dude Perfect 2': 1,
#  'Dungeon Hunter Champions: Epic Online Action RPG': 1,
#  "Dunkin' Donuts": 1,
#  'Duolingo: Learn Languages Free': 6,
#  'E*TRADE Mobile': 1,
#  'EMT PASS': 1,
#  'EMT Review Plus': 1,
#  'EMT Tutor NREMT-B Study Guide': 1,
#  'EMT-B Pocket Prep': 1,
#  'ES File Explorer File Manager': 2,
#  'ESPN': 6,
#  'ESPN Fantasy Sports': 3,
#  'Earn to Die 2': 1,
#  'Ebook Reader': 1,
#  'Edmodo': 1,
#  'EliteSingles – Dating for Single Professionals': 1,
#  'Elmo Calls by Sesame Street': 2,
#  'Endomondo - Running & Walking': 1,
#  'English Dictionary - Offline': 1,
#  'English Grammar Test': 1,
#  'Episode - Choose Your Story': 1,
#  'Equestria Girls': 2,
#  'Essential Anatomy 3': 1,
#  'Etsy: Handmade & Vintage Goods': 1,
#  'Evernote – Organizer, Planner for Notes & Memos': 3,
#  'Expedia Hotels, Flights & Car Rental Travel Deals': 3,
#  'Extreme Coupon Finder': 2,
#  'FIFA - Tournaments, Soccer News & Live Scores': 1,
#  'FOX': 1,
#  'FOX NOW - On Demand & Live TV': 2,
#  'FOX Sports: Live Streaming, Scores & News': 1,
#  'FP Notebook': 1,
#  'Fabulous: Motivate Me! Meditate, Relax, Sleep': 1,
#  'Face Filter, Selfie Editor - Sweet Camera': 1,
#  'Facebook': 1,
#  'Facebook Ads Manager': 1,
#  'Facebook Lite': 1,
#  'Facebook Pages Manager': 1,
#  'Facetune - For Free': 2,
#  'Fallout Shelter': 1,
#  'Fancy': 2,
#  'Fandango Movies - Times + Tickets': 1,
#  'Fantasy Football': 1,
#  'Farm Heroes Saga': 4,
#  'FarmersOnly Dating': 1,
#  'Farming Simulator 14': 1,
#  'Fashion in Vogue': 2,
#  'Fast Scanner : Free PDF Scan': 1,
#  'FastMeet: Chat, Dating, Love': 1,
#  'FilterGrid - Cam&Photo Editor': 1,
#  'Final Fantasy XV: A New Empire': 1,
#  'Find Real Love — YouLove Premium Dating': 1,
#  'Firefox Browser fast & private': 2,
#  'Firefox Focus: The privacy browser': 2,
#  'Fishdom': 2,
#  'Fitbit Coach': 1,
#  'Flashlight': 1,
#  'Flickr': 1,
#  'Flipboard: News For Our Time': 2,
#  'Flipkart Online Shopping App': 1,
#  'Flipp - Weekly Shopping': 1,
#  'FlirtChat - ♥Free Dating/Flirting App♥': 1,
#  'Flow Free': 4,
#  'Fly Delta': 1,
#  'Food Calorie Calculator': 1,
#  'Food Network': 2,
#  'FotMob - Live Soccer Scores': 1,
#  'Fox News – Breaking News, Live Video & News Alerts': 2,
#  'Free Blood Pressure': 2,
#  'Free Cam Girls - Live Webcam': 1,
#  'Free Dating & Flirt Chat - Choice of Love': 1,
#  'Free Dating App - Meet Local Singles - Flirt Chat': 1,
#  'Free Dating App - YoCutie - Flirt, Chat & Meet': 1,
#  'Free Dating Hook Up Messenger': 1,
#  'Free phone calls, free texting SMS on free number': 1,
#  'FreshBooks Classic': 1,
#  'Frozen Free Fall': 2,
#  'Fruits Bomb': 1,
#  'Fun Kid Racing - Motocross': 1,
#  'Fuzzy Numbers: Pre-K Number Foundation': 1,
#  'G Cloud Backup': 1,
#  'GO Keyboard - Emoticon keyboard, Free Theme, GIF': 1,
#  'Galaxy Attack: Alien Shooter': 2,
#  "Game for KIDS: KIDS match'em": 1,
#  'Gardenscapes': 1,
#  'Garena Free Fire': 3,
#  'Gay Sugar Daddy Dating & Hookup – Sudy Gay': 1,
#  'Gboard - the Google Keyboard': 2,
#  'Genius Scan - PDF Scanner': 1,
#  'Geometry Dash World': 1,
#  'Girls Live Chat - Free Text & Video Chat': 1,
#  'Glide - Video Chat Messenger': 1,
#  'Gmail': 2,
#  'Golfshot: Golf GPS + Tee Times': 1,
#  'Google': 1,
#  'Google Ads': 2,
#  'Google Allo': 2,
#  'Google Analytics': 1,
#  'Google Calendar': 2,
#  'Google Chrome: Fast & Secure': 2,
#  'Google Classroom': 2,
#  'Google Docs': 2,
#  'Google Drive': 3,
#  'Google Duo - High Quality Video Calls': 1,
#  'Google Earth': 1,
#  'Google Keep': 3,
#  'Google My Business': 2,
#  'Google News': 3,
#  'Google PDF Viewer': 2,
#  'Google Pay': 3,
#  'Google Photos': 3,
#  'Google Play Games': 1,
#  'Google Sheets': 1,
#  'Google Street View': 1,
#  'Google Translate': 1,
#  'Google Voice': 2,
#  'Google+': 1,
#  'Granny': 4,
#  'Groupon - Shop Deals, Discounts & Coupons': 3,
#  'Grubhub: Food Delivery': 1,
#  'Gyft - Mobile Gift Card Wallet': 2,
#  'H TV': 1,
#  'H&M': 1,
#  'HBO GO: Stream with TV Package': 1,
#  'HBO NOW: Stream TV & Movies': 3,
#  'HD Camera for Android': 1,
#  'HD Widgets': 1,
#  'HISTORY: Watch TV Show Full Episodes & Specials': 2,
#  'Hangouts': 3,
#  'Hangouts Dialer - Call Phones': 1,
#  'Harry Potter: Hogwarts Mystery': 1,
#  'Haystack TV: Local & World News - Free': 1,
#  'Headspace: Meditation & Mindfulness': 1,
#  'Health and Nutrition Guide': 1,
#  'Helix Jump': 5,
#  'Hello Kitty Nail Salon': 1,
#  'HelloTalk — Chat, Speak & Learn Foreign Languages': 1,
#  'Hide App, Private Dating, Safe Chat - PrivacyHider': 1,
#  'High Blood Pressure Symptoms': 1,
#  'Hill Climb Racing': 3,
#  'Hill Climb Racing 2': 1,
#  'Hily: Dating, Chat, Match, Meet & Hook up': 2,
#  'Hinge: Dating & Relationships': 1,
#  'HipChat - Chat Built for Teams': 1,
#  'Hole19: Golf GPS App, Rangefinder & Scorecard': 1,
#  'Home Security Camera WardenCam - reuse old phones': 1,
#  'Home Workout - No Equipment': 1,
#  'Homescapes': 1,
#  'Honkai Impact 3rd': 1,
#  'Hopper - Watch & Book Flights': 1,
#  'Hospitalist Handbook': 1,
#  'Hostelworld: Hostels & Cheap Hotels Travel App': 1,
#  'Hot Wheels: Race Off': 1,
#  'Hot or Not - Find someone right now': 2,
#  'HotelTonight: Book amazing deals at great hotels': 2,
#  'Hotels.com: Book Hotel Rooms & Find Vacation Deals': 1,
#  'Houzz Interior Design Ideas': 3,
#  'Howlr': 1,
#  'Hulu: Stream TV, Movies & more': 3,
#  'Human Anatomy Atlas 2018: Complete 3D Human Body': 2,
#  'Hungry Shark Evolution': 2,
#  'Hungry Shark World': 1,
#  'IBM Micromedex Drug Info': 1,
#  'IMDb Movies & TV': 2,
#  'Ibotta: Cash Back Savings, Rewards & Coupons App': 1,
#  'Idle Heroes': 1,
#  'Inside Out Thought Bubbles': 1,
#  'Insightly CRM': 1,
#  'InstaBeauty -Makeup Selfie Cam': 1,
#  'InstaSize Photo Filters & Collage Editor': 1,
#  'Instagram': 3,
#  'Invoice & Time Tracking - Zoho': 1,
#  'Invoice 2go — Professional Invoices and Estimates': 1,
#  'I’m Expecting - Pregnancy App': 1,
#  'JH Blood Pressure Monitor': 1,
#  'JOANN - Crafts & Coupons': 1,
#  "JackThreads: Men's Shopping": 2,
#  'Jaumo Dating, Flirt & Live Video': 1,
#  'Jetpack Joyride': 1,
#  'Jewels Star: OZ adventure': 1,
#  'Journal Club: Medicine': 1,
#  'Jurassic World™ Alive': 1,
#  'Just She - Top Lesbian Dating': 2,
#  'K PLUS': 1,
#  'KAYAK Flights, Hotels & Cars': 2,
#  'KakaoTalk: Free Calls & Text': 2,
#  'Khan Academy': 2,
#  'Kick the Buddy': 3,
#  'Kids Balloon Pop Game Free 🎈': 1,
#  'Knife Hit': 1,
#  'LEGO® Juniors Create & Cruise': 1,
#  'LEGO® TV': 1,
#  'LINE Camera - Photo editor': 1,
#  'LINE WEBTOON - Free Comics': 1,
#  'LINE: Free Calls & Messages': 2,
#  'LOVOO': 1,
#  'Lark - 24/7 Health Coach': 1,
#  'Last Day on Earth: Survival': 1,
#  'Learn 50 languages': 1,
#  'Learn C++': 1,
#  'Learn English with Wlingua': 1,
#  'Learn languages, grammar & vocabulary with Memrise': 3,
#  'Lifetime - Watch Full Episodes & Original Movies': 2,
#  'LinkedIn': 1,
#  'Live Girls Talk - Free Video Chat': 1,
#  'Live Talk - Free Text and Video Chat': 1,
#  'LiveMe - Video chat, new friends, and make money': 1,
#  'LivingSocial - Local Deals': 2,
#  'Lose It! - Calorie Counter': 2,
#  'Love Balls': 1,
#  'Lumosity: #1 Brain Games & Cognitive Training App': 1,
#  'Lynda - Online Training Videos': 1,
#  'MARVEL Contest of Champions': 1,
#  'MARVEL Strike Force': 2,
#  'MEGA': 1,
#  'MLB At Bat': 4,
#  'MLB Ballpark': 1,
#  'MTV': 1,
#  'MX Player': 2,
#  'Magic Tiles 3': 3,
#  'MailChimp - Email, Marketing Automation': 1,
#  'Manga AZ - Manga Comic Reader': 1,
#  'Mango Languages: Lovable Language Courses': 1,
#  'Maps & GPS Navigation — OsmAnd': 1,
#  'Maps - Navigate & Explore': 2,
#  'Mapy.cz - Cycling & Hiking offline maps': 1,
#  'Maricopa AH': 1,
#  'Masha and the Bear Child Games': 1,
#  "McDonald's": 1,
#  'Mcqueen Coloring pages': 1,
#  'MealLogger-Photo Food Journal': 1,
#  'Medical ID - In Case of Emergency (ICE)': 1,
#  'Meditation Music - Relax, Yoga': 1,
#  'Meet24 - Love, Chat, Singles': 1,
#  'Meet4U - Chat, Love, Singles!': 1,
#  'MeetMe: Chat & Meet New People': 4,
#  'Meetup': 3,
#  'Merge Dragons!': 1,
#  'Messages, Text and Video Chat for Messenger': 1,
#  'Messenger Lite: Free Calls & Messages': 1,
#  'Messenger – Text and Video Chat for Free': 2,
#  'Metal Soldiers 2': 1,
#  'Microsoft Edge': 1,
#  'Microsoft Excel': 1,
#  'Microsoft OneDrive': 1,
#  'Microsoft OneNote': 2,
#  'Microsoft Outlook': 1,
#  'Microsoft PowerPoint': 1,
#  'Microsoft Word': 2,
#  'Millionaire Match: Rich Singles Dating App': 1,
#  'Minecraft': 1,
#  'Minion Rush: Despicable Me Official Game': 3,
#  'Mint: Budget, Bills, Finance': 2,
#  'Miraculous Ladybug & Cat Noir - The Official Game': 2,
#  'Mobi Calculator free & AD free!': 1,
#  'Mobile Doc Scanner (MDScan) Lite': 1,
#  'Moco - Chat, Meet People': 2,
#  'Moco+ - Chat, Meet People': 1,
#  "Modcloth – Unique Indie Women's Fashion & Style": 1,
#  'Monash Uni Low FODMAP Diet': 1,
#  'Money Lover: Expense Tracker, Budget Planner': 1,
#  'Moneycontrol – Stocks, Sensex, Mutual Funds, IPO': 1,
#  'Monster High™': 1,
#  'Monster Truck Driver & Racing': 1,
#  'MoodSpace': 1,
#  'Moovit: Bus Time & Train Time Live Info': 1,
#  'Mortgage by Zillow: Calculator & Rates': 1,
#  'Moto File Manager': 1,
#  'Motorola FM Radio': 1,
#  'MouseMingle': 1,
#  'Movies by Flixster, with Rotten Tomatoes': 2,
#  'Muscle Premium - Human Anatomy, Kinesiology, Bones': 1,
#  'Muzy - Share photos & collages': 1,
#  'My Class Schedule: Timetable': 1,
#  'My Diet Diary Calorie Counter': 1,
#  'My Dressing - Fashion closet': 1,
#  'My Little Pony Celebration': 1,
#  'My Little Pony: Harmony Quest': 1,
#  'My Photo Keyboard': 1,
#  'My Talking Angela': 3,
#  'My Talking Tom': 2,
#  'MyPlate Calorie Tracker': 1,
#  'NBC News': 1,
#  'NFL': 2,
#  'NOOK App for NOOK Devices': 1,
#  'NOOK: Read eBooks & Magazines': 1,
#  'NPR News': 1,
#  'NYTimes - Latest News': 2,
#  'Netflix': 4,
#  'Newegg Mobile': 1,
#  'Newsroom: News Worth Sharing': 1,
#  'Nextdoor - Local neighborhood news & classifieds': 1,
#  'Nick': 5,
#  'Nighty Night Circus': 1,
#  'Nike Training Club - Workouts & Fitness Plans': 2,
#  'Nike+ Run Club': 3,
#  'No Crop & Square for Instagram': 1,
#  'No.Draw - Colors by Number 2018': 1,
#  'Notepad & To do list': 1,
#  'Nova Launcher': 1,
#  'Nurse Grid': 1,
#  'O-Star': 2,
#  'OfficeSuite : Free Office + PDF Editor': 1,
#  'Offline Maps & Navigation': 1,
#  'OkCupid Dating': 2,
#  'Once - Quality Matches Every day': 1,
#  'Open Camera': 2,
#  'Opera Browser: Fast and Secure': 2,
#  'Opera Mini - fast web browser': 2,
#  'Orbitz - Hotels, Flights & Package Deals': 1,
#  'Overstock – Home Decor, Furniture Shopping': 1,
#  'Ovia Fertility Tracker & Ovulation Calculator': 1,
#  'Oxford Dictionary of English : Free': 1,
#  'PAC-MAN': 1,
#  'PBS KIDS Video': 1,
#  'PGA TOUR': 1,
#  'PJ Masks: Moonlight Heroes': 2,
#  'PMHNP-BC Pocket Prep': 1,
#  'POF Free Dating App': 2,
#  'PTA Content Master': 1,
#  'PUBG MOBILE': 3,
#  'Panera Bread': 1,
#  'Papumba Academy - Fun Learning For Kids': 2,
#  'Paramedic Protocol Provider': 1,
#  'PayPal': 1,
#  'Peak – Brain Games & Training': 1,
#  'Pedi STAT': 1,
#  'Penn State Health OnDemand': 1,
#  'Period Tracker': 1,
#  'Periscope - Live Video': 2,
#  'Phogy, 3D Camera': 1,
#  'Phone Tracker : Family Locator': 1,
#  'Photo Editor': 1,
#  'Photo Editor Pro': 1,
#  'Photo Editor Selfie Camera Filter & Mirror Image': 1,
#  'Photo Editor by Aviary': 1,
#  'Photo Editor-': 1,
#  'PicsArt Photo Studio: Collage Maker & Pic Editor': 1,
#  'Pinterest': 2,
#  'Pixel Art: Color by Number Game': 2,
#  'Planner Pro-Personal Organizer': 1,
#  'Plants vs. Zombies FREE': 4,
#  'Plants vs. Zombies™ Heroes': 1,
#  'PlayKids - Educational cartoons and games for kids': 1,
#  'Pocket Yoga': 1,
#  'Podcast App: Free & Offline Podcasts by Player FM': 1,
#  'Pokémon GO': 1,
#  'Polaris Office - Word, Docs, Sheets, Slide, PDF': 1,
#  'Poshmark - Buy & Sell Fashion': 1,
#  'Postmates Food Delivery: Order Eats & Alcohol': 1,
#  'Pou': 3,
#  'PowerDirector Video Editor App: 4K, Slow Mo & More': 1,
#  'Premier League - Official App': 1,
#  'Priceline Hotel Deals, Rental Cars & Flights': 2,
#  'Princess Coloring Book': 1,
#  'Puffin Web Browser': 2,
#  'QR Scanner & Barcode Scanner 2018': 1,
#  'Quick PDF Scanner + OCR FREE': 2,
#  'QuickBooks Accounting: Invoicing & Expenses': 2,
#  'QuickPic - Photo Gallery with Google Drive Support': 2,
#  'Quizlet: Learn Languages & Vocab with Flashcards': 3,
#  'Quora': 1,
#  'ROBLOX': 8,
#  'RT 516 VET': 1,
#  'RULES OF SURVIVAL': 1,
#  'Racing in Car 2': 1,
#  'Random Video Chat': 1,
#  'Random Video Chat App With Strangers': 1,
#  'Real Racing 3': 1,
#  'Realtor.com Real Estate: Homes for Sale and Rent': 1,
#  'Red Bull TV: Live Sports, Music & Entertainment': 1,
#  'Redfin Real Estate': 1,
#  'Relax Meditation: Sleep with Sleep Sounds': 1,
#  'Relax Melodies: Sleep Sounds': 1,
#  'RetailMeNot - Coupons, Deals & Discount Shopping': 2,
#  'Reuters News': 1,
#  'Rider': 1,
#  'Ringtone Maker': 1,
#  'Robinhood - Investing, No Fees': 1,
#  'Rosetta Stone: Learn to Speak & Read New Languages': 3,
#  'Ruler': 1,
#  'Run Sausage Run!': 1,
#  'Run with Map My Run': 2,
#  'Runkeeper - GPS Track Run Walk': 1,
#  'Runtastic Running App & Mile Tracker': 2,
#  'Runtastic Sleep Better: Sleep Cycle & Smart Alarm': 1,
#  'SHAREit - Transfer & Share': 1,
#  'SHOWTIME': 1,
#  'SKOUT - Meet, Chat, Go Live': 1,
#  'SONIC Drive-In': 1,
#  'STARZ': 2,
#  'SUBWAY®': 1,
#  'Sago Mini Babies': 1,
#  'Sago Mini Friends': 2,
#  'SayHi Chat, Meet New People': 2,
#  'Scarf Fashion Designer': 1,
#  'School of Dragons': 1,
#  'Score! Hero': 2,
#  'ScriptSave WellRx Rx Discounts': 1,
#  'Seven - 7 Minute Workout Training Challenge': 1,
#  'Shadow Fight 2': 1,
#  'Share Music & Transfer Files - Xender': 1,
#  'Shopkick: Free Gift Cards, Shop Rewards & Deals': 1,
#  'Shopkins World!': 1,
#  'Shopular: Coupons, Weekly Ads & Shopping Deals': 1,
#  'Showtime Anytime': 1,
#  'Shutterfly: Free Prints, Photo Books, Cards, Gifts': 3,
#  'SignEasy | Sign and Fill PDF and other Documents': 1,
#  'Simple - Better Banking': 1,
#  'Simple Habit Meditation': 1,
#  'Six Pack in 30 Days - Abs Workout': 1,
#  'Skype - free IM & video calls': 2,
#  'Skyscanner': 4,
#  'Slack': 2,
#  'Slickdeals: Coupons & Shopping': 2,
#  'Smart Launcher 5': 1,
#  'Snapchat': 3,
#  'SnipSnap Coupon App': 1,
#  'Sniper 3D Gun Shooter: Free Shooting Games - FPS': 5,
#  'Socratic - Math Answers & Homework Help': 1,
#  'Solitaire': 2,
#  'Sonic Dash': 1,
#  'Sounds for Toddlers FREE': 1,
#  'Southwest Airlines': 1,
#  'Spanish English Translator': 1,
#  'Starbucks': 1,
#  'Stocard - Rewards Cards Wallet': 1,
#  'Strawberry Shortcake BerryRush': 2,
#  'Strawberry Shortcake Ice Cream Island': 1,
#  'StyleSeat': 1,
#  'Subway Surfers': 5,
#  'Sudy – Meet Elite & Rich Single': 1,
#  'Super ABC! Learning games for kids! Preschool apps': 1,
#  'Super Hearing Super Ear Amplifier': 1,
#  'Super Jim Jump - pixel 3d': 2,
#  'Swamp Attack': 1,
#  'Sway Medical': 1,
#  'TED': 3,
#  'TO-FU Oh!SUSHI': 1,
#  'Tagged - Meet, Chat & Dating': 1,
#  'Talkatone: Free Texts, Calls & Phone Number': 1,
#  'Talking Ben the Dog': 1,
#  'Talking Tom Gold Run': 3,
#  'Talkray - Free Calls & Texts': 1,
#  'Tango - Live Video Broadcast': 1,
#  'Tapatalk - 100,000+ Forums': 1,
#  'Target - now with Cartwheel': 2,
#  'Tee and Mo Bath Time Free': 1,
#  'Teladoc Member': 1,
#  'Telegram': 2,
#  'Telegram X': 1,
#  'Telemundo Now': 1,
#  'Temple Run 2': 5,
#  'Text Free: WiFi Calling App': 2,
#  'Text free - Free Text + Call': 1,
#  'TextNow - free text + calls': 1,
#  'Textgram - write on photos': 1,
#  'The 5th Stand': 1,
#  'The CW': 3,
#  'The Coupons App': 3,
#  'The Emirates App': 1,
#  'The Game of Life': 1,
#  'The NBC App - Watch Live TV and Full Episodes': 1,
#  'The Sims™ FreePlay': 1,
#  'The Wall Street Journal: Business & Market News': 1,
#  'Thomas & Friends: Race On!': 1,
#  'TickTick: To Do List with Reminder, Day Planner': 1,
#  'Tiny Scanner - PDF Scanner App': 1,
#  'Tiny Scanner Pro: PDF Doc Scan': 1,
#  'To-Do Calendar Planner': 1,
#  'Toca Kitchen 2': 2,
#  'Toca Life: City': 1,
#  'Todoist: To-do lists for task management & errands': 2,
#  'Toon Blast': 2,
#  'Topbuzz: Breaking News, Videos & Funny GIFs': 1,
#  'Toy Blast': 1,
#  'Traffic Racer': 1,
#  'Transenger – Ts Dating and Chat for Free': 1,
#  'Transit: Real-Time Transit App': 1,
#  'TripAdvisor Hotels Flights Restaurants Attractions': 4,
#  'Truecaller: Caller ID, SMS spam blocking & Dialer': 1,
#  'Trulia Real Estate & Rentals': 1,
#  'Trulia Rent Apartments & Homes': 1,
#  'Tubi TV - Free Movies & TV': 2,
#  'Tumblr': 2,
#  'Turbo FAST': 1,
#  'TurboScan: scan documents and receipts in PDF': 1,
#  'Twitch: Livestream Multiplayer Games & Esports': 1,
#  'Twitter': 2,
#  'UC Browser - Fast Download Private & Secure': 2,
#  'UC Browser Mini -Tiny Fast Private & Secure': 2,
#  'UFC': 1,
#  'UNICORN - Color By Number & Pixel Art Coloring': 1,
#  'US Open Tennis Championships 2018': 1,
#  'USA TODAY': 2,
#  'Uber': 1,
#  'Udacity - Lifelong Learning': 1,
#  'Udemy - Online Courses': 2,
#  'United Airlines': 1,
#  'Univision NOW - Live TV and On Demand': 1,
#  'VH1': 2,
#  'VLC for Android': 1,
#  'VPN Free - Betternet Hotspot VPN & Private Browser': 1,
#  'Vaniday - Beauty Booking App': 1,
#  'Vargo Anesthesia Mega App': 1,
#  'Viber Messenger': 4,
#  'Video Downloader': 1,
#  'Video Editor': 2,
#  'Video Player All Format': 1,
#  'Vigo Video': 1,
#  'Viki: Asian TV Dramas & Movies': 2,
#  'WPS Office - Word, Docs, PDF, Note, Slide & Sheet': 1,
#  'WWE': 1,
#  'Walk with Map My Walk': 1,
#  'Walmart': 1,
#  'Wanelo Shopping': 1,
#  'WatchESPN': 3,
#  'Wattpad 📖 Free Books': 1,
#  'Waze - GPS, Maps, Traffic Alerts & Live Navigation': 1,
#  'We Heart It': 1,
#  'WeChat': 3,
#  'Weather by eltiempo.es': 1,
#  'Web Browser for Android': 1,
#  'Weight Loss Running by Verv': 2,
#  'Weight Loss Tracker - RecStyle': 1,
#  'Weight Watchers Mobile': 2,
#  'Wells Fargo Daily Change': 1,
#  'Wells Fargo Mobile': 1,
#  'Wendy’s – Food and Offers': 1,
#  'WhatsApp Business': 1,
#  'WhatsApp Messenger': 2,
#  'Wheretoget: Shop in style': 1,
#  'Who': 1,
#  'Who Viewed My Facebook Profile - Stalkers Visitors': 1,
#  'Whoscall - Caller ID & Block': 1,
#  'Wish - Shopping Made Fun': 4,
#  'Word Search': 3,
#  'Wordscapes': 3,
#  'Workout Trainer: fitness coach': 1,
#  'Wunderlist: To-Do List & Tasks': 2,
#  'Xero Accounting Software': 1,
#  'Yahoo Fantasy Sports - #1 Rated Fantasy App': 4,
#  'Yahoo Mail – Stay Organized': 2,
#  'Yahoo Sports - scores, stats, news, & highlights': 2,
#  'Yandex Browser with Protect': 1,
#  'YouCam Makeup - Magic Selfie Makeovers': 1,
#  'YouCam Perfect - Selfie Photo Editor': 2,
#  'YouTube': 1,
#  'YouTube Gaming': 1,
#  'YouTube Kids': 3,
#  'YouTube Studio': 1,
#  'Youper - AI Therapy': 2,
#  'Z Camera - Photo Editor, Beauty Selfie, Collage': 1,
#  'ZALORA Fashion Shopping': 1,
#  'ZEDGE™ Ringtones & Wallpapers': 3,
#  'ZOOM Cloud Meetings': 1,
#  'Zappos – Shoe shopping made simple': 1,
#  'Zara': 1,
#  'Zello PTT Walkie Talkie': 1,
#  'Zenefits': 1,
#  'Zillow: Find Houses for Sale & Apartments for Rent': 1,
#  'Zomato - Restaurant Finder and Food Delivery App': 1,
#  'Zombie Catchers': 5,
#  'Zombie Hunter King': 3,
#  'Zombie Tsunami': 4,
#  'Zoosk Dating App: Meet Singles': 1,
#  'ai.type Free Emoji Keyboard': 1,
#  'busuu: Learn Languages - Spanish, English & More': 3,
#  'eBay: Buy & Sell this Summer - Discover Deals Now!': 4,
#  'edX - Online Courses by Harvard, MIT & more': 1,
#  "fred's Pharmacy": 1,
#  'free video calls and chat': 2,
#  'iBP Blood Pressure': 1,
#  'iPair-Meet, Chat, Dating': 1,
#  'imo beta free calls and text': 1,
#  'imo free video calls and chat': 3,
#  'join.me - Simple Meetings': 2,
#  'letgo: Buy & Sell Used Stuff, Cars & Real Estate': 1,
#  'muzmatch: Muslim & Arab Singles, Marriage & Dating': 2,
#  'myAT&T': 1,
#  'mySugr: the blood sugar tracker made just for you': 2,
#  'ooVoo Video Calls, Messaging & Stories': 1,
#  'osmino Wi-Fi: free WiFi': 1,
#  'realestate.com.au - Buy, Rent & Sell Property': 1,
#  'slither.io': 5,
#  'stranger chat - anonymous chat': 1,
#  'textPlus: Free Text & Calls': 1,
#  'theScore: Live Sports Scores, News, Stats & Videos': 4,
#  'trivago: Hotels & Travel': 2,
#  'wetter.com - Weather and Radar': 1}

# %%
#what is the highest number of duplicates ?
max(apps.values())
# Out:
# 8

# %%
# which app do these duplicates belong to
for k, v in apps.items():
    if v == 8:
        print("k:", k)
# Out:
# k: ROBLOX

# %%
apps['ROBLOX']
# Out:
# 8

# %%
for row in google_data[1:]:
    name = row[0]
    if name == 'ROBLOX':
        print(row)
# Out:
# ['ROBLOX', 'GAME', '4.5', '4447388', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4447346', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4448791', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4449882', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4449910', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4449910', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4450855', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4450890', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4443407', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']

# %%
for row in google_data[1:]:
    name = row[0]
    if name == 'Box':
        print(row)
# Out:
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# We have to find a way to remove duplicate data and keep the most current. One of the ways to do this is to keep the duplicate entry with the highest number of reviews and discard the others

# %%
# show length of dataset once duplicates are removed (exclude the header)

non_dup_google = len(google_data[1:]) - number_of_duplicates

# %% [markdown]
# Length of google dataset once duplicates have been removed: {{non_dup_google}}

# %% [markdown]
# Create a dictionary where each key is a unique app name with the corresponding highest number of reviews of the app

# %%
# this code will extract the maximum number of reviews per unique app name in the duplicates free dataset

reviews_max = {}
for row in google_data[1:]:
    name = row[0]
    n_reviews = float(row[3])
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
    else:
        name not in reviews_max
        reviews_max[name] = n_reviews
        
        
pprint.pprint(reviews_max)  #pretty print the output to make it legible
# Out:
# {'"i DT" Fútbol. Todos Somos Técnicos.': 27.0,
#  '+Download 4 Instagram Twitter': 40467.0,
#  '- Free Comics - Comic Apps': 115.0,
#  '.R': 259.0,
#  '/u/app': 573.0,
#  '058.ba': 27.0,
#  '1. FC Köln App': 2019.0,
#  '10 Best Foods for You': 2490.0,
#  '10 Minutes a Day Times Tables': 681.0,
#  '10 WPM Amateur ham radio CW Morse code trainer': 10.0,
#  '10,000 Quotes DB (Premium)': 70.0,
#  '100 Doors of Revenge': 105766.0,
#  '100+ C Programs': 20.0,
#  '100000+ Messages - DP, Status, Jokes & GIF 2018': 121.0,
#  '101 C Programming Problems': 498.0,
#  '104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment room': 74359.0,
#  '11st': 48732.0,
#  '12 Step Meditations & Sober Prayers AA NA AL-ANON': 759.0,
#  '14thStreetVet': 0.0,
#  '17th Edition Cable Sizer': 47.0,
#  '1800 Contacts - Lens Store': 23160.0,
#  '1LINE – One Line with One Touch': 214878.0,
#  '1st Fed CI Mobile Banking': 0.0,
#  '2 Amateur ham radio CW Morse code practice keys TX': 6.0,
#  '2-Player Co-op Zombie Shoot': 33.0,
#  '20 Minuten (CH)': 14153.0,
#  '20 minutes (CH)': 4379.0,
#  '2000 AD Comics and Judge Dredd': 705.0,
#  '2017 BN SM Sales Conference': 2.0,
#  '2017 EMRA Antibiotic Guide': 12.0,
#  '2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif': 115773.0,
#  '2019 Tricks Es File Explores': 4.0,
#  '2048 BTS J Hope KPop Puzzle Game': 17.0,
#  '2048(AI)': 20.0,
#  '20WPM Amateur ham radio Koch CW Morse code trainer': 12.0,
#  '21-Day Meditation Experience': 11506.0,
#  '211:CK': 8.0,
#  '211:CK Lite': 3.0,
#  '23rd QM BDE EO': 0.0,
#  '24 megapixel hd camera': 802.0,
#  '24/7 BZ Reis': 421.0,
#  '25 Mins Ako ay may lobo Etc Pinoy Kid Song Offline': 0.0,
#  '25WPM Amateur ham radio Koch CW Morse code trainer': 0.0,
#  '2Date Dating App, Love and matching': 41605.0,
#  '2Do - Reminders, To-do List & Notes': 4649.0,
#  '2GIS: directory & navigator': 768833.0,
#  '2RedBeans': 337.0,
#  '2ndLine - Second Phone Number': 15880.0,
#  '30 Day AB Challenge - Lumowell': 793.0,
#  '30 Day Ab Challenge': 1886.0,
#  '30 Day Ab Challenge FREE': 48253.0,
#  '30 Day Fitness Challenge - Workout at Home': 471036.0,
#  '30-Day Ab Challenge Tracker': 224.0,
#  '30WPM Amateur ham radio Koch CW Morse code trainer': 1.0,
#  '350 Diy Room Decor Ideas': 27.0,
#  '360 Security - Free Antivirus, Booster, Cleaner': 16771865.0,
#  '360-M Flight': 84.0,
#  '365Scores - Live Scores': 666246.0,
#  '3D Blue Glass Water Keyboard Theme': 62209.0,
#  '3D Bowling': 1076243.0,
#  '3D Color Pixel by Number - Sandbox Art Coloring': 1518.0,
#  '3D Color by Number with Voxels': 5481.0,
#  '3D Color by Number: Voxel, Unicorn, Pixel Art 3D': 2017.0,
#  '3D DJ – DJ Mixer 2018': 6333.0,
#  '3D DJ – Music Mixer with Virtual DJ': 796.0,
#  '3D Holograms Joke': 31596.0,
#  '3D Live Neon Weed Launcher': 1724.0,
#  '3D Metal Piano Keys Keyboard Theme': 467.0,
#  '3D Tennis': 1008012.0,
#  '3DAnimeGirl DX DreamPortrait KAWAII Girl DressUp': 449.0,
#  '3G DZ Configuration': 488.0,
#  '3G to 4G Converter - Simulator': 268.0,
#  '3G/4G Config Dz': 2058.0,
#  '4 Paws PH': 1.0,
#  '4 in a Row': 4257.0,
#  '4 in a row': 47698.0,
#  '4 x4 Offroad SUV 3D Truck Simulator Driving 2017': 32.0,
#  "4-T's Bar-BQ & Catering": 0.0,
#  '420 BZ Budeze Delivery': 2.0,
#  '4Eternity EO': 0.0,
#  '4K Ultra Camera': 382.0,
#  '4K VIDEO PLAYER ULTRA HD': 20.0,
#  '4K Wallpapers and Ultra HD Backgrounds': 7583.0,
#  '4x4 Jeep Racer': 7279.0,
#  '5 Minute Ab Workouts': 2067.0,
#  '5 Minute Clinical Consult 2019 - #1 for 25 years': 33.0,
#  '5 Minute Veterinary Consult: Canine & Feline': 17.0,
#  '5 Nights at Cube Pizzeria City': 2691.0,
#  '5-Minute Clinical Consult': 84.0,
#  '50 Healthy Slow Cooker Recipes': 196.0,
#  '500 AP World History Questions': 7.0,
#  '50000 Free eBooks & Free AudioBooks': 52312.0,
#  '591 Housing Trading - Hong Kong': 3522.0,
#  '591 housing transactions - renting houses, middle-class houses, new cases, real-time registration, villas through the sky, apartment suites, MRT, buying a house selling prices, housing mortgages': 24977.0,
#  '6 Pack Promise - Ultimate Abs': 18921.0,
#  '7 Cups: Anxiety & Stress Chat': 13799.0,
#  '7 Day Food Journal Challenge': 3346.0,
#  '7 Minute Workout': 399009.0,
#  '7 Nights at Pixel Pizzeria - 2': 23168.0,
#  '7 Weeks - Habit & Goal Tracker': 6011.0,
#  '7 minute abs workout - Daily Ab Workout': 527.0,
#  '8 Ball Pool': 14184910.0,
#  '850 Sports News Digest': 539.0,
#  '8fit Workouts & Meal Planner': 115721.0,
#  '95Live -SG#1 Live Streaming App': 4954.0,
#  '98point6': 47.0,
#  '9GAG: Funny Gifs, Pics, Memes & Videos for IGTV': 1450632.0,
#  '9th stage': 454.0,
#  'A & B Taxi': 41.0,
#  'A Better Camera': 76484.0,
#  'A Call From Santa Claus!': 3720.0,
#  'A Manual of Acupuncture': 214.0,
#  'A Word A Day': 2398.0,
#  'A hundred': 236.0,
#  'A&E - Watch Full Episodes of TV Shows': 29708.0,
#  'A&W Restaurants': 14.0,
#  'A+ Gallery - Photos & Videos': 223941.0,
#  'A+ Mobile': 730.0,
#  'A-B repeater': 32.0,
#  'A-J Media Vault': 1.0,
#  'A-Y Collection': 2.0,
#  'A-Z App Store': 2728.0,
#  'A-Z Punjabi Songs & Music Videos 2018': 367.0,
#  'A-Z Screen Recorder -': 17.0,
#  'A. O. Smith': 32.0,
#  'A.J. Green Wallpapers 4 Fans': 0.0,
#  'A.J. Styles HD Wallpapers 2018': 1.0,
#  'A/C Air Conditioner Remote': 7816.0,
#  'A/C REFRIGERANT CAPACITY': 84.0,
#  'A/C Universal Remote Control': 3263.0,
#  'A41 WatchFace for Android Wear Smart Watch': 231.0,
#  'AAFP': 63.0,
#  'AAS-IN-ASIA 2018': 3.0,
#  'AB Anywhere Mobile Banking': 3.0,
#  'AB Blast Match 3': 111.0,
#  'AB Click2Shop': 454.0,
#  'AB Crush Match 3': 96.0,
#  'AB Match': 9.0,
#  'AB Mobile App': 2105.0,
#  'AB Repeat Player': 1628.0,
#  'AB Screen Recorder': 533.0,
#  'ABAI CE Scanner': 0.0,
#  'ABC Kids - Tracing & Phonics': 36606.0,
#  'ABC News - US & World News': 18976.0,
#  'ABC Preschool Free': 27572.0,
#  'ABC – Live TV & Full Episodes': 50428.0,
#  'ABC15 Arizona': 1820.0,
#  'ABCmouse.com': 50887.0,
#  'ABG Master': 2.0,
#  'ABS Workout - Belly workout, 30 days AB': 5103.0,
#  'ABTO CY-ET1': 1.0,
#  'AC & TV, DVD, Set Top Box - Remote control IR': 3632.0,
#  'AC - Tips & News for Android™': 23291.0,
#  'AC Air condition Troubleshoot,Repair,Maintenance': 27.0,
#  'AC CE BJT Actorial': 1.0,
#  'AC DC Power Monitor': 1.0,
#  'AC Freedom': 537.0,
#  'AC Mobile Control': 1450.0,
#  'AC REMOTE UNIVERSAL-PRO': 402.0,
#  'AC Remote Control': 472.0,
#  'AC Remote Control Simulator': 353.0,
#  'AC Remote For LG': 1298.0,
#  'AC Remote for Carrier - NOW FREE': 163.0,
#  'AC Remote for Daikin - NOW FREE': 383.0,
#  'AC Remote for Haier - NOW FREE': 336.0,
#  'AC Remote for LG - NOW FREE': 1041.0,
#  'AC Remote for Midea - NOW FREE': 448.0,
#  'AC Remote for O General - NOW FREE': 274.0,
#  'AC Remote for Samsung - NOW FREE': 566.0,
#  'AC Remote for Sharp - NOW FREE': 332.0,
#  'AC Troubleshooter': 147.0,
#  'AC WIFI': 41.0,
#  'AC remote control mobile': 3043.0,
#  'AC-BL': 0.0,
#  'ACCDB MDB DB Manager Pro - Editor for MS Access': 19.0,
#  'ACCEPT CE MARKING': 0.0,
#  'ACE Elite': 2898.0,
#  'ACTIVEON CX & CX GOLD': 439.0,
#  'AD - News, Sports, Region & Entertainment': 10382.0,
#  'AD - Nieuws, Sport, Regio & Entertainment': 10369.0,
#  'ADMIRALTY H-Note': 176.0,
#  'ADP Mobile Solutions': 85185.0,
#  'ADS-B Driver': 2.0,
#  'ADW Launcher 2': 181399.0,
#  'ADWLauncher 1 EX': 28728.0,
#  'AE + Aerie: Jeans, Dresses, Swimsuits & Bralettes': 20476.0,
#  'AE 3D MOTOR :Racing Games Free': 74902.0,
#  'AE 3D Moto 3': 2588.0,
#  'AE Air Hockey': 926.0,
#  'AE Angry Chef': 533.0,
#  'AE Archer': 8638.0,
#  'AE Basketball': 8100.0,
#  'AE Bingo: Offline Bingo Games': 61746.0,
#  'AE Blackjack': 1417.0,
#  'AE Bubble:Offline Bubble Games': 6973.0,
#  'AE Bulletins': 14.0,
#  'AE Checkout Plugin': 208.0,
#  'AE City Jump': 804.0,
#  'AE Coin Mania : Arcade Fun': 30002.0,
#  'AE Fishing Hunter': 14.0,
#  'AE FreeCell': 358.0,
#  'AE GTO Racing': 6988.0,
#  'AE Garage': 64.0,
#  'AE Gun Ball: arcade ball games': 8581.0,
#  'AE Jewels': 960.0,
#  'AE Jewels 2: Island Adventures': 652.0,
#  'AE Lucky Fishing': 18277.0,
#  'AE Manager': 0.0,
#  'AE Master Moto': 17876.0,
#  'AE Order': 19.0,
#  'AE Roundy POP': 5262.0,
#  'AE Solitaire': 1776.0,
#  'AE Spider Solitaire': 17263.0,
#  'AE Sudoku': 2171.0,
#  'AE Video Poker': 721.0,
#  'AEE AP': 4.0,
#  "AEMET's time": 15966.0,
#  'AF Comics Reader - Free': 5.0,
#  'AF Hydro': 136.0,
#  'AF Johannesburg': 3.0,
#  'AF Legendary 2017': 0.0,
#  'AF Link': 210.0,
#  'AF Nutrition - Integratori': 6.0,
#  'AF Our Time to Shine': 0.0,
#  'AF-STROKE': 5.0,
#  'AF-STROKE (FREE)': 93.0,
#  'AG Contacts, Lite edition': 185.0,
#  'AG Contacts, Premium edition': 88.0,
#  'AG Drive 3D': 164.0,
#  'AG EMS Tour': 3.0,
#  'AG Fast Service Automotive': 5.0,
#  'AG Screen Recorder': 7.0,
#  'AG Subway Simulator Lite': 6738.0,
#  'AG Subway Simulator Mobile': 623.0,
#  'AG Subway Simulator Pro': 0.0,
#  'AG Track': 12.0,
#  'AG test': 3.0,
#  'AH Alarm Panel': 7.0,
#  'AH Connect (Adventist Health)': 5.0,
#  'AH Kollection for KLWP': 644.0,
#  'AH Lake Villa': 3.0,
#  'AH of Rocky Hill': 0.0,
#  'AH! Soundboard': 11.0,
#  'AH-1 Viper Cobra Ops - helicopter flight simulator': 1088.0,
#  'AI Benchmark': 97.0,
#  'AI Draw | Art Filter for Selfie': 20.0,
#  'AI Face Beauty Analysis - IntelliFace (Free)': 40.0,
#  'AI Image Recognizer (beta)': 0.0,
#  'AI Sight': 43.0,
#  'AI Today : Artificial Intelligence News & AI 101': 43.0,
#  'AI with Python Tutorial': 8.0,
#  'AJ AUTO': 0.0,
#  'AJ Academy: Amazing Animals': 1564.0,
#  'AJ Bell Youinvest': 135.0,
#  'AJ Blue Icon Pack': 4.0,
#  'AJ Cam': 44.0,
#  'AJ Concept Group App': 0.0,
#  'AJ Gray Dark Icon Pack': 2.0,
#  'AJ Gray Icon Pack': 5.0,
#  'AJ Jump: Animal Jam Kangaroos!': 2975.0,
#  "AJ Men's Grooming": 2.0,
#  'AJ Nails Supply': 1.0,
#  'AJ Official': 31.0,
#  'AJ Orange Icon Pack': 0.0,
#  'AJ Percent Off Calculator': 134.0,
#  'AJ Player': 18.0,
#  'AJ RETAILS': 9.0,
#  'AJ Rafael Music Lessons': 1.0,
#  'AJ Rafael Music Lyrics': 0.0,
#  'AJ Reminders': 0.0,
#  'AJ Styles HD Wallpapers': 48.0,
#  'AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper': 18.0,
#  'AJ Tracey Music and Lyrics': 0.0,
#  'AJ Turquoise Dark Icon Pack': 0.0,
#  'AJ Wallpapers': 0.0,
#  'AJ and Alyssa': 0.0,
#  'AJ+ Beta': 0.0,
#  'AJ-COMICS': 0.0,
#  'AJ렌터카 법인 카셰어링': 0.0,
#  'AK 47 Assault Rifle Wallpapers': 1.0,
#  'AK 47 Guns Wallpaper': 322.0,
#  'AK 47 Live Wallpaper': 585.0,
#  'AK 47 Lock Screen': 5.0,
#  'AK Blackjack': 4.0,
#  'AK Booster': 71.0,
#  'AK Interactive': 734.0,
#  'AK Lodi Films': 23.0,
#  'AK Math Coach': 283.0,
#  'AK Phone': 9.0,
#  'AK-47 3D': 91.0,
#  'AK-47 Assault Rifle': 165.0,
#  'AK-47 Assult Rifle: Gun Shooting Simulator Game': 1.0,
#  'AK-47 Simulation and Info': 2.0,
#  'AK-47 Sounds': 656.0,
#  'AK-47 guns Sounds': 2.0,
#  'AK-47 sounds': 7.0,
#  'AK-47: Simulator and Shooting': 345.0,
#  'AK47 Assault Rifle': 54.0,
#  'AKASO DV': 99.0,
#  'AL Voice Recorder': 4832.0,
#  'AL.com': 803.0,
#  'AL.com: Alabama Football News': 459.0,
#  'ALL-IN-ONE PACKAGE TRACKING': 167406.0,
#  'ALPHA - Artificial Intelligence': 51.0,
#  'AMBW Dating App: Asian Men Black Women Interracial': 2.0,
#  'AMC': 20843.0,
#  'AMC Theatres': 44550.0,
#  'AMM Events & CPD': 5.0,
#  'AND CO': 175.0,
#  'AO Player': 9.0,
#  'AO Surgery Reference': 2570.0,
#  'AO-EVENT': 0.0,
#  'AO/OTA Fracture Classification': 25.0,
#  'AOL - News, Mail & Video': 62465.0,
#  'AP App for Android™': 188.0,
#  'AP Art History Flashcards': 1.0,
#  'AP Biology Prep: Practice Tests, Flashcards': 87.0,
#  'AP Biology Study Guide + Quiz': 105.0,
#  'AP Calculus BC Practice Test': 4.0,
#  'AP Calculus BC: Practice Tests and Flashcards': 5.0,
#  'AP Chemistry Prep: Practice Tests and Flashcards': 55.0,
#  'AP ENPS Mobile': 22.0,
#  'AP English Language: Practice Tests and Flashcards': 19.0,
#  'AP European History: Practice Tests and Flashcards': 7.0,
#  'AP Flashcards': 88.0,
#  'AP Government Review': 3.0,
#  'AP Installer': 23.0,
#  'AP Manager': 177.0,
#  'AP Math & Computer Science': 37.0,
#  'AP Mobile': 117.0,
#  'AP Mobile - Breaking News': 76616.0,
#  'AP Mobile 104': 0.0,
#  'AP Physics 1 Prep: Practice Tests and Flashcards': 29.0,
#  'AP Planner': 45.0,
#  'AP Psychology Prep: Practice Tests and Flashcards': 242.0,
#  'AP Series Solution Pro': 0.0,
#  'AP Stamps and Registration': 82.0,
#  'AP Statistics Prep: Practice Tests and Flashcards': 19.0,
#  'AP Themes for Kustom/KLWP': 5.0,
#  'AP World History: Practice Tests and Flashcards': 21.0,
#  'APE Weather ( Live Forecast)': 20008.0,
#  'APN Settings': 3743.0,
#  'APOEL FC': 688.0,
#  'APUS Booster - Space Cleaner & Booster': 1048766.0,
#  'APUS File Manager (Explorer)': 498894.0,
#  'APUS Launcher - Theme, Wallpaper, Hide Apps': 5783441.0,
#  'APagri CD': 5.0,
#  'AP® Guide': 3.0,
#  'AQ Aspergers Test': 265.0,
#  'AQ Coach': 0.0,
#  'AQ Dentals': 0.0,
#  'AQ Guards': 0.0,
#  'AQ Math Facts': 1.0,
#  'AQ Ria Retail': 4.0,
#  'AQ SMS Notify': 0.0,
#  'AQ Service': 4.0,
#  'AQ wisdom +': 0.0,
#  'AQ: First Contact': 0.0,
#  'AR Dragon Pet': 0.0,
#  'AR Remote Car': 1354.0,
#  'AR Sport Cars': 284.0,
#  'AR Tank Battle': 153.0,
#  'AR Toybox - Augmented Reality Demos': 20.0,
#  'AR Toys: Playground Sandbox | Remote Car': 153.0,
#  'AR effect': 79792.0,
#  'ARK: Survival Evolved': 51523.0,
#  'ARY NEWS': 2959.0,
#  'ARY NEWS URDU': 1071.0,
#  'ARuler - AR Ruler app, Measure tools': 1602.0,
#  'AS - Diario online deportivo. Fútbol, motor y más': 0.0,
#  'AS - News and sports results.': 20879.0,
#  'AS Guía de las Ligas 2017-2018': 4374.0,
#  'ASCCP Mobile': 63.0,
#  'ASCP® CG Exam Flashcards 2018': 0.0,
#  'ASOS': 181823.0,
#  'ASRA Coags': 15.0,
#  'ASUS Calling Screen': 102451.0,
#  'ASUS Cover for ZenFone 2': 43960.0,
#  'ASUS Gallery': 125259.0,
#  'ASUS PixelMaster Camera': 626366.0,
#  'ASUS Quick Memo': 23089.0,
#  'ASUS Sound Recorder': 34126.0,
#  'ASUS SuperNote': 26559.0,
#  'AT&T Call Protect': 6454.0,
#  'AT&T Digital Life': 10067.0,
#  'AT&T DriveMode': 8465.0,
#  'AT&T FamilyMap®': 21592.0,
#  'AT&T Messages for Tablet': 3044.0,
#  'AT&T Mobile Transfer': 22775.0,
#  'AT&T Navigator: Maps, Traffic': 32862.0,
#  'AT&T Smart Limits℠': 2300.0,
#  'AT&T Smart Wi-Fi': 18513.0,
#  'AT&T THANKS®': 2445.0,
#  'AT&T U-verse': 38606.0,
#  'AT&T Visual Voicemail': 13761.0,
#  'ATC Unico BS': 10.0,
#  'ATI Cargoes and Transportation': 4162.0,
#  'AU Call Blocker - Block Unwanted Calls Texts 2018': 16.0,
#  'AU Mobile Indonesia': 16521.0,
#  'AU Results - AU COE Corner': 664.0,
#  'AU Results 2017 Auzone': 762.0,
#  'AU Spark': 681.0,
#  'AU Students Zone (Result 2016)': 97.0,
#  "AV Anthony's": 0.0,
#  'AV Buddy Free': 25.0,
#  'AV HD Video Player': 6.0,
#  'AV High School District': 91.0,
#  'AV MAX': 9.0,
#  'AV Phone': 4.0,
#  'AV Phonetics': 259.0,
#  'AV Pro Voice Changer': 174.0,
#  'AV Tools': 631.0,
#  'AV Tools Pro': 35.0,
#  'AV-IPTV': 43.0,
#  'AVG AntiVirus 2018 for Android Security': 6207063.0,
#  'AVG Cleaner – Speed, Battery & Memory Booster': 1188154.0,
#  'AW': 0.0,
#  'AW - Le News di AndroidWorld': 2808.0,
#  'AW - free video calls and chat': 7317.0,
#  'AW Browser with Chrome Custom Tabs': 9.0,
#  'AW CAMERA': 2.0,
#  'AW Connect': 0.0,
#  'AW Radio': 1.0,
#  'AW Reader: news & apps [Dutch]': 1948.0,
#  'AW Screen Recorder No Root': 1659.0,
#  'AW TeamUp': 9.0,
#  'AW Toolbox': 3.0,
#  'AW Tozer Devotionals - Daily': 8.0,
#  'AW Training': 11.0,
#  'AX Battery Saver': 4546.0,
#  'AX Player -Nougat Video Player': 15765.0,
#  'AX Selfie': 10.0,
#  'AX Timesheets App for Dynamics': 0.0,
#  'AX Video Player': 569.0,
#  'AX Watch for WatchMaker': 2.0,
#  'AX Window': 0.0,
#  'AX!OM': 5.0,
#  'AX-PIC Pedidos': 1.0,
#  'AXE.IO - Brutal Survival Battleground': 3845.0,
#  'AY EMLAK': 8.0,
#  'AY Oakmont': 0.0,
#  'AY Recorder - Screen Recorder, Live, Video Editor': 12.0,
#  'AY Recruitment': 1.0,
#  'AY Sing': 111.0,
#  'AZ Browser. Private & Download': 1520.0,
#  'AZ Camera - Manual Pro Cam': 2332.0,
#  'AZ Immune Related AEManagement': 3.0,
#  'AZ Lottery Players Club': 97.0,
#  'AZ Mobile Gizmo': 16.0,
#  'AZ PLAYER HD': 24.0,
#  'AZ Plugin 2 (newest)': 11087.0,
#  'AZ Practice Test & Questions': 13.0,
#  'AZ REMOTE CONTROL': 149.0,
#  'AZ Rockets': 162.0,
#  'AZ Screen Recorder - No Root': 751911.0,
#  'AZ Screen Recorder pro': 60.0,
#  'Aab e Hayat Full Novel': 1476.0,
#  'Aaj Bangla: ei samay er khobor': 34.0,
#  'Ab Workouts': 27501.0,
#  'Ab Workouts - Ab Generator': 21.0,
#  'Abdominal CT Sectional Walker': 2.0,
#  'Ability DS UNO': 3.0,
#  'Abs Training-Burn belly fat': 2071.0,
#  'Abs Workout - 30 Days Fitness App for Six Pack Abs': 299.0,
#  'Abs Workout - Burn Belly Fat with No Equipment': 69279.0,
#  'Abs workout - 21 Day Fitness Challenge': 18604.0,
#  'Abs workout 7 minutes': 37224.0,
#  'Abs, Core & Back Workout Challenge': 3908.0,
#  'Absolute RC Heli Simulator': 654.0,
#  'Ac remote control': 822.0,
#  'AcDisplay': 66473.0,
#  'Access Point Browser': 25.0,
#  'Access Point Finder': 22.0,
#  'Access Point Names': 138.0,
#  'Access Point Proximity': 5.0,
#  'Account Class-11 Solutions (D K Goel)': 663.0,
#  'Account Class-12 Solutions (D K Goel) Vol-1': 708.0,
#  'Account Class-12 Solutions (D K Goel) Vol-2': 124.0,
#  'Account Manager': 76604.0,
#  'Accounting App - Zoho Books': 3079.0,
#  'Accounting Quiz (AQ) Malaysia': 25.0,
#  'AccuWeather: Daily Forecast & Live Weather Reports': 2052407.0,
#  'Ace Screen Recorder w facecam': 2447.0,
#  'Acorn TV: World-class TV from Britain and Beyond': 493.0,
#  'Acorns - Invest Spare Change': 45962.0,
#  'Across Age DX': 5964.0,
#  'ActionDirector Video Editor - Edit Videos Fast': 74531.0,
#  'Active Soccer 2 DX': 28.0,
#  'Acupuncture Assistant': 492.0,
#  'Ad Block REMOVER - NEED ROOT': 999.0,
#  'Ad Blocker Turbo - Adblocker Browser': 107.0,
#  'Ad Blocker for SayHi': 4.0,
#  'Ad Detect Plugin - Handy Tool': 5107.0,
#  'Ad Detector': 208.0,
#  'Ad Removal: thereisonlywe': 16.0,
#  'Ad Remove Plugin for App2SD': 66.0,
#  'Ad-free Triangle Solver': 118.0,
#  'AdClear Ad blocker for Samsung': 1586.0,
#  'AdWords Express': 7149.0,
#  'Ada - Your Health Guide': 87418.0,
#  'Adblock Browser for Android': 121113.0,
#  'Adblock Fast': 9914.0,
#  'Adblock Plus for Samsung Internet - Browse safe.': 8769.0,
#  'Add Text To Photo': 21578.0,
#  'Add Watermark Free': 18325.0,
#  'Add-On: Alcatel (h)': 107.0,
#  'Add-On: bq (a)': 26.0,
#  'Add-On: bq (b)': 9.0,
#  'Add-On: bq (c)': 17.0,
#  'Adguard Content Blocker': 14491.0,
#  'Adhenarcos - Coupe Adhemar EY 2018': 0.0,
#  'Adivina el Emoji': 2536.0,
#  'Adivina el cantante de Trap y Reggaeton': 1914.0,
#  'Adobe Acrobat Reader': 3014548.0,
#  'Adobe Fill & Sign: Easy PDF Form Filler': 11402.0,
#  'Adobe Illustrator Draw': 65766.0,
#  'Adobe Photoshop Express:Photo Editor Collage Maker': 914917.0,
#  'Adobe Photoshop Fix': 28390.0,
#  'Adobe Premiere Clip': 39495.0,
#  'Adult Color By Number Book: Number Coloring Pages': 2231.0,
#  'Adult Color by Number Book - Paint Mandala Pages': 997.0,
#  'Adult Dating - AdultFinder': 1601.0,
#  'Adult Dirty Emojis': 80.0,
#  'Adult Glitter Color by Number Book - Sandbox Pages': 8918.0,
#  'Advanced Comprehension Therapy': 3.0,
#  'Advanced Download Manager': 569727.0,
#  'Advanced Download Manager Holo': 16192.0,
#  'Advanced Download Manager Pro': 6505.0,
#  'Advanced EX for FIAT': 138.0,
#  'Advanced EX for HYUNDAI': 168.0,
#  'Advanced EX for KIA': 257.0,
#  'Advanced EX for MITSUBISHI': 33.0,
#  'Advanced EX for NISSAN': 164.0,
#  'Advanced EX for RENAULT': 130.0,
#  'Advanced Task Killer': 577059.0,
#  'Advanced Warfare Guns': 2079.0,
#  'Advanced calculator fx 991 es plus & 991 ms plus': 7252.0,
#  'Adventure Quest World Mobile Quiz': 28.0,
#  'Adventure Time Game Wizard': 4107.0,
#  'Adventure Time Run': 24628.0,
#  'Adventure Xpress': 24775.0,
#  'AdventureQuest 3D MMO': 22667.0,
#  'AdventureQuest Dragons': 10114.0,
#  'Ae Allah na Dai (Rasa)': 263.0,
#  'Aegis BT': 16.0,
#  'AfreecaTV': 381023.0,
#  'AfterFocus': 165224.0,
#  'Afterlight': 50893.0,
#  'Ag Across America': 0.0,
#  'Ag Guardian': 1.0,
#  'Ag PhD Deficiencies': 20.0,
#  'Ag PhD Field Guide': 114.0,
#  'Ag PhD Planting Population Calculator': 0.0,
#  'Ag PhD Soils': 3.0,
#  'Ag PhD Soybean Diseases': 0.0,
#  'Ag Tools': 2.0,
#  'Ag Trucking Mobile App': 0.0,
#  'Ag Valley Cooperative': 6.0,
#  'Ag Weather Tools': 0.0,
#  'Ag-Power': 0.0,
#  'Ag-Pro Companies': 0.0,
#  'Agar.io': 3815614.0,
#  'Age Calculator': 24265.0,
#  'Age of AI: War Strategy': 71.0,
#  'Age of Conquest: N. America': 659.0,
#  'Age of Procreation DX': 1894.0,
#  'Agenda EF': 79.0,
#  'Agent HQ for The Division': 1060.0,
#  'Agoda – Hotel Booking Deals': 263525.0,
#  'Ah !': 3.0,
#  'Ah Bailar': 10.0,
#  'Ah Ha Block': 2.0,
#  'Ah! Bird': 1689.0,
#  'Ah! Coins': 256.0,
#  'Ah! Cutie': 536.0,
#  'Ah! Monster': 1998.0,
#  'Ai File Viewer': 66.0,
#  'Ai La Trieu Phu - ALTP Free': 776.0,
#  'Ai illustrator viewer': 486.0,
#  'Ai-Ball AV Recorder': 90.0,
#  'Ain Arabic Kids Alif Ba ta': 0.0,
#  'Air Conditioner Maintenance': 11.0,
#  'Air Traffic': 14110.0,
#  'Air Transat CinePlus B': 83.0,
#  'Air conditioner remote control': 29854.0,
#  'AirAsia': 98585.0,
#  'AirWatch Agent': 20973.0,
#  'AirWatch Inbox': 8346.0,
#  'Airbnb': 359560.0,
#  'Airplane Fly Hawaii': 83427.0,
#  'Airplane Pilot Car Transporter': 182363.0,
#  'Airport + Flight Tracker Radar': 6762.0,
#  'Airway Ex - Intubate. Anesthetize. Train.': 123.0,
#  'Aj Di Awaaz': 9.0,
#  'Aj. Vallbona': 0.0,
#  'Aj.Petra': 5.0,
#  'Ak Parti Yardım Toplama': 0.0,
#  'Ak-47 Wallpapers 2018': 7.0,
#  'Akinator': 1805398.0,
#  'Ako ay may lobo Pinoy Kid Song Offline': 0.0,
#  'Al Jazeera English': 24456.0,
#  'Al Mayadeen': 13620.0,
#  'Al Quran (Tafsir & by Word)': 57400.0,
#  'Al Quran : EAlim - Translations & MP3 Offline': 96419.0,
#  'Al Quran Al karim': 41608.0,
#  'Al Quran Audio (Full 30 Juz)': 7878.0,
#  'Al Quran Free - القرآن (Islam)': 1777.0,
#  'Al Quran Indonesia': 445756.0,
#  'Al Quran MP3 - Quran Reading®': 47463.0,
#  'Al jazeera TV': 9952.0,
#  "Al'Quran Bahasa Indonesia": 361780.0,
#  "Al'Quran Bahasa Indonesia PRO": 1340.0,
#  'Al-Moazin Lite (Prayer Times)': 284670.0,
#  'Al-Muhaffiz': 2319.0,
#  'Al-Quran (Free)': 218451.0,
#  'Al-Quran 30 Juz free copies': 12322.0,
#  'Al-Quran Ahmad Saud Offline': 7116.0,
#  'Al-Quran Al-Muallim': 199.0,
#  'AlReader -any text book reader': 90468.0,
#  'Alabama Ag Credit Ag Banking': 0.0,
#  'Alabama DMV Permit Test - AL': 218.0,
#  'Alabama Gameday Live': 19.0,
#  'Alabama Road Trips': 71.0,
#  'Alachua County Sheriff FL': 5.0,
#  'Alarm Clock': 114788.0,
#  'Alarm Clock Free': 59973.0,
#  'Alarm Clock Plus★': 155693.0,
#  'Alarm Clock: Stopwatch & Timer': 870928.0,
#  'Alarm.fo – choose your info': 19.0,
#  'Alarmy (Sleep If U Can) - Pro': 10249.0,
#  'Alba Heaven - Alvarez Job Portal Services': 8941.0,
#  'Alchemy Classic Ad Free': 20178.0,
#  'Aldiko Book Reader': 210534.0,
#  'Alerte au gogol': 14.0,
#  'Alex & Co Quiz': 9.0,
#  'Alex Fuel Calculator for EK': 19.0,
#  'Alfa-Bank (Alfa-Bank)': 44545.0,
#  'Alfred Home Security Camera': 103305.0,
#  "Ali Baba's Farm Tutorial Kids Games": 36.0,
#  'AliExpress - Smarter Shopping, Better Living': 5911055.0,
#  'Alif Ba Ta Bullseye': 1.0,
#  'Alif Ba Ta Song - Arabic Kids': 227.0,
#  'Alipay': 42497.0,
#  'Alizay, pirate girl': 197.0,
#  'All AJK Board Matric Fa Fsc Results': 0.0,
#  'All C Programs': 2387.0,
#  'All Email Providers': 20901.0,
#  'All Events in City': 3782.0,
#  'All Football - Latest News & Videos': 152653.0,
#  'All Football GO- Live Score, Games': 1981.0,
#  'All Info about Cg': 15.0,
#  'All Language Translator': 29944.0,
#  'All Language Translator Free': 30105.0,
#  'All Maths Formulas': 2709.0,
#  'All Mental disorders': 453.0,
#  'All Social Networks': 22650.0,
#  'All Star Of CW': 0.0,
#  'All States Ag Parts': 68.0,
#  'All Type Ac Repair & Services': 45.0,
#  'All Type DP': 1853.0,
#  'All Types DP & Status Maker': 16.0,
#  'All Video Downloader': 165723.0,
#  'All Video Downloader 2018': 7557.0,
#  'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)': 1754.0,
#  'All-In-One Toolbox: Cleaner, Booster, App Manager': 536926.0,
#  'All-in-One Mahjong 3': 38.0,
#  'All-in-One Mahjong 3 FREE': 566.0,
#  'All-night drugstore CI & Price': 0.0,
#  'AllTrails: Hiking, Running & Mountain Bike Trails': 16943.0,
#  'Allegiant': 5572.0,
#  'Allrecipes Dinner Spinner': 61881.0,
#  'Allsetra B.V.': 15.0,
#  'Alopec - Online Shipping System': 1240.0,
#  'Alpha Bank CY': 39.0,
#  'Alphabet "H" Passcode Lock Screen': 2.0,
#  'Alphabet A-Z': 306.0,
#  'Alt-C': 499.0,
#  "Alto's Adventure": 515240.0,
#  'Alumni BJ': 2.0,
#  'Alzashop.com': 32014.0,
#  'Amadeus GR & CY': 4.0,
#  'Amazing CG Backgrounds': 34.0,
#  'Amazing Fart Sounds': 28136.0,
#  'Amazon Drive': 18669.0,
#  'Amazon FreeTime – Kids’ Videos, Books, & TV shows': 2715.0,
#  'Amazon Kindle': 814151.0,
#  'Amazon Prime Video': 411683.0,
#  'Amazon Shopping': 908525.0,
#  'Amazon for Tablets': 141584.0,
#  'Amber Weather': 260137.0,
#  'Ambient CX': 0.0,
#  'Ambulance Rescue Simulator 17': 6669.0,
#  'Ambulance Simulator 3D': 29415.0,
#  'American Airlines': 16973.0,
#  'American Girls Mobile Numbers': 5.0,
#  'American Muscle Car Race': 129.0,
#  'American Sniper City Fight Shooting Assassin': 395.0,
#  'Amex Mobile': 24729.0,
#  'Amino: Communities and Chats': 1264084.0,
#  'Amleen Ey': 0.0,
#  'Amtrak': 16815.0,
#  'An Elite Warrior Ex': 15.0,
#  'Analog BW - Camera filter effect foto film retouch': 2.0,
#  'Analog Clock AW Plus-7': 725.0,
#  'Analog Clock AW-7': 2158.0,
#  'Analog Clock AW-7 PRO': 40.0,
#  'Analog and Digital Clock AW-7': 202.0,
#  'Analog and Digital Clock AW-7PRO': 4.0,
#  'Anatomy & Physiology Vocabulary Exam Review App': 1.0,
#  'Anatomy Learning - 3D Atlas': 72167.0,
#  'AnatomyMapp': 80.0,
#  'Ancestry': 64513.0,
#  'AndStream - Streaming Download': 38607.0,
#  'AndroZip™ FREE File Manager': 277794.0,
#  'Android Auto - Maps, Media, Messaging & Voice': 271920.0,
#  'Android Messages': 781810.0,
#  'Android P 9.0': 12.0,
#  'Android P Home KLWP': 0.0,
#  'Android P Launcher 9.0 launcher': 164.0,
#  'Android P Rotation': 502.0,
#  'Android P Stock Wallpapers': 16.0,
#  'Android P Style Icon Pack': 1.0,
#  'Android P Wallpapers': 53.0,
#  'Android P | Xperia™ Theme 4800+ icons': 29.0,
#  'Android TV Remote Service': 1.0,
#  'Android-P Mono Grey EMUI 8/5 Theme': 61.0,
#  'Angelcare AH': 0.0,
#  'Angelo Rules - Crazy day': 108336.0,
#  'Anger of stick 5 : zombie': 547644.0,
#  'Angry Birds 2': 3881752.0,
#  'Angry Birds Blast': 253115.0,
#  'Angry Birds Classic': 5565856.0,
#  'Angry Birds Epic RPG': 2634605.0,
#  'Angry Birds Evolution': 384602.0,
#  'Angry Birds Friends': 829753.0,
#  'Angry Birds Go!': 3846378.0,
#  'Angry Birds Match': 227401.0,
#  'Angry Birds POP Bubble Shooter': 596628.0,
#  'Angry Birds Rio': 2610328.0,
#  'Angry Birds Space HD': 43645.0,
#  'Angry Birds Star Wars': 1218055.0,
#  'Angry Shark 2016': 73185.0,
#  'Animal Hunting: Sniper Shooting': 0.0,
#  'Animal Jam - Play Wild!': 361734.0,
#  'Animal Planet GO': 2442.0,
#  'Animated Photo Editor': 203.0,
#  'Anime Avatar Creator: Make Your Own Avatar': 10944.0,
#  'Anime Expo 2018': 54.0,
#  'Anime Love Story Games: ✨Shadowtime✨': 198480.0,
#  'Anime Manga Coloring Book': 5035.0,
#  'Anime Mod for BM': 0.0,
#  'Anime X Wallpaper': 32613.0,
#  'Anime et Manga Amino en Français': 3782.0,
#  'Ankle Surgery ER Emergency': 10449.0,
#  'Anna.K Tarot': 17.0,
#  'Anno: Build an Empire': 33944.0,
#  'Annonces.ci': 14.0,
#  'Anonymous caller detection': 161.0,
#  'Ant Smasher by Best Cool & Fun Games': 1185148.0,
#  'Antenna Tool': 522.0,
#  'Antenna Tool Premium': 14.0,
#  'AntennaPict β': 15439.0,
#  'Anthem Anywhere': 2657.0,
#  'Anthem BC Anywhere': 496.0,
#  'Anti Adware': 18751.0,
#  'Anti Mosquito simulation': 74.0,
#  'Anti-virus Dr.Web Light': 1094094.0,
#  'Antillean Gold Telegram (original version)': 2939.0,
#  'Antivirus & Mobile Security': 351267.0,
#  'Any.do: To-do list, Calendar, Reminders & Planner': 298854.0,
#  'Ao Oni2': 21223.0,
#  'Ap Video Downloader for fb New 2018': 676.0,
#  'Apartment Decorating Ideas': 1478.0,
#  'Apartment List: Housing, Apt, and Property Rentals': 8481.0,
#  'Apartment, Home Rental Search: Realtor.com Rentals': 10117.0,
#  'Apartments & Rentals - Zillow': 27387.0,
#  'Apartments.com Rental Search': 22584.0,
#  'Apex Launcher': 266434.0,
#  'Apk Installer': 7750.0,
#  'App Lock: Locker w/ fingerprint, Parental Control': 37607.0,
#  'App Seguridad AV Villas': 251.0,
#  'App for Craigslist Pro - Buy & Sell Postings': 707.0,
#  'App vault': 25094.0,
#  'AppBrain Ad Detector': 9221.0,
#  'AppClose - The #1 FREE Co-Parenting App': 159.0,
#  'AppFinder by AppTap': 2221.0,
#  'AppLock': 4931562.0,
#  'AppLock - Fingerprint': 745245.0,
#  'AppLock - Fingerprint Unlock': 112482.0,
#  'Apple Daily Apple News': 41490.0,
#  'Applock': 4934130.0,
#  'Apps Ads Detector': 315.0,
#  'Apps for SportsBєtting.ag - Bitcoin Welcome here!': 0.0,
#  'Aproveita DF': 0.0,
#  'Aquarium Co-Op Podcast': 206.0,
#  'Aqw&3d Design Notes Manager': 11.0,
#  'Arab Halls - For Wedding & Events': 28.0,
#  'Arabic Alif Ba Ta For Kids': 226.0,
#  'Arabic Alphabet Alif Ba Ta Wooden Blocks': 66.0,
#  'Arabic Alphabets': 34.0,
#  'Arabic Chat - Chat': 162.0,
#  "Arby's": 194.0,
#  'Archery Physics Objects Destruction Apple shooter': 6026.0,
#  'Archie Comics': 5084.0,
#  'Archos File Manager': 2131.0,
#  'Arcraft - AR Sandbox': 469.0,
#  'Arena of Valor: 5v5 Arena Game': 438911.0,
#  'Ariana News AF': 20.0,
#  'Arizona DMV Permit Test - AZ': 109.0,
#  'Arizona Mobile': 285.0,
#  'Arizona Statutes, ARS (AZ Law)': 9.0,
#  'Arizona Trail': 65.0,
#  'Armani Exchange Connected': 305.0,
#  'Armed Cam Gun Pack': 1012.0,
#  'Armored Warfare: Assault': 7718.0,
#  'Army of Heroes': 85015.0,
#  'Arogyam EH': 18.0,
#  'Arrayanes EC': 2.0,
#  'Arrhythmias and Dysrhythmias': 3.0,
#  'Arrow.io': 343263.0,
#  'Arrowhead AH App': 3.0,
#  'Art Drawing Ideas': 227.0,
#  'Art Pixel Coloring. Color by Number.': 992.0,
#  'Art of F J Taylor': 2.0,
#  'Artificial Intelligence': 339.0,
#  'Artificial intelligence': 3.0,
#  'Arto: f.infrared photo': 41.0,
#  'Asahi Shimbun Digital': 735.0,
#  'Asana: organize team projects': 20815.0,
#  'Ascape VR: 360° Virtual Travel': 890.0,
#  'Asha Ek Hope - ALS/ MND': 2.0,
#  'Asiimov Skin - CS GO Icon Pack': 26.0,
#  'Asphalt 8: Airborne': 8389714.0,
#  'Asphalt Xtreme: Rally Racing': 567984.0,
#  "Assassin's Creed Identity": 42529.0,
#  'Assault Line CS Online Fps Go': 52163.0,
#  'Assemblr - Create 3D Models (Sandbox AR)': 1745.0,
#  'Associated Credit Union Mobile': 3290.0,
#  'Aster DM Healthcare': 32.0,
#  'Asteroids 3D live wallpaper': 157495.0,
#  'Asylum Night Shift - Five Nights Survival': 59223.0,
#  'At home - rental · real estate · room finding application such as apartment · apartment': 2496.0,
#  'Atlan3D Navigation: Korea navigator': 22063.0,
#  'Atlanta United FC': 215.0,
#  'Attack the Light': 19209.0,
#  'Au Bon Pain': 70.0,
#  'Au Mobile: Audition Chính Hiệu': 85278.0,
#  'Au Pair': 58.0,
#  'Au Pair Legend': 28.0,
#  'Au Rubis les bijoutiers': 0.0,
#  'Au Weather Free': 1185.0,
#  'Au-allstar for KR': 2433.0,
#  'Auction Wars : Storage King': 29062.0,
#  'Audio Murli Glossary For BK': 39.0,
#  'AudioBT: BT audio GPS/SMS/Text': 198.0,
#  'Audiobooks from Audible': 568922.0,
#  'Audiowalk EB': 0.0,
#  'Augment - 3D Augmented Reality': 25195.0,
#  'Aunjai i lert u': 1140.0,
#  'Aura Hair Group BC': 0.0,
#  'Aurum Blade EX': 28151.0,
#  'Australia Newspapers - AU News Apps': 48.0,
#  'Austria Wien FK - Fussball - Inoffizielle App': 2.0,
#  'Authy 2-Factor Authentication': 15070.0,
#  'Auto Background Changer': 35188.0,
#  'Auto DM for Twitter 🔥': 44.0,
#  'Auto Dslr Photo Effect : Auto Focus Effect': 6.0,
#  'AutoCAD - DWG Viewer & Editor': 145088.0,
#  'AutoScout24 - used car finder': 186648.0,
#  'AutoScout24 Switzerland – Find your new car': 13372.0,
#  'Automagic * Automation': 1947.0,
#  'Automatic Call Recorder': 1648515.0,
#  'Autool BT-BOX': 4.0,
#  'Autoroute.EU': 10.0,
#  'Avakin Life - 3D virtual world': 1275373.0,
#  'Avast Cleanup & Boost, Phone Cleaner, Optimizer': 648380.0,
#  'Avast Mobile Security 2018 - Antivirus & App Lock': 5180480.0,
#  'Avast Wi-Fi Finder': 37277.0,
#  'Avatar Musik': 159063.0,
#  'Avaya CX': 21.0,
#  'Avenger Legends': 3715.0,
#  'Aviary Effects: Classic': 67007.0,
#  'Aviary Stickers: Free Pack': 126862.0,
#  'Avios for Android': 862.0,
#  'Avokiddo Emotions': 73.0,
#  'Aw Restaurant': 4.0,
#  'Awake Dating': 2.0,
#  'Ax 3 Domaines': 12.0,
#  'Axe': 18.0,
#  'Axe Champ': 141.0,
#  'Axe Champ Hit': 1.0,
#  'Axe Champion': 21.0,
#  'Axe Champs! Wars': 8.0,
#  'Axe Clicker': 10446.0,
#  'Axe Knight': 52.0,
#  'Axe Man': 53.0,
#  'Axe Spinner': 2.0,
#  'Axe Throw: Flip Champ Axes Champion Throwing Games': 1.0,
#  'Axe Wallpaper': 9.0,
#  'Axetatic - Axe Throwing Game': 29.0,
#  'Axxess AX-DSP': 17.0,
#  'Axxess Updater': 56.0,
#  'Ay': 11.0,
#  'Ay Hasnain k Nana Milad Naat': 72.0,
#  'Ay Mohabbat Teri Khatir Novel': 27.0,
#  'Ay Peruk': 0.0,
#  'Ay Sabz Gunbad Waly': 4.0,
#  'Ay Telekom Oim': 6.0,
#  'Ay Up': 11.0,
#  'Ay Vamos - PJ. Balvin - Piano': 0.0,
#  'Ay Yıldız - Xperia Live Theme': 0.0,
#  'Ay Yıldız Analog Saat': 37.0,
#  'Ay Yıldız Duvar Kağıtları': 3.0,
#  'Ay Yıldız Keyboard': 26.0,
#  'Ayat - Al Quran': 173394.0,
#  'Ayyush wih wih new without Net': 912.0,
#  'Az Content': 24.0,
#  'Az Video Status': 13.0,
#  'AzadBazar.af': 3.0,
#  'Azar': 1092337.0,
#  'Azpen eReader': 156.0,
#  'Azulones Getafe CF Fans': 4.0,
#  'AÖF Ev İdaresi 1. Sınıf': 2.0,
#  'B': 800.0,
#  'B & W Filter for Photo Editor Pro': 65.0,
#  'B L Enterprises': 2.0,
#  'B R COACHINGS': 1.0,
#  'B R Telco FCU Mobile Banking': 413.0,
#  'B Tiff Viewer': 283.0,
#  'B y H Niños ES': 53.0,
#  'B&H Kids AR': 286.0,
#  'B&H Photo Video Pro Audio': 17180.0,
#  'B&M Stores': 192.0,
#  'B&W Photo Filter Editor': 205.0,
#  "B'H BURGER HEIM": 0.0,
#  'B-17 Flying Fortress WWII LWP': 7.0,
#  'B-52 Spirits of Glory Deluxe': 12.0,
#  'B-BLE(BLE4.0 Scan)': 159.0,
#  'B-Dubs®': 3042.0,
#  'B-Grade Renegade': 24.0,
#  'B-L Animal Hospital': 1.0,
#  'B-Messenger Video Chat': 12495.0,
#  'B. R. Ambedkar Jayanti SMS': 0.0,
#  'B.GOOD': 155.0,
#  'B.M.Snowboard Free': 9765.0,
#  'B.T.': 636.0,
#  'B.Z. Live-Ticker': 114.0,
#  'B612 - Beauty & Filter Camera': 5276983.0,
#  'B@dL!bs Lite': 10.0,
#  'BA 3 Banjarmasin': 2.0,
#  'BA Accesible': 31.0,
#  'BA Calculator': 22.0,
#  'BA Pro Financial Calculator': 36.0,
#  'BA SALES': 0.0,
#  'BA Status': 0.0,
#  'BA VPN - Free Unlimited VPN': 181.0,
#  'BA4You': 87.0,
#  'BAC DZ Questionnaire': 38.0,
#  'BAMMS for BM 1Park': 7.0,
#  'BAMMS for BM SQ': 2.0,
#  'BANGLA TV 3G/4G': 142.0,
#  'BAR-B-Q Recipes': 0.0,
#  'BBC Media Player': 87384.0,
#  'BBC News': 296781.0,
#  'BBC Persian | BBC Farsi News': 978.0,
#  'BBC Sport': 18679.0,
#  'BBM - Free Calls & Messages': 12843436.0,
#  'BBMoji - Your personalized BBM Stickers': 8827.0,
#  'BBVA Compass Banking': 5905.0,
#  'BBVA Spain': 36746.0,
#  'BBW Dating & Curvy Singles Chat- LargeFriends': 218.0,
#  'BBW Dating & Plus Size Chat': 12633.0,
#  'BBWCupid - BBW Dating App': 241.0,
#  'BC Camera': 5.0,
#  'BC Connect': 11.0,
#  'BC Highways - Road Conditions': 382.0,
#  'BC Hockey': 20.0,
#  'BC Hospital Wait Times': 8.0,
#  'BC Liquor Stores': 492.0,
#  'BC Lotto Check': 10.0,
#  'BC MVA Fines': 5.0,
#  'BC Mobile Intro - Americas': 0.0,
#  'BC Navigator': 21.0,
#  'BC Pizza': 3.0,
#  'BC Slots - The Lost Reels FREE': 209.0,
#  'BC Wildfire': 27.0,
#  'BC Wildflowers': 7.0,
#  'BC browser': 1.0,
#  'BC iptv player': 8.0,
#  "BC's Pizza": 113.0,
#  'BD All Results': 205.0,
#  'BD All Sim Offer': 197.0,
#  'BD Attendance': 93.0,
#  'BD Bank Interest': 289.0,
#  'BD Briight: Your Diabetes Personal Assistant': 17.0,
#  'BD CRICKET LIVE': 1238.0,
#  'BD Data Plan (3G & 4G)': 10341.0,
#  'BD Dialer': 29.0,
#  'BD Earn Pro': 540.0,
#  'BD Field Force': 41.0,
#  'BD Fishpedia': 123.0,
#  "BD Hospital's": 12.0,
#  'BD Internet Package Activator': 13.0,
#  'BD Internet Packages (Updated)': 474.0,
#  'BD Live Call': 7.0,
#  'BD Online News': 30.0,
#  'BD Online Passport Application': 12.0,
#  'BD Online Shop': 63.0,
#  'BD Provider App': 45.0,
#  'BD Radio TV Free List': 539.0,
#  'BD Simplist Through Their Eyes': 1.0,
#  'BD Sports Box & TV': 5.0,
#  'BD TYCOON': 16.0,
#  'BD tools': 21.0,
#  'BDCast - Bangla Live TV,Radio': 7461.0,
#  'BEBONCOOL GAMEPAD V1.0': 404.0,
#  'BELONG Beating Cancer Together': 623.0,
#  'BEST CAR SOUNDS': 348.0,
#  'BET NOW - Watch Shows': 14807.0,
#  'BEYBLADE BURST app': 216849.0,
#  'BF 3d Images': 19.0,
#  'BF 3d View Wallpapers': 4.0,
#  'BF 3d Wallpapers': 256.0,
#  'BF 4 Guns': 1542.0,
#  'BF Abstract 3d Pictures': 72.0,
#  'BF Beautiful Nature': 5.0,
#  'BF Browser by Betfilter - Stop Gambling Today!': 39.0,
#  'BF CG Abstract Pictures': 6.0,
#  'BF CG View Wallpapers': 13.0,
#  'BF Combat: Genesis': 3322.0,
#  'BF Family user': 8.0,
#  'BF Frontline City': 29798.0,
#  'BF Movies Fun': 63.0,
#  'BF Scale Health Fitness Tool': 19.0,
#  'BF at Sea Refueled': 1849.0,
#  'BF games': 262.0,
#  'BF-Calc': 428.0,
#  'BG Advisor™': 7.0,
#  'BG BRIDAL GALLERY': 17.0,
#  'BG Blurry HD Wallpapers': 1.0,
#  'BG Burger': 1.0,
#  'BG Cable TV': 5.0,
#  'BG Cricket': 6.0,
#  'BG Editor': 0.0,
#  'BG Future School': 16.0,
#  'BG Guide': 3.0,
#  'BG LINKED (BGLINKED)': 22.0,
#  'BG MUSIC PLAYER - MUSIC PLAYER': 0.0,
#  'BG Metro - Red voznje': 89.0,
#  'BG Middle East': 1.0,
#  'BG Monitor Diabetes': 643.0,
#  'BG Monitor Diabetes Pro': 87.0,
#  'BG Products': 4.0,
#  'BG Remover & Eraser Pro': 4.0,
#  'BG Score': 64.0,
#  'BG Sports News': 41.0,
#  'BG TV App': 6.0,
#  'BG TV Program': 1.0,
#  'BG TV Stations': 0.0,
#  'BG Television': 3.0,
#  'BG Torneos': 7.0,
#  'BG video - floating video - background video': 64.0,
#  'BG+Phone Backup': 16.0,
#  'BG-FLEET': 0.0,
#  'BGCN TV': 4334.0,
#  'BGKontakti Bayern BG Kontakti': 32.0,
#  'BGKontakti London BG Kontakti': 4.0,
#  'BGKontakti Vienna BG Kontakti': 111.0,
#  'BH - Fitness & Nutrition': 0.0,
#  'BH Açaí': 3.0,
#  'BH Bikes GPS Locator': 0.0,
#  'BH Bikes Premium': 26.0,
#  'BH Challenge - Museum of the Jewish People': 12.0,
#  'BH Connect': 0.0,
#  'BH Cosmetics': 2.0,
#  'BH INVEST': 7.0,
#  'BH Mail': 7.0,
#  'BH Mission Playbook': 0.0,
#  'BH Online': 0.0,
#  'BH Patrole': 27.0,
#  'BH Recepti': 3.0,
#  'BH Rocking': 13.0,
#  'BH Táxi': 91.0,
#  'BH by Kinomap': 141.0,
#  'BI APP': 2.0,
#  'BI Barcode Scanner': 0.0,
#  'BI Mobile': 337.0,
#  'BI Mobile Banking': 180.0,
#  'BI News': 22.0,
#  'BI Office': 76.0,
#  'BI SmartLINK': 16.0,
#  'BI-LO': 43.0,
#  'BI-LO Rx': 77.0,
#  'BIG Launcher': 881.0,
#  'BIGO LIVE - Live Stream': 2349421.0,
#  'BJ & Jamie': 13.0,
#  'BJ - Confidential': 0.0,
#  'BJ Adams': 1.0,
#  'BJ Bridge Acol Beginner 2018': 11.0,
#  'BJ Bridge Free (2018)': 20.0,
#  'BJ Bridge Pro 2018': 17.0,
#  'BJ Bridge Standard American 2018': 1.0,
#  'BJ Foods': 3.0,
#  'BJ Grand Salon Mobile App': 1.0,
#  'BJ Memo Widget': 616.0,
#  'BJ Strategy Tester': 1.0,
#  'BJ TIKET': 3.0,
#  'BJ Toys': 55.0,
#  'BJ card game blackjack': 3.0,
#  "BJ's Bingo & Gaming Casino": 501.0,
#  "BJ's Community SoundBoard": 0.0,
#  "BJ's Express Scan": 69.0,
#  "BJ's Wholesale Club": 4099.0,
#  'BJ-DRONE': 1.0,
#  'BJ-FPV': 16.0,
#  'BJ-UFO': 226.0,
#  'BJJ Roadmap by Stephan Kesting': 969.0,
#  'BJ’s Mobile App': 4722.0,
#  'BK Arogyam Task Track': 8.0,
#  'BK Chat': 6.0,
#  'BK Dinos': 30.0,
#  'BK Formula Calculator': 6.0,
#  'BK Formula Calculator 2': 4.0,
#  'BK Gold App': 4.0,
#  'BK Manager': 19.0,
#  'BK Murli Dictionary (H to E)': 106.0,
#  'BK Murli Offline April 2017': 33.0,
#  'BK News Channel': 277.0,
#  'BK Photography': 20.0,
#  'BK Shivani Videos': 29.0,
#  'BK Suraj bhai': 9.0,
#  'BK Traffic Control cum Chart': 549.0,
#  'BK Travel Solutions': 1.0,
#  'BK Video Status': 13.0,
#  'BK murli today (Mobile Murli) - Gyan': 100.0,
#  'BL 1-Click Camera': 4.0,
#  'BL 1-Click Camera - Free': 52.0,
#  'BL Banking DES': 3.0,
#  'BL Carrier': 0.0,
#  'BL Community Icon Pack': 289.0,
#  'BL Driver': 230.0,
#  'BL Essentials BW Icon Pack': 17.0,
#  'BL File Explorer': 1.0,
#  'BL Flowers Digital': 21.0,
#  'BL Holo Theme': 18.0,
#  'BL IP-Camera': 15.0,
#  'BL Kennedy Theme': 279.0,
#  'BL Mobile Banking': 23.0,
#  'BL ONLINE PERSONAL TRAINING': 0.0,
#  'BL Portfolio': 4.0,
#  'BL PowerPoint Remote': 33.0,
#  'BL Taxi': 124.0,
#  'BL info': 98.0,
#  'BL 女性向け恋愛ゲーム◆ごくメン': 1901.0,
#  'BL 女性向け恋愛ゲーム◆俺プリクロス': 3379.0,
#  'BL!TZ - Endless': 21.0,
#  'BL-ED: From BLUE to RED': 3.0,
#  'BLACKJACK!': 524467.0,
#  'BLK - Swipe. Match. Chat.': 2067.0,
#  'BLOOD & GLORY: IMMORTALS': 101762.0,
#  'BM Assets': 6.0,
#  'BM Box': 28.0,
#  'BM CRM': 0.0,
#  'BM FlexCheck': 2.0,
#  'BM Interventi': 2.0,
#  'BM Online OEC Verification': 783.0,
#  'BM Pharmacy': 42.0,
#  'BM Physiotherapy Clinic': 3.0,
#  'BM SPM Practice': 6.0,
#  'BM Tahmin: Ücretsiz İddaa Tahminleri': 7.0,
#  'BM Wallet': 798.0,
#  'BM speed test': 1.0,
#  'BMH-BJ Congregation': 0.0,
#  'BMX Boy': 839206.0,
#  'BMX Boy Bike Stunt Rider Game': 299.0,
#  'BN Bank Mobilbank': 72.0,
#  'BN DB1 App': 2.0,
#  'BN Habitat - Property Experts - Buy | Sell | Rent': 0.0,
#  'BN Inscript Improved Input keyboard': 0.0,
#  'BN Inscript Improved Keyboard': 0.0,
#  'BN MALLORCA Radio': 23.0,
#  'BN Mi Banco': 597.0,
#  'BN Más Cerca de Usted': 8185.0,
#  'BN PERKS™': 0.0,
#  'BN Pro Arial Legacy Text': 83.0,
#  'BN Pro ArialXL Legacy Text': 142.0,
#  'BN Pro ArialXL-b HD Text': 24.0,
#  'BN Pro ArialXL-b Neon HD Text': 66.0,
#  'BN Pro Battery Level-White': 21.0,
#  'BN Pro Black Text': 18.0,
#  'BN Pro Black Text on White': 53.0,
#  'BN Pro BlueICS HD Text': 174.0,
#  'BN Pro BlueICS-b HD Text': 78.0,
#  'BN Pro LcdD HD Text': 50.0,
#  'BN Pro LcdD Legacy Text': 71.0,
#  'BN Pro LcdD-b HD Text': 131.0,
#  'BN Pro Percent White HD Text': 45.0,
#  'BN Pro PercentXL-b Neon HD Txt': 45.0,
#  'BN Pro Play HD Text': 63.0,
#  'BN Pro Play-b HD Text': 34.0,
#  'BN Pro Roboto-b Neon HD Text': 30.0,
#  'BN Pro RobotoXL HD Text': 15.0,
#  'BN Pro RobotoXL-b HD Text': 86.0,
#  'BN Pro Solid Battery-White': 7.0,
#  'BN Pro White HD Text': 120.0,
#  'BN Pro White Text': 50.0,
#  'BN Whitening Shoppe Ph': 2.0,
#  'BNCR Token Celular': 913.0,
#  'BOO! - Next Generation Messenger': 20675.0,
#  'BP Assist': 0.0,
#  'BP Fitness Lead Scanner': 0.0,
#  'BP Journal - Blood Pressure Diary': 6.0,
#  'BP Log lite': 3.0,
#  'BP Scanner Prank': 157.0,
#  'BP Service': 0.0,
#  'BP Toolbox': 32.0,
#  'BP Tracker': 12.0,
#  'BP Tracker-Symptoms & Solution': 34.0,
#  'BP World Energy': 25.0,
#  'BP and Sugar Test Prank': 7808.0,
#  'BP-Tech': 12.0,
#  'BPme - Mobile Fuel Payment & BP Driver Rewards app': 69.0,
#  'BQ Camera': 2526.0,
#  'BQ Llicència': 18.0,
#  'BQ Partners': 0.0,
#  'BQ Scan': 18.0,
#  'BQ Scanner': 2.0,
#  'BQ Services': 5004.0,
#  'BQ Wings': 1.0,
#  'BQ-መጽሐፍ ቅዱሳዊ ጥያቄዎች': 191.0,
#  'BR': 859.0,
#  'BR Ambedkar Biography & Quotes': 156.0,
#  'BR Chat Bot': 16.0,
#  'BR Classified': 0.0,
#  'BR Series': 1016.0,
#  'BR Video Player': 46.0,
#  'BRL AG': 0.0,
#  'BROTHER IN WARS: GUNNER CITY WARLORDS': 8649.0,
#  'BS Battery+': 269.0,
#  'BS CS IT & SE': 9.0,
#  'BS Calendar / Patro / पात्रो': 218.0,
#  'BS Chopper': 0.0,
#  "BS Detector - Diss 'n' Gauges": 0.0,
#  'BS Films': 1.0,
#  'BS Generator': 5.0,
#  'BS MAPS': 6.0,
#  'BS Match Maker Premium': 3.0,
#  'BS Meter (Ad Supported)': 14.0,
#  'BS Play': 56.0,
#  'BS TRACK CLIENT': 0.0,
#  'BS Tractor': 3.0,
#  'BS Where Am I': 9.0,
#  'BS player remote': 54.0,
#  'BS-Mobile': 1.0,
#  'BSC IT': 847.0,
#  'BSPlayer': 4585.0,
#  'BSPlayer ARMv7 VFP CPU support': 9966.0,
#  'BSPlayer FREE': 138337.0,
#  'BSc Ag Entrance Preparation': 138.0,
#  'BT (Usage Interne)': 3.0,
#  'BT App': 24.0,
#  'BT Camera': 1307.0,
#  'BT Church': 26.0,
#  'BT Communicator': 32.0,
#  'BT Controller': 4374.0,
#  'BT Dating -Find your match, help cupid, be social': 158.0,
#  'BT Find Address for Bluetooth': 8.0,
#  'BT Master': 0.0,
#  'BT MeetMe with Dolby Voice': 437.0,
#  'BT Messenger': 97.0,
#  'BT Mobile': 22.0,
#  'BT Notifier': 2794.0,
#  'BT One Mobile secure access': 54.0,
#  'BT One Phone Mobile App': 33.0,
#  'BT One Voice anywhere': 80.0,
#  'BT One Voice mobile access': 32.0,
#  'BT Panorama': 34.0,
#  'BT Position Sender - Bluetooth Position Sender': 0.0,
#  'BT Remote (SPP) for Bluetooth': 36.0,
#  'BT Satmeter': 0.0,
#  'BT Share It': 12.0,
#  'BT Speed': 3.0,
#  'BTK-FH Online Campus': 1.0,
#  'BTNotification': 15665.0,
#  'BTS J-Hope Wallpaper HD for KPOP Fans': 4.0,
#  'BTS J-Hope Wallpaper KPOP Fans HD': 98.0,
#  'BTS V Kim Taehyung Wallpapers Kpop HD New': 51.0,
#  'BTS V LINE Launcher theme': 3283.0,
#  'BTS j-hope LINE Launcher theme': 934.0,
#  'BU Alsace': 3.0,
#  'BU Beauty Rooms': 1.0,
#  'BU Bison Nation': 4.0,
#  'BU Bookstore': 2.0,
#  'BU Bus Tracker': 57.0,
#  'BU Calculator': 69.0,
#  'BU Dental GoGoldman': 0.0,
#  'BU HANGİ ŞARKI ? - 2018': 4.0,
#  'BU Library': 4.0,
#  'BU Mobile': 472.0,
#  'BU Questrom Launch': 3.0,
#  'BU School of Public Health': 0.0,
#  "BU Students' Rep. Council": 38.0,
#  'BU Study': 7.0,
#  'BU Syllabus': 38.0,
#  'BURGER KING® App': 41747.0,
#  'BURGER KING® MOBILE APP': 19221.0,
#  'BURGER KING® Puerto Rico': 2448.0,
#  'BURST Professionals': 11.0,
#  'BV': 3.0,
#  'BV Aventure': 0.0,
#  'BV Bombers': 0.0,
#  'BV Forest': 0.0,
#  'BV Frankfurt inside': 3.0,
#  'BV Link': 10.0,
#  'BV MAAp': 9.0,
#  'BV Mobile Apps': 3.0,
#  'BV Productions': 0.0,
#  'BV Rando': 0.0,
#  'BV Smart': 28.0,
#  'BV Sridhara Maharaj': 8.0,
#  'BV Taxi - Driver': 1.0,
#  'BV Taxi Sudan': 8.0,
#  'BV Teknisk App': 0.0,
#  'BW App': 48.0,
#  'BW COMPANY FINDER': 48.0,
#  'BW Fuhlenbrock': 4.0,
#  'BW Map mobile': 57.0,
#  'BW Mobilbanking für Smartphone und Tablet': 2048.0,
#  'BW Smart': 50.0,
#  'BW SmartLife': 0.0,
#  'BW Switch': 1.0,
#  'BW Taxi': 67.0,
#  'BW Ultra': 0.0,
#  'BW Wallpaper': 4.0,
#  'BW eServices': 1.0,
#  'BW t&t': 2.0,
#  'BW-DGS plugin': 70.0,
#  'BW-GnuGo': 64.0,
#  'BW-Go': 265.0,
#  'BW-Go Free': 547.0,
#  'BW-IVMS': 0.0,
#  'BW-Joseki': 705.0,
#  'BX Diff - Crypto Coins Checker': 83.0,
#  'BX Memo': 131.0,
#  'BX Mobile TMC for SAP B1': 3.0,
#  'BX Thailand - Crypto Tracking & Analyse Bitcoin': 2.0,
#  'BZ Berner Oberländer': 64.0,
#  'BZ Berner Zeitung E-Paper': 4.0,
#  'BZ Bingo': 1.0,
#  'BZ Conferencing': 7.0,
#  'BZ Dealer': 5.0,
#  'BZ Delivery': 1.0,
#  'BZ Fingers': 15.0,
#  'BZ Langenthaler Tagblatt': 22.0,
#  'BZ Langenthaler Tagblatt E-Paper': 0.0,
#  'BZ Reminder': 41625.0,
#  'BZ Reminder PRO': 726.0,
#  'BZ Straußenführer': 291.0,
#  'BZ Vesper-App': 60.0,
#  'BZ Zombie VR': 12.0,
#  'BZ-Digital': 4.0,
#  'BZ-Smart': 828.0,
#  'BZWBK24 mobile': 64983.0,
#  'Ba Cristi': 196.0,
#  'Ba Financial Calculator plus': 31.0,
#  'Ba Zi Fortune': 592.0,
#  'Ba ba black sheep offline Video': 20.0,
#  'Ba dum tss - Rimshot widget': 690.0,
#  'BaBe + - Indonesian News': 42624.0,
#  'BaBe - Read News': 355921.0,
#  'BaBe Lite - Read Quota Saving News': 9548.0,
#  "Baba Yaad Hai?(BK's)": 160.0,
#  'Babbel – Learn Languages': 267787.0,
#  'Babbel – Learn Spanish': 54798.0,
#  'Baby ABC in box! Kids alphabet games for toddlers!': 9652.0,
#  'Baby Care & Tracker': 319.0,
#  'Baby Connect (activity log)': 8343.0,
#  'Baby Food - Homemade Recipes': 44.0,
#  'Baby Game Animal Jam Free': 9.0,
#  'Baby Monitor': 5343.0,
#  'Baby Monitor AV': 1434.0,
#  'Baby Name Together': 464.0,
#  'Baby Names': 86.0,
#  'Baby Panda Care': 108795.0,
#  'Baby Panda Learns Shapes': 3789.0,
#  'Baby Panda Musical Genius': 3346.0,
#  'Baby Panda’s Juice Shop': 19230.0,
#  'Baby Sleep: White noise lullabies for newborns': 62386.0,
#  'Baby Tiger Care - My Cute Virtual Pet Friend': 432.0,
#  'Baby puzzles': 11950.0,
#  'BackCountry Navigator TOPO GPS PRO': 6230.0,
#  'Backgammon NJ for Android': 1644.0,
#  'Background Changer & Eraser': 2076.0,
#  'Background Eraser': 267378.0,
#  'Backgrounds (HD Wallpapers)': 202474.0,
#  'Backgrounds HD (Wallpapers)': 2390099.0,
#  'BaconReader for Reddit': 103074.0,
#  'Bacteria Vaginosis': 4015.0,
#  'Bacterial Vaginosis': 1.0,
#  'Bacterial Vaginosis Symptoms': 698.0,
#  'Bacterial Vaginosis Symptoms & Treatment': 0.0,
#  'Bacterial Vaginosis Treatment': 0.0,
#  'Bacterial Vaginosis 🇺🇸': 1.0,
#  'Bacterial vaginosis Treatment - Sexual disease': 2.0,
#  'Bad Piggies': 1168959.0,
#  'Bad Piggies HD': 764967.0,
#  'Badische Zeitung': 262.0,
#  'Badoo - Free Chat & Dating App': 3781467.0,
#  'BakaReader EX': 8894.0,
#  "Baldur's Gate II": 5442.0,
#  "Baldur's Gate: Enhanced Edition": 20101.0,
#  'Banana Kong': 3452530.0,
#  'Banco Sabadell App. Your mobile bank': 25205.0,
#  "Band O'Clock": 1140.0,
#  'Banfield Pet Health Tracker': 1747.0,
#  'Bangla Calendar 1425: (EN-BN-AR) Holiday': 31.0,
#  'Banjo': 58341.0,
#  'Bank FD Interest Calculator': 166.0,
#  'Bank Of Cyprus': 1514.0,
#  'Bank of America Mobile Banking': 341090.0,
#  'Bank of Brazil': 1336246.0,
#  'BankMobile Vibe App': 14627.0,
#  'BankNordik': 28.0,
#  'Banking Calculator': 3704.0,
#  'Banorte Movil': 111632.0,
#  'Bar BQ Night Middlesbrough': 0.0,
#  'Bar BQ Tonight Dublin': 0.0,
#  'Bar-B-Q Recipes': 18.0,
#  'Bar-B-Q Rib House': 2.0,
#  'Barbers.BH': 2.0,
#  'Barbie Life™': 133117.0,
#  'Barbie Magical Fashion': 328619.0,
#  'Barbie™ Fashion Closet': 68286.0,
#  'Barca News - FC Barcelona, World Foot & Transfers': 160.0,
#  'Barca News - app for Barcelona FC Fans': 207.0,
#  'Barcelona Calendar': 670.0,
#  'Barcelona FC Noticias Live': 2.0,
#  'Barcelona Live - Goal Score & News for Barca Fans': 38.0,
#  'Barcelona Live 2018—Goals & News for Barca FC Fans': 342.0,
#  'Barcelona News - Sportfusion': 382.0,
#  'Barcelona Wallpaper HD': 93.0,
#  'Barclays US for Android': 6998.0,
#  'Barcode Scanner': 3945.0,
#  'Barisal University App-BU Face': 100.0,
#  'Barista Coffee Dictionary A-Z': 127.0,
#  'Baritastic - Bariatric Tracker': 4318.0,
#  'Barry EC': 14.0,
#  'Baseball Boy!': 148177.0,
#  'Basic Strategy Training BJ 21': 0.0,
#  'Basics of Orthopaedics': 1.0,
#  'Basket Manager 2016 Free': 1879.0,
#  'Basket Manager 2016 Pro': 117.0,
#  'Basket Manager 2017 Free': 2710.0,
#  'Basket Manager 2017 Pro': 163.0,
#  'Basket Manager 2018 Free': 1520.0,
#  'Basket Manager 2018 Pro': 84.0,
#  'Basketball Dynasty Manager 16': 426.0,
#  'Basketball FRVR - Shoot the Hoop and Slam Dunk!': 4076.0,
#  'Basketball Stars': 867920.0,
# ...
#  'Xtreme Racing 2018 - Jeep & 4x4 off road simulator': 2178.0,
#  'Y! Mobile menu': 9.0,
#  'YAKALA AY': 0.0,
#  'YAY - TBH': 2520.0,
#  'YAZIO Calorie Counter, Nutrition Diary & Diet Plan': 117176.0,
#  'YEBIS OpenGL ES 3.0 Tech Demo': 380.0,
#  'Yahoo Fantasy Sports - #1 Rated Fantasy App': 277939.0,
#  'Yahoo Finance': 135952.0,
#  'Yahoo Mail – Stay Organized': 4188345.0,
#  'Yahoo Sports - scores, stats, news, & highlights': 32386.0,
#  'Yahoo Weather': 1312037.0,
#  'Yahoo! Weather for SH Forecast for understanding the approach of rain clouds Free': 7457.0,
#  'Yahoo! transit guide free timetable, operation information, transfer search': 104800.0,
#  'Yandex Browser with Protect': 1235841.0,
#  'Yandex.Disk': 115072.0,
#  'Yandex.Shell (Launcher+Dialer)': 87300.0,
#  'Yandex.Trains': 56471.0,
#  'Yandex.Transport': 126282.0,
#  'Yandex.Weather': 309617.0,
#  'Yanosik: "antyradar", traffic jams, navigation, camera': 102248.0,
#  'Yaoi Novels - Shounen ai Book&fiction': 304.0,
#  'Yaoi Ooku: Distorted Love': 2614.0,
#  'Yatra - Flights, Hotels, Bus, Trains & Cabs': 251037.0,
#  'Yazdani Cd Center EllahAbad Official App': 8.0,
#  'Yeled EI': 0.0,
#  'Yelp: Food, Shopping, Services Nearby': 397422.0,
#  'Yes day': 10055521.0,
#  'Yes319 real price login query': 12.0,
#  'Yidio: TV Show & Movie Guide': 27424.0,
#  'Yoga - Track Yoga': 7976.0,
#  'Yoga Studio: Mind & Body': 5499.0,
#  'Yongqing fast search': 1437.0,
#  "Yoong: Kick 'Em Up!": 7107.0,
#  'Yoriza Pension - travel, lodging, pension, camping, caravan, pool villas accommodation discount': 17882.0,
#  "You're an Anime": 2.0,
#  'YouCam Makeup - Magic Selfie Makeovers': 3337952.0,
#  'YouCam Perfect - Selfie Photo Editor': 1579343.0,
#  'YouCamp EU': 39.0,
#  'YouCut - Video Editor & Video Maker, No Watermark': 98819.0,
#  'YouNow: Live Stream Video Chat': 309872.0,
#  'YouTube': 25623548.0,
#  'YouTube Gaming': 130549.0,
#  'YouTube Kids': 469851.0,
#  'YouTube Studio': 436170.0,
#  'YouTube TV - Watch & Record Live TV': 38517.0,
#  'Youboox - Livres, BD et magazines': 4071.0,
#  'Young Speeches': 2221.0,
#  'Youper - AI Therapy': 1976.0,
#  'Your Freedom VPN Client': 74497.0,
#  'Your rank CS:GO': 4946.0,
#  'YourTube Video Views BG': 8.0,
#  'Yummly Recipes & Shopping List': 91359.0,
#  'Yuzu eReader': 250.0,
#  'Z App': 405.0,
#  'Z Camera': 142.0,
#  'Z Camera - Photo Editor, Beauty Selfie, Collage': 1075016.0,
#  'Z Champions': 96028.0,
#  'Z City': 3976.0,
#  'Z Day: Hearts of Heroes': 5894.0,
#  'Z Origins - (Z The Game)': 4421.0,
#  'Z PIVOT': 0.0,
#  'Z Ringtones PREMIUM 2018': 10158.0,
#  'Z War-Zombie Modern Combat': 62301.0,
#  'Z-Empire: Dead Strike': 99.0,
#  'ZAK DW': 0.0,
#  'ZALORA Fashion Shopping': 142512.0,
#  'ZArchiver': 337242.0,
#  'ZArchiver Donate': 1721.0,
#  'ZEDGE™ Ringtones & Wallpapers': 6459626.0,
#  'ZERO Lock Screen': 75336.0,
#  'ZOMBIE RIPPER': 16073.0,
#  'ZOOKEEPER DX TouchEdition': 3195.0,
#  'ZOOM Cloud Meetings': 31614.0,
#  'ZUL - Rotativo Digital BH': 29.0,
#  'Zaatar w Zeit': 205.0,
#  'Zagat': 2528.0,
#  'Zalo – Video Call': 1042170.0,
#  'Zap-Map: EV charging points UK': 181.0,
#  'Zappos – Shoe shopping made simple': 44588.0,
#  'Zapya - File Transfer, Sharing': 387958.0,
#  'Zapzapmath: K-6 Math Games': 1065.0,
#  'Zara': 95905.0,
#  'Zdravei.BG': 6.0,
#  'Zello PTT Walkie Talkie': 695576.0,
#  'Zen Leaf': 1.0,
#  'ZenUI Dialer & Contacts': 437674.0,
#  'ZenUI Help': 136874.0,
#  'ZenUI Keyboard – Emoji, Theme': 537554.0,
#  'ZenUI Launcher': 1141545.0,
#  'ZenUI Safeguard': 100.0,
#  'ZenUI Themes – Stylish Themes': 47393.0,
#  'Zenefits': 296.0,
#  'Zenith Bank Mobile App': 7215.0,
#  'Zepp Golf Swing Analyzer': 2020.0,
#  'Zetup, print in one click': 40.0,
#  'Ziggo GO': 29690.0,
#  'Zillow: Find Houses for Sale & Apartments for Rent': 417907.0,
#  'ZipRealty Real Estate & Homes': 3937.0,
#  'ZiraatBank BH': 58.0,
#  'Zlax.io Zombs Luv Ax': 6344.0,
#  'Zocdoc: Find Doctors & Book Appointments': 6099.0,
#  'Zoho Reports - Mobile BI': 45.0,
#  'Zomato - Restaurant Finder and Food Delivery App': 511420.0,
#  'Zombie Avengers:(Dreamsky)Stickman War Z': 13604.0,
#  'Zombie Catchers': 989158.0,
#  'Zombie Death Shooter': 17372.0,
#  'Zombie Defense': 275048.0,
#  'Zombie Frontier': 326689.0,
#  'Zombie Hunter King': 10538.0,
#  'Zombie Hunter: Post Apocalypse Survival Games': 327599.0,
#  'Zombie Sniper 3D III': 8122.0,
#  'Zombie Tsunami': 4918776.0,
#  'Zombie War Z : Hero Survival Rules': 1987.0,
#  'ZombieVital DG': 10.0,
#  'Zombies, Run! 5k Training (Free)': 267.0,
#  'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo': 7880.0,
#  'Zoo For Preschool Kids 3-9 Years': 76.0,
#  'Zooper Widget': 30498.0,
#  'Zoopla Property Search UK - Home to buy & rent': 21195.0,
#  'Zoosk Dating App: Meet Singles': 516917.0,
#  'Zowi App': 516.0,
#  'Zumper - Apartment Rental Finder': 11200.0,
#  'Zynga Poker – Texas Holdem': 1986068.0,
#  '[BN] Blitz': 4.0,
#  '[EF]ShoutBox': 3.0,
#  '[ROOT] X Privacy Installer': 12147.0,
#  '[Sub/EMUI] P Pro - EMUI 8.1/8.0/5.X Theme': 13.0,
#  '[Substratum] K-Manager for K-Klock': 14.0,
#  '[Substratum] M5 Theme': 16.0,
#  '[adult swim]': 21433.0,
#  '[root] Pry-Fi': 6736.0,
#  '[substratum] Vacuum: P': 230.0,
#  '[verify-U] VideoIdent': 83.0,
#  'aCalendar - Android Phone': 80119.0,
#  'aCalendar+ Calendar & Tasks': 26919.0,
#  'aa': 886418.0,
#  'ab': 10.0,
#  'abeoCoder': 83.0,
#  'ac remote control': 9514.0,
#  'ai robot keyboard': 1891.0,
#  'ai.Bot Box': 0.0,
#  'ai.type Free Emoji Keyboard': 647721.0,
#  'ai.type keyboard Plus + Emoji': 57076.0,
#  'allhomes.com.au': 874.0,
#  'amazer - Global Kpop Video Community': 1215.0,
#  'amm dz': 0.0,
#  'ao': 14145.0,
#  'ap,wifi testing,iperf,ping,android,Bluetooth,tcp': 3.0,
#  'au': 9126.0,
#  'auto Call Recorder 2018': 929.0,
#  'auto fines': 31433.0,
#  "autolina.ch has over 120'000 cars on offer.": 25.0,
#  'autoricardo.ch – vehicles': 1045.0,
#  'bX Hot Articles by Ex Libris': 42.0,
#  'bX Thailand Simple Market Price and Alert': 8.0,
#  'ba': 1734.0,
#  'bacterial vaginosis': 0.0,
#  "bd's Mongolian Grill": 120.0,
#  'be Produbanco': 967.0,
#  "be'ah": 5.0,
#  'beIN SPORTS TR': 135763.0,
#  'bgtime.tv': 694.0,
#  'bi-Cube Mobile Token': 5.0,
#  'bigbasket - online grocery': 216741.0,
#  'bitcoin exchange bx thailand': 19.0,
#  'bk Group Mobile': 1.0,
#  'bm Wallet': 196.0,
#  'bm offers': 320.0,
#  'bm-Events': 0.0,
#  'boattheory.ch Full 2018': 54.0,
#  'bp Magazine for Bipolar': 5.0,
#  'bp e-store': 52.0,
#  'bpresso PRO': 515.0,
#  'bq magazine': 2.0,
#  'busuu: Learn Languages - Spanish, English & More': 207294.0,
#  'bz Basel E-Paper': 72.0,
#  'bz Basel News': 23.0,
#  'bz Baselland E-Paper': 69.0,
#  'bz Basellandschaftliche News': 33.0,
#  'cPro Marketplace: Buy. Sell. Rent. Date. Jobs.': 385764.0,
#  'camera zoom moon': 1213.0,
#  'cg guruji': 170.0,
#  'ch-mm Dict': 0.0,
#  'chat dz': 8.0,
#  'chat live chat': 24.0,
#  'chat saudi arabia': 11.0,
#  'chicken song': 434.0,
#  'chomp SMS': 335646.0,
#  'ci': 1691.0,
#  'ck-modelcars Shop': 118.0,
#  'ck-modelcars-UK Shop': 69.0,
#  'cloudLibrary': 10774.0,
#  'cluster.dk': 49.0,
#  'cm to inches | centimeters to inches conversion': 52.0,
#  'cm, mm to inch, feet converter tool': 176.0,
#  'codeEazy - C/C++/JAVA': 130.0,
#  'codeSpark Academy & The Foos': 4522.0,
#  'comico Popular Original Cartoon Updated Everyday Comico': 93965.0,
#  'converter video to mp3': 783.0,
#  'cronometer (ad free)': 1075.0,
#  'cronometra-br': 0.0,
#  'cx advance call blocker': 3.0,
#  'cx-32wifi': 62.0,
#  'cx-33wifi': 63.0,
#  'dB Meter - measure sound & noise level in Decibel': 154.0,
#  'dB Sound Level Meter': 203.0,
#  'dB Sound Meter': 29.0,
#  'dB: Sound Meter Pro': 31.0,
#  'daily News': 26411.0,
#  'daskal.eu': 5.0,
#  'db Meter - sound level meter with data logging': 0.0,
#  'db.Mobil App': 23.0,
#  'dekoreko-dz': 16.0,
#  'delivery.com: Order Food, Alcohol & Laundry': 1920.0,
#  'detikcom - Latest & Most Complete News': 190888.0,
#  'df': 4.0,
#  'df-Vegetable': 0.0,
#  'diep.io': 347883.0,
#  'dk': 5.0,
#  'dk Verk': 9.0,
#  'do': 1073.0,
#  'dr.fone - Recovery & Transfer wirelessly & Backup': 23347.0,
#  'dt Pro': 4.0,
#  'dt.se': 124.0,
#  'du View': 935.0,
#  'du app': 7578.0,
#  'dv Prompter': 321.0,
#  'dy n fly': 1.0,
#  'dz NEWS Algerie': 2318.0,
#  'dz press': 30.0,
#  'e-Anatomy': 1545.0,
#  'e-Boks.dk': 6752.0,
#  'e-DN - den digitala tidningen från Dagens Nyheter': 160.0,
#  'e-Docente EI/anos iniciais EF': 2.0,
#  'eBay Kleinanzeigen for Germany': 318142.0,
#  'eBay: Buy & Sell this Summer - Discover Deals Now!': 2788460.0,
#  'eBiblio': 2907.0,
#  'eBoox new: Reader for fb2 epub zip books': 2739.0,
#  'eBoox: book reader fb2 epub zip': 21336.0,
#  'eChallan Andhra Pradesh (AP)': 5.0,
#  'eCooltra: scooter sharing. Share electric scooters': 2822.0,
#  'eG Monitor': 8.0,
#  'eHub': 6969.0,
#  'eP Finder': 0.0,
#  'eP Scanner': 0.0,
#  'ePN Cashback AliExpress': 19212.0,
#  'ePay.bg': 2017.0,
#  'ePazar.bg': 28.0,
#  'ear super hearing': 0.0,
#  'easyFocus': 3396.0,
#  'easyJet: Travel App': 134895.0,
#  'ec-Work': 3.0,
#  'ec.tv': 0.0,
#  'edX - Online Courses by Harvard, MIT & more': 32380.0,
#  'edp re:dy': 172.0,
#  'edp re:dy smarthome': 30.0,
#  'efootwear.eu - online store': 928.0,
#  'eharmony - Online Dating App': 31320.0,
#  'ei': 2.0,
#  'ei Calc': 2.0,
#  'ek tuhi': 316.0,
#  'el': 32405.0,
#  'energyly (TNEB,BESCOM,MH,DL..)': 627.0,
#  'ep-liggare - Elektronisk personalliggare': 0.0,
#  'eu sou franky': 195.0,
#  'ew-Magazin': 2.0,
#  'ez Share Android app': 1461.0,
#  'ezETC (ETC balance inquiry, meter trial, real-time traffic)': 38846.0,
#  "f'east": 38.0,
#  'f.lux (preview, root-only)': 5559.0,
#  'fi': 691.0,
#  'following': 1.0,
#  'foodpanda - Local Food Delivery': 292969.0,
#  'foody Cyprus - online ordering': 214.0,
#  "fred's Pharmacy": 315.0,
#  'free video calls and chat': 594720.0,
#  'funny Image Comments for FB': 19.0,
#  'gCMOB': 7935.0,
#  'gardening ideas flower diy': 0.0,
#  'go41cx': 171.0,
#  'gps tracker cg': 0.0,
#  'happn – Local dating app': 1118201.0,
#  'hellofood - Food Delivery': 43614.0,
#  'high cholesterol levels': 0.0,
#  'homegate.ch': 2543.0,
#  'hum app': 10218.0,
#  'i am EB': 1.0,
#  'i am rich': 213.0,
#  'i miss you quotes and photos': 0.0,
#  'i-share AF/KLM (AFKL ishare)': 2.0,
#  'iBP Blood Pressure': 578.0,
#  'iBiznes24 mobile': 38.0,
#  'iCam - Webcam Video Streaming': 770.0,
#  'iCard BD Plus': 2.0,
#  'iCluster - The DX-Cluster database': 0.0,
#  'iDates - Chats, Flirts, Dating, Love & Relations': 13890.0,
#  'iFORA BM': 3.0,
#  'iFORA BP': 18.0,
#  'iFish BC': 25.0,
#  'iFunny :)': 503757.0,
#  'iGun Pro -The Original Gun App': 249308.0,
#  'iHoroscope - 2018 Daily Horoscope & Astrology': 398307.0,
#  'iHunter BC': 55.0,
#  'iKeyboard - emoji, emoticons': 624924.0,
#  'iLauncher OS 12 Pro - Phone X': 3.0,
#  'iLocker X - iOS11 Lockscreen with HD Wallpapers': 1714.0,
#  'iMediaShare – Photos & Music': 104551.0,
#  'iOBD2-CF': 5.0,
#  'iPair-Meet, Chat, Dating': 182986.0,
#  'iPlayIT for YouTube VR Player': 5879.0,
#  'iProperty Malaysia': 809.0,
#  'iReadMe': 8.0,
#  'iScore5 AP Psych': 10.0,
#  'iSmart DV': 5692.0,
#  'iSniper 3D Arctic Warfare': 35572.0,
#  'iSwipe Phone X': 58366.0,
#  'iTooch Mathématiques CP': 1018.0,
#  'iTranslate Translator & Dictionary': 201718.0,
#  'iWnn IME for Nexus': 2394.0,
#  'ibis Paint X': 224399.0,
#  'icon wallpaper dressup💞CocoPPa': 595120.0,
#  'imo beta free calls and text': 659395.0,
#  'imo free video calls and chat': 4785892.0,
#  'infirmiers': 125.0,
#  'ipsy: Makeup, Beauty, and Tips': 49790.0,
#  'issuu - Read Magazines, Catalogs, Newspapers.': 74425.0,
#  'ivi - movies and TV shows in HD': 684116.0,
#  'ixigo Cabs-Compare & Book Taxi': 11838.0,
#  'join.me - Simple Meetings': 6989.0,
#  'junainfo.dy.fi': 8.0,
#  'justWink Greeting Cards': 69177.0,
#  'kick the buddy': 294.0,
#  'kicker football news': 56270.0,
#  'learn c in hindi': 109.0,
#  'lesparticuliers.fr': 96.0,
#  'letgo: Buy & Sell Used Stuff, Cars & Real Estate': 972256.0,
#  'lifebox': 56403.0,
#  'live Point': 54.0,
#  'loans.com.au Smart Money': 30.0,
#  'love': 42677.0,
#  'love sms good morning': 10.0,
#  'm, cm, mm to yard, feet, inch converter tool': 246.0,
#  'm-Faisaa': 142.0,
#  'm.ride - your motorcycle app': 189.0,
#  'm:go BiH': 559.0,
#  'm>notes notepad': 184.0,
#  'magicApp Calling & Messaging': 207712.0,
#  'mail.co.uk Mail': 21.0,
#  'mail.com mail': 44706.0,
#  'meStudying: AP English Lit': 1.0,
#  'metroZONE': 47497.0,
#  'mobLee Events': 11.0,
#  'mobileRx Pharmacy': 124.0,
#  'mon guide au bank populaire -infos et instructions': 4.0,
#  'most expensive app (H)': 6.0,
#  'music (CG)': 0.0,
#  'muzmatch: Muslim & Arab Singles, Marriage & Dating': 5168.0,
#  'my face': 1054.0,
#  'my4D': 573.0,
#  'myAT&T': 80816.0,
#  'myAir™ for Air10™ by ResMed': 236.0,
#  'myChevrolet': 6747.0,
#  'myGrow': 84.0,
#  'myHomework Student Planner': 28392.0,
#  'myLPG.eu': 556.0,
#  'myMail – Email for Hotmail, Gmail and Outlook Mail': 305218.0,
#  'myMetro': 26189.0,
#  'myNaida CI': 64.0,
#  'myQ': 3642.0,
#  'mySharpBranded CI Test': 0.0,
#  'mySugr: the blood sugar tracker made just for you': 21187.0,
#  'mysms SMS Text Messaging Sync': 37320.0,
#  'myvi by': 122.0,
#  'nds4droid': 107778.0,
#  'news.com.au': 1.0,
#  'ooVoo Video Calls, Messaging & Stories': 1157003.0,
#  'orderin.bm': 0.0,
#  'osmino Wi-Fi: free WiFi': 134203.0,
#  'pCloud: Free Cloud Storage': 16149.0,
#  'palmPEDi: Pediatric Tape': 66.0,
#  'payermonstationnement.fr': 38.0,
#  'photo keypad lockscreen': 225544.0,
#  'pixiv': 86956.0,
#  "pixiv comic - everyone's manga app": 18814.0,
#  'play2prep: ACT, SAT prep': 3692.0,
#  'postit.bm': 1.0,
#  'pretty Easy privacy p≡p': 21.0,
#  'qEG APP / Química EG SRL': 0.0,
#  'quran-DZ': 0.0,
#  'realcommercial.com.au': 128.0,
#  'realestate.com.au - Buy, Rent & Sell Property': 14657.0,
#  'reality.cz': 1372.0,
#  'retteMi.ch': 31.0,
#  'ricardo.ch': 13232.0,
#  'sABN': 2287.0,
#  'search.ch': 11514.0,
#  'senior easy phone': 168.0,
#  'signály.cz': 38.0,
#  'slither.io': 5231553.0,
#  'stranger chat - anonymous chat': 13204.0,
#  'studentsLife by FH Kärnten': 108.0,
#  'sugar, sugar': 1405.0,
#  'sustainability@BU': 10.0,
#  'swissinfo.ch': 271.0,
#  'tTorrent - ad free': 2976.0,
#  'taxi.eu': 1865.0,
#  'textPlus: Free Text & Calls': 382121.0,
#  "that's lit": 1115.0,
#  'the Egg - crack the egg': 211.0,
#  'theCut': 499.0,
#  'theScore esports': 16257.0,
#  'theScore: Live Sports Scores, News, Stats & Videos': 133833.0,
#  'think Comics': 1006.0,
#  'tinyCam Monitor FREE': 65914.0,
#  'tournaments and more.aj.2': 0.0,
#  'trip.bg': 103.0,
#  'trivago: Hotels & Travel': 219848.0,
#  'tutti.ch - Free Classifieds': 9950.0,
#  'tv-ec': 1.0,
#  'tökr': 17.0,
#  'uCiC- Videos and Photos on demand': 2052.0,
#  'usgang.ch': 492.0,
#  'v-view': 309.0,
#  'van Gennip Textiles BV': 1.0,
#  'vide-greniers.org': 5839.0,
#  'video player': 26421.0,
#  'video player for android': 351168.0,
#  'view.com.au - Buy, Rent or Research Real Estate': 212.0,
#  'virtual lover 3D': 5195.0,
#  'w UN map': 23164.0,
#  'waut.ch!': 10.0,
#  'weather - weather forecast': 11118.0,
#  'weather HD': 1546.0,
#  'weight conversion calculator': 807.0,
#  'wetter.com - Weather and Radar': 189310.0,
#  'wikiHow: how to do anything': 43088.0,
#  'yHomework - Math Solver': 50771.0,
#  'zulily - Shop Daily Deals in Fashion and Home': 28560.0,
#  '¡Ay Caramba!': 0.0,
#  '¡Ay Metro!': 489.0,
#  '¿Es Vegan?': 438.0,
#  'Égalité et Réconciliation': 58.0,
#  'ÖBB Scotty': 12572.0,
#  'İşCep': 381788.0,
#  'Šmelina .cz inzeráty inzerce': 117.0,
#  'Аim Training for CS': 2328.0,
#  'Билеты ПДД CD 2019 PRO': 21.0,
#  'РИА Новости': 44274.0,
#  'РееI Smart Remote MP3 CD Player': 27.0,
#  'أحداث وحقائق | خبر عاجل في اخبار العالم': 311.0,
#  'الفاتحون Conquerors': 108130.0,
#  'صور حرف H': 13.0,
#  'لعبة تقدر تربح DZ': 238.0,
#  'বাংলা টিভি প্রো BD Bangla TV': 193.0,
#  'বাংলাflix': 1111.0,
#  'သိင်္ Astrology - Min Thein Kha BayDin': 2225.0,
#  '► MultiCraft ― Free Miner! 👍': 1305050.0,
#  '【Miku AR Camera】Mikuture': 36268.0,
#  '【Ranobbe complete free】 Novelba - Free app that you can read and write novels': 1330.0,
#  'あなカレ【BL】無料ゲーム': 6073.0,
#  'パーリーゲイツ公式通販｜EJ STYLE（イージェイスタイル）': 1.0,
#  '中国語 AQリスニング': 21.0,
#  '乐屋网: Buying a house, selling a house, renting a house': 2248.0,
#  '乗換NAVITIME\u3000Timetable & Route Search in Japan Tokyo': 50459.0,
#  '哈哈姆特不EY': 239.0,
#  '日本AV历史': 215.0,
#  '漫咖 Comics - Manga,Novel and Stories': 12088.0,
#  '英漢字典 EC Dictionary': 55408.0,
#  '감성학원 BL 첫사랑': 190.0,
#  '뽕티비 - 개인방송, 인터넷방송, BJ방송': 414.0,
#  "💎 I'm rich": 718.0,
#  '💘 WhatsLov: Smileys of love, stickers and GIF': 22098.0,
#  '📏 Smart Ruler ↔️ cm/inch measuring for homework!': 19.0,
#  '🔥 Football Wallpapers 4K | Full HD Backgrounds 😍': 11661.0}

# %%
# compare the lengths of the reviews_max dictionary and the duplicates free (unique) dataset. Are they the same ?

len(reviews_max) == non_dup_google
# Out:
# True

# %%
# the already added list will be a check to confirm that all the unique app names 
# in the dataset have been added and cleaned

android_clean, already_added = [], []
for row in google_data[1:]:
    name = row[0]
    n_reviews = float(row[3])
    if reviews_max[name] == n_reviews and name not in already_added:
        android_clean.append(row)
        already_added.append(name)
pprint.pprint(android_clean)
# Out:
# [['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'ART_AND_DESIGN',
#   '4.1',
#   '159',
#   '19M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 7, 2018',
#   '1.0.0',
#   '4.0.3 and up'],
#  ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'ART_AND_DESIGN',
#   '4.7',
#   '87510',
#   '8.7M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 1, 2018',
#   '1.2.4',
#   '4.0.3 and up'],
#  ['Sketch - Draw & Paint',
#   'ART_AND_DESIGN',
#   '4.5',
#   '215644',
#   '25M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Art & Design',
#   'June 8, 2018',
#   'Varies with device',
#   '4.2 and up'],
#  ['Pixel Draw - Number Art Coloring Book',
#   'ART_AND_DESIGN',
#   '4.3',
#   '967',
#   '2.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'June 20, 2018',
#   '1.1',
#   '4.4 and up'],
#  ['Paper flowers instructions',
#   'ART_AND_DESIGN',
#   '4.4',
#   '167',
#   '5.6M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 26, 2017',
#   '1.0',
#   '2.3 and up'],
#  ['Smoke Effect Photo Maker - Smoke Editor',
#   'ART_AND_DESIGN',
#   '3.8',
#   '178',
#   '19M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 26, 2018',
#   '1.1',
#   '4.0.3 and up'],
#  ['Infinite Painter',
#   'ART_AND_DESIGN',
#   '4.1',
#   '36815',
#   '29M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'June 14, 2018',
#   '6.1.61.1',
#   '4.2 and up'],
#  ['Garden Coloring Book',
#   'ART_AND_DESIGN',
#   '4.4',
#   '13791',
#   '33M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'September 20, 2017',
#   '2.9.2',
#   '3.0 and up'],
#  ['Kids Paint Free - Drawing Fun',
#   'ART_AND_DESIGN',
#   '4.7',
#   '121',
#   '3.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'July 3, 2018',
#   '2.8',
#   '4.0.3 and up'],
#  ['Text on Photo - Fonteee',
#   'ART_AND_DESIGN',
#   '4.4',
#   '13880',
#   '28M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'October 27, 2017',
#   '1.0.4',
#   '4.1 and up'],
#  ['Name Art Photo Editor - Focus n Filters',
#   'ART_AND_DESIGN',
#   '4.4',
#   '8788',
#   '12M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 31, 2018',
#   '1.0.15',
#   '4.0 and up'],
#  ['Tattoo Name On My Photo Editor',
#   'ART_AND_DESIGN',
#   '4.2',
#   '44829',
#   '20M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Art & Design',
#   'April 2, 2018',
#   '3.8',
#   '4.1 and up'],
#  ['Mandala Coloring Book',
#   'ART_AND_DESIGN',
#   '4.6',
#   '4326',
#   '21M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'June 26, 2018',
#   '1.0.4',
#   '4.4 and up'],
#  ['3D Color Pixel by Number - Sandbox Art Coloring',
#   'ART_AND_DESIGN',
#   '4.4',
#   '1518',
#   '37M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 3, 2018',
#   '1.2.3',
#   '2.3 and up'],
#  ['Learn To Draw Kawaii Characters',
#   'ART_AND_DESIGN',
#   '3.2',
#   '55',
#   '2.7M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'June 6, 2018',
#   'NaN',
#   '4.2 and up'],
#  ['Photo Designer - Write your name with shapes',
#   'ART_AND_DESIGN',
#   '4.7',
#   '3632',
#   '5.5M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 31, 2018',
#   '3.1',
#   '4.1 and up'],
#  ['350 Diy Room Decor Ideas',
#   'ART_AND_DESIGN',
#   '4.5',
#   '27',
#   '17M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'November 7, 2017',
#   '1.0',
#   '2.3 and up'],
#  ['FlipaClip - Cartoon animation',
#   'ART_AND_DESIGN',
#   '4.3',
#   '194216',
#   '39M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 3, 2018',
#   '2.2.5',
#   '4.0.3 and up'],
#  ['ibis Paint X',
#   'ART_AND_DESIGN',
#   '4.6',
#   '224399',
#   '31M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 30, 2018',
#   '5.5.4',
#   '4.1 and up'],
#  ['Logo Maker - Small Business',
#   'ART_AND_DESIGN',
#   '4.0',
#   '450',
#   '14M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 20, 2018',
#   '4.0',
#   '4.1 and up'],
#  ["Boys Photo Editor - Six Pack & Men's Suit",
#   'ART_AND_DESIGN',
#   '4.1',
#   '654',
#   '12M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 20, 2018',
#   '1.1',
#   '4.0.3 and up'],
#  ['Superheroes Wallpapers | 4K Backgrounds',
#   'ART_AND_DESIGN',
#   '4.7',
#   '7699',
#   '4.2M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Art & Design',
#   'July 12, 2018',
#   '2.2.6.2',
#   '4.0.3 and up'],
#  ['HD Mickey Minnie Wallpapers',
#   'ART_AND_DESIGN',
#   '4.7',
#   '118',
#   '23M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 7, 2018',
#   '1.1.3',
#   '4.1 and up'],
#  ['Harley Quinn wallpapers HD',
#   'ART_AND_DESIGN',
#   '4.8',
#   '192',
#   '6.0M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 25, 2018',
#   '1.5',
#   '3.0 and up'],
#  ['Colorfit - Drawing & Coloring',
#   'ART_AND_DESIGN',
#   '4.7',
#   '20260',
#   '25M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'October 11, 2017',
#   '1.0.8',
#   '4.0.3 and up'],
#  ['Animated Photo Editor',
#   'ART_AND_DESIGN',
#   '4.1',
#   '203',
#   '6.1M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 21, 2018',
#   '1.03',
#   '4.0.3 and up'],
#  ['Pencil Sketch Drawing',
#   'ART_AND_DESIGN',
#   '3.9',
#   '136',
#   '4.6M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 12, 2018',
#   '6.0',
#   '2.3 and up'],
#  ['Easy Realistic Drawing Tutorial',
#   'ART_AND_DESIGN',
#   '4.1',
#   '223',
#   '4.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 22, 2017',
#   '1.0',
#   '2.3 and up'],
#  ['Pink Silver Bow Keyboard Theme',
#   'ART_AND_DESIGN',
#   '4.2',
#   '1120',
#   '9.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 12, 2018',
#   '6.7.12.2018',
#   '4.0.3 and up'],
#  ['Art Drawing Ideas',
#   'ART_AND_DESIGN',
#   '4.1',
#   '227',
#   '5.2M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'May 31, 2018',
#   '1.2',
#   '2.3 and up'],
#  ['Anime Manga Coloring Book',
#   'ART_AND_DESIGN',
#   '4.5',
#   '5035',
#   '11M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 19, 2018',
#   '2.20',
#   '4.0 and up'],
#  ['Easy Origami Ideas',
#   'ART_AND_DESIGN',
#   '4.2',
#   '1015',
#   '11M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 6, 2018',
#   '1.1.0',
#   '4.1 and up'],
#  ['I Creative Idea',
#   'ART_AND_DESIGN',
#   '4.7',
#   '353',
#   '4.2M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Art & Design',
#   'April 27, 2018',
#   '1.6',
#   '4.1 and up'],
#  ['How to draw Ladybug and Cat Noir',
#   'ART_AND_DESIGN',
#   '3.8',
#   '564',
#   '9.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 11, 2018',
#   '2.1',
#   '4.1 and up'],
#  ['Floor Plan Creator',
#   'ART_AND_DESIGN',
#   '4.1',
#   '36639',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 14, 2018',
#   'Varies with device',
#   '2.3.3 and up'],
#  ['PIP Camera - PIP Collage Maker',
#   'ART_AND_DESIGN',
#   '4.7',
#   '158',
#   '11M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'November 29, 2017',
#   '1.3',
#   '4.0.3 and up'],
#  ['How To Color Disney Princess - Coloring Pages',
#   'ART_AND_DESIGN',
#   '4.0',
#   '591',
#   '9.4M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 31, 2018',
#   '1',
#   '4.0 and up'],
#  ['Drawing Clothes Fashion Ideas',
#   'ART_AND_DESIGN',
#   '4.2',
#   '117',
#   '15M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 20, 2018',
#   '2.0.1',
#   '4.0.3 and up'],
#  ['Sad Poetry Photo Frames 2018',
#   'ART_AND_DESIGN',
#   '4.5',
#   '176',
#   '10M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 2, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['Paint Splash!',
#   'ART_AND_DESIGN',
#   '3.8',
#   '2206',
#   '1.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'April 15, 2018',
#   '1.46',
#   '4.1 and up'],
#  ['Popsicle Sticks and Similar DIY Craft Ideas',
#   'ART_AND_DESIGN',
#   '4.2',
#   '26',
#   '12M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 3, 2018',
#   '1.0.0',
#   '4.1 and up'],
#  ['Canva: Poster, banner, card maker & graphic design',
#   'ART_AND_DESIGN',
#   '4.7',
#   '174531',
#   '24M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 31, 2018',
#   '1.6.1',
#   '4.1 and up'],
#  ['Install images with music to make video without Net - 2018',
#   'ART_AND_DESIGN',
#   '4.6',
#   '1070',
#   '26M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'November 14, 2017',
#   '1.6',
#   '4.1 and up'],
#  ['Little Teddy Bear Colouring Book Game',
#   'ART_AND_DESIGN',
#   '4.2',
#   '85',
#   '8.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'December 17, 2017',
#   '2.0.0',
#   '4.1 and up'],
#  ['How To Draw Food',
#   'ART_AND_DESIGN',
#   '4.3',
#   '845',
#   '7.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'May 28, 2018',
#   '1.0',
#   '2.3 and up'],
#  ['Monster Truck Stunt 3D 2019',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '367',
#   '25M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 10, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['Real Tractor Farming',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1598',
#   '56M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '11.0',
#   '4.1 and up'],
#  ['Ultimate F1 Racing Championship',
#   'AUTO_AND_VEHICLES',
#   '3.8',
#   '284',
#   '57M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '3.0',
#   '4.1 and up'],
#  ['Used Cars and Trucks for Sale',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '17057',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['American Muscle Car Race',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '129',
#   '35M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '3.0',
#   '4.1 and up'],
#  ['Offroad Oil Tanker Driver Transport Truck 2019',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '542',
#   '33M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 31, 2018',
#   '4.0',
#   '4.1 and up'],
#  ['Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with '
#   'Drom.ru',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '10479',
#   '33M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 18, 2018',
#   '1.7.1',
#   '4.0 and up'],
#  ['Gas Prices (Germany only)',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '805',
#   '5.6M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 29, 2018',
#   '2.5.1',
#   '4.4 and up'],
#  ['Extreme Rally Championship',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '129',
#   '54M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '3.0',
#   '4.1 and up'],
#  ['Restart Navigator',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1403',
#   '201k',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 26, 2014',
#   '1.0.1',
#   '2.2 and up'],
#  ['REG - Check the regnumber, find information about Swedish vehicles',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '3971',
#   '3.6M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   '2.493',
#   '4.4 and up'],
#  ['CityBus Lviv',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '534',
#   '5.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 8, 2018',
#   '1.9.1',
#   '4.0.3 and up'],
#  ['CDL Practice Test 2018 Edition',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '7774',
#   '17M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 3, 2018',
#   '1.7',
#   '4.2 and up'],
#  ['ezETC (ETC balance inquiry, meter trial, real-time traffic)',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '38846',
#   '8.6M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 28, 2018',
#   '2.20 Build 02',
#   '4.1 and up'],
#  ['Free VIN Report for Used Cars',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '2431',
#   '2.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 12, 2018',
#   '1.37',
#   '4.0 and up'],
#  ['DMV Permit Practice Test 2018 Edition',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '6090',
#   '27M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 3, 2018',
#   '1.7',
#   '4.2 and up'],
#  ['Check Vehicle Tax',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '295',
#   '2.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   '0.2.1',
#   '4.4 and up'],
#  ['Used Cars Mexico',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '190',
#   '2.5M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'October 14, 2016',
#   '1.0',
#   '2.3 and up'],
#  ['Ulysse Speedometer',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '40211',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['REPUVE',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '356',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Used cars for sale - Trovit',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '52530',
#   '7.0M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 16, 2018',
#   '4.47.3',
#   '4.0.3 and up'],
#  ['Fines of the State Traffic Safety Inspectorate are official: inspection, '
#   'payment of fines',
#   'AUTO_AND_VEHICLES',
#   '4.8',
#   '116986',
#   '35M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   '1.9.7',
#   '4.0.3 and up'],
#  ['SK Enca Direct Malls - Used Cars Search',
#   'AUTO_AND_VEHICLES',
#   '3.6',
#   '1379',
#   '16M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   '2.2.21',
#   '4.2 and up'],
#  ['Android Auto - Maps, Media, Messaging & Voice',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '271920',
#   '16M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Auto & Vehicles',
#   'July 11, 2018',
#   'Varies with device',
#   '5.0 and up'],
#  ['PDD-UA',
#   'AUTO_AND_VEHICLES',
#   '4.8',
#   '736',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 29, 2018',
#   '2.9',
#   '2.3.3 and up'],
#  ['Tickets SDA 2019 + Exam RF',
#   'AUTO_AND_VEHICLES',
#   '4.8',
#   '7021',
#   '17M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 27, 2018',
#   '1.79',
#   '4.0 and up'],
#  ['Super Cars Wallpapers And Backgrounds',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '197',
#   '3.4M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 14, 2018',
#   '1.3',
#   '4.0 and up'],
#  ['Police Lights, Sirens & Follow Me',
#   'AUTO_AND_VEHICLES',
#   '4.5',
#   '737',
#   '8.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 8, 2018',
#   '2.3.5.1',
#   '4.1 and up'],
#  ['Police Detector (Speed Camera Radar)',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '3574',
#   '3.9M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Auto & Vehicles',
#   'July 4, 2018',
#   '1.6',
#   '4.0 and up'],
#  ['Best Car Wallpapers',
#   'AUTO_AND_VEHICLES',
#   '4.5',
#   '994',
#   '2.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'March 27, 2018',
#   '1.6',
#   '4.1 and up'],
#  ['Tickets + PDA 2018 Exam',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '197136',
#   '38M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 15, 2018',
#   '8.31',
#   '4.1 and up'],
#  ['Pick Your Part Garage',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '142',
#   '32M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 24, 2018',
#   '1.1.5.0',
#   '6.0 and up'],
#  ['PakWheels: Buy & Sell Cars',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '15168',
#   '37M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 27, 2018',
#   '10.0.2',
#   '4.2 and up'],
#  ['Supervision service',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '2155',
#   '15M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   '1.10.3',
#   '5.0 and up'],
#  ['Speed Camera Detector - Traffic & Speed Alert',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '138',
#   '5.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 23, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['Used car search Goo net whole car Go to net',
#   'AUTO_AND_VEHICLES',
#   '3.7',
#   '5414',
#   '18M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 23, 2018',
#   '3.20.1',
#   '4.4 and up'],
#  ['CarMax – Cars for Sale: Search Used Car Inventory',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '21777',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['BEST CAR SOUNDS',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '348',
#   '38M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 29, 2018',
#   '1.0.3',
#   '2.3 and up'],
#  ['RST - Sale of cars on the PCT',
#   'AUTO_AND_VEHICLES',
#   '3.2',
#   '250',
#   '1.1M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'April 27, 2018',
#   '1.4',
#   '4.0.3 and up'],
#  ['AutoScout24 Switzerland – Find your new car',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '13372',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '7880',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 10, 2018',
#   '4.6.5',
#   'Varies with device'],
#  ['SMS Park',
#   'AUTO_AND_VEHICLES',
#   '4.5',
#   '3617',
#   '7.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 16, 2018',
#   '2.8.2',
#   '4.1 and up'],
#  ['SKencar',
#   'AUTO_AND_VEHICLES',
#   '3.7',
#   '4806',
#   '35M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 31, 2018',
#   '4.0.3',
#   '4.0.3 and up'],
#  ['Fuelio: Gas log & costs',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '65786',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   'Varies with device',
#   '4.0.3 and up'],
#  ['auto fines',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '31433',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   '1.40',
#   '4.0.3 and up'],
#  ['Used car is the first car - used car purchase, used car quotation, dealer '
#   'information to',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '5097',
#   '19M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 23, 2018',
#   '1.5.18',
#   '4.0.3 and up'],
#  ['All of the parking lot - National Park application (parking lot search / '
#   'parking sharing / discount payment)',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1754',
#   '14M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 2, 2018',
#   '2.3.4',
#   '4.0 and up'],
#  ['Inquiry Fines and Debits of Vehicles',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '2680',
#   '2.2M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'March 20, 2018',
#   '1.03',
#   '4.0.3 and up'],
#  ['Gas Station',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1288',
#   '4.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'April 21, 2018',
#   '2.17',
#   '4.0 and up'],
#  ['Hush - Beauty for Everyone',
#   'BEAUTY',
#   '4.7',
#   '18900',
#   '17M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'August 2, 2018',
#   '6.10.1',
#   '5.0 and up'],
#  ['ipsy: Makeup, Beauty, and Tips',
#   'BEAUTY',
#   '4.9',
#   '49790',
#   '14M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'November 9, 2017',
#   '2.3.0',
#   '4.1 and up'],
#  ['Natural recipes for your beauty',
#   'BEAUTY',
#   '4.7',
#   '1150',
#   '9.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 15, 2018',
#   '4.0',
#   '4.1 and up'],
#  ['BestCam Selfie-selfie, beauty camera, photo editor',
#   'BEAUTY',
#   '3.9',
#   '1739',
#   '21M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 12, 2018',
#   '1.0.6',
#   '4.0.3 and up'],
#  ['Mirror - Zoom & Exposure -',
#   'BEAUTY',
#   '3.9',
#   '32090',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'October 24, 2016',
#   'Varies with device',
#   'Varies with device'],
#  ['Beauty Selfie Camera',
#   'BEAUTY',
#   '4.2',
#   '2225',
#   '52M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'February 28, 2018',
#   '1.6',
#   '4.1 and up'],
#  ['Hairstyles step by step',
#   'BEAUTY',
#   '4.6',
#   '4369',
#   '14M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 25, 2018',
#   '1.9',
#   '4.0.3 and up'],
#  ['Filters for Selfie',
#   'BEAUTY',
#   '4.3',
#   '8572',
#   '25M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 10, 2018',
#   '1.1.0',
#   '4.0 and up'],
#  ['Tie - Always be happy',
#   'BEAUTY',
#   '4.7',
#   '964',
#   '9.0M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 21, 2018',
#   '4.0',
#   '4.2 and up'],
#  ['Ulta Beauty',
#   'BEAUTY',
#   '4.7',
#   '42050',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 5, 2018',
#   '5.4',
#   '5.0 and up'],
#  ['Prom MakeUp Tutorial',
#   'BEAUTY',
#   '4.8',
#   '104',
#   '12M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 26, 2018',
#   '1.3',
#   '4.0.3 and up'],
#  ['Selfie Camera',
#   'BEAUTY',
#   '4.2',
#   '17934',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'September 12, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Sweet Selfie Beauty Camera',
#   'BEAUTY',
#   '4.3',
#   '601',
#   '35M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 2, 2018',
#   '2.0.0',
#   '4.0 and up'],
#  ['Colors of white in Urdu',
#   'BEAUTY',
#   '4.5',
#   '36',
#   '6.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 26, 2018',
#   '6.0',
#   '4.0 and up'],
#  ['Selfie Camera Photo Editor & Filter & Sticker',
#   'BEAUTY',
#   '4.1',
#   '187',
#   '30M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Beauty',
#   'July 24, 2018',
#   '3.0.1',
#   '4.0.3 and up'],
#  ['Wrinkles and rejuvenation',
#   'BEAUTY',
#   'NaN',
#   '182',
#   '5.7M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Beauty',
#   'September 20, 2017',
#   '8.0',
#   '3.0 and up'],
#  ['Eyes Makeup Beauty Tips',
#   'BEAUTY',
#   '4.2',
#   '30',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'April 9, 2018',
#   '3.3.9',
#   '4.0.3 and up'],
#  ['Photo Editor 2018',
#   'BEAUTY',
#   '4.5',
#   '134',
#   '17M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'March 1, 2018',
#   '1.20',
#   '4.0.3 and up'],
#  ['Step By Step Eyes Makeup Tutorial',
#   'BEAUTY',
#   '4.4',
#   '74',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'April 5, 2018',
#   '2.3.09',
#   '4.0.3 and up'],
#  ['Beauty Camera - Selfie Camera',
#   'BEAUTY',
#   '4.0',
#   '113715',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'August 3, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Girls Hairstyles',
#   'BEAUTY',
#   '4.1',
#   '3595',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 24, 2018',
#   'Varies with device',
#   '4.0 and up'],
#  ['Mirror Camera (Mirror + Selfie Camera)',
#   'BEAUTY',
#   '4.1',
#   '9315',
#   '2.6M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'November 21, 2017',
#   '1.4.2',
#   '4.0 and up'],
#  ['Beauty Tips - Beauty Tips in Sinhala',
#   'BEAUTY',
#   '4.4',
#   '75',
#   '4.2M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'October 18, 2017',
#   '1.0.0',
#   '4.0.3 and up'],
#  ['Haircut Tutorials/Haircut Videos',
#   'BEAUTY',
#   '4.6',
#   '38',
#   '7.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 29, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['Sephora: Skin Care, Beauty Makeup & Fragrance Shop',
#   'BEAUTY',
#   '4.5',
#   '26834',
#   '57M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 24, 2018',
#   '18.5',
#   '5.0 and up'],
#  ['Manicure - nail design',
#   'BEAUTY',
#   'NaN',
#   '119',
#   '3.7M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 23, 2018',
#   '1.3',
#   '4.1 and up'],
#  ['Sticker Camera - Selfie Filters, Beauty Camera',
#   'BEAUTY',
#   '3.9',
#   '2277',
#   '22M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 12, 2018',
#   '1.1.0',
#   '4.0.3 and up'],
#  ['Filters for B Live',
#   'BEAUTY',
#   '4.4',
#   '2280',
#   '24M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 14, 2018',
#   '1.1.0',
#   '4.0 and up'],
#  ['Skin Care and Natural Beauty',
#   'BEAUTY',
#   'NaN',
#   '654',
#   '7.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Beauty',
#   'July 17, 2018',
#   '1.15',
#   '4.1 and up'],
#  ['Facial Wrinkle Reduction',
#   'BEAUTY',
#   '4.6',
#   '184',
#   '21M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 2, 2018',
#   '1.5',
#   '4.1 and up'],
#  ['Makeup Videos',
#   'BEAUTY',
#   '3.8',
#   '9',
#   '3.4M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 7, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['Secrets of beauty, youth and health',
#   'BEAUTY',
#   'NaN',
#   '77',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Beauty',
#   'August 8, 2017',
#   '2.0',
#   '2.3 and up'],
#  ['Recipes and tips for losing weight',
#   'BEAUTY',
#   'NaN',
#   '35',
#   '3.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Beauty',
#   'December 11, 2017',
#   '2.0',
#   '3.0 and up'],
#  ['Discover Color',
#   'BEAUTY',
#   '4.0',
#   '364',
#   '6.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 24, 2018',
#   '1.1',
#   '4.0.3 and up'],
#  ['Eyeliner step by step 2018',
#   'BEAUTY',
#   '4.3',
#   '18',
#   '3.2M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 1, 2018',
#   '1.2.13',
#   '4.0.3 and up'],
#  ['Dresses Ideas & Fashions +3000',
#   'BEAUTY',
#   '4.5',
#   '473',
#   '8.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Beauty',
#   'March 1, 2017',
#   '1.0.2.0',
#   '1.6 and up'],
#  ['Lady adviser (beauty, health)',
#   'BEAUTY',
#   'NaN',
#   '30',
#   '9.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Beauty',
#   'January 24, 2018',
#   '3.0',
#   '3.0 and up'],
#  ['Step By Step Hairstyles For Women',
#   'BEAUTY',
#   '4.1',
#   '66',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'April 5, 2018',
#   '3.1.89',
#   '4.0.3 and up'],
#  ['Rainbow Camera',
#   'BEAUTY',
#   '3.7',
#   '3871',
#   '23M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 30, 2018',
#   '2.2.0',
#   '4.0 and up'],
#  ['Methods of teeth whitening',
#   'BEAUTY',
#   '4.7',
#   '257',
#   '4.6M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'August 7, 2017',
#   '1.0',
#   '4.0.3 and up'],
#  ['Girls hairstyles 2018',
#   'BEAUTY',
#   '4.2',
#   '62',
#   '3.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 28, 2018',
#   '1.9.2',
#   '4.0.3 and up'],
#  ['E-Book Read - Read Book for free',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '1857',
#   '4.9M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 3, 2018',
#   '1.3.2',
#   '4.4 and up'],
#  ['Download free book with green book',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '4478',
#   '9.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Books & Reference',
#   'July 31, 2017',
#   '1.1',
#   '4.0 and up'],
#  ['Wikipedia',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '577550',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Cool Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '246315',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 17, 2015',
#   'Varies with device',
#   '1.5 and up'],
#  ['Free Panda Radio Music',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '418',
#   '4.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'March 27, 2018',
#   '2.1',
#   '4.1 and up'],
#  ['Book store',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '22486',
#   '5.4M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'June 6, 2018',
#   '3.2.1',
#   '4.0 and up'],
#  ['FBReader: Favorite Book Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '203130',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 28, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['English Grammar Complete Handbook',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '1435',
#   '2.8M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'January 21, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['Free Books - Spirit Fanfiction and Stories',
#   'BOOKS_AND_REFERENCE',
#   '4.8',
#   '116507',
#   '5.0M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'August 1, 2018',
#   '2.0.075',
#   '4.0.3 and up'],
#  ['Google Play Books',
#   'BOOKS_AND_REFERENCE',
#   '3.9',
#   '1433233',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['AlReader -any text book reader',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '90468',
#   '5.9M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 27, 2018',
#   '1.911805270',
#   '2.3 and up'],
#  ['Offline English Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.2',
#   '860',
#   '13M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 17, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['Offline: English to Tagalog Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.7',
#   '967',
#   '6.7M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 4, 2018',
#   '1.1.6',
#   '4.0.3 and up'],
#  ['FamilySearch Tree',
#   'BOOKS_AND_REFERENCE',
#   '4.3',
#   '17506',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 20, 2018',
#   '2.3.18',
#   '4.1 and up'],
#  ['Cloud of Books',
#   'BOOKS_AND_REFERENCE',
#   '3.3',
#   '1862',
#   '19M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'April 27, 2018',
#   '2.2.5',
#   '4.1 and up'],
#  ['Recipes of Prophetic Medicine for free',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '2084',
#   '6.7M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 17, 2018',
#   '15.0',
#   '2.3 and up'],
#  ['ReadEra – free ebook reader',
#   'BOOKS_AND_REFERENCE',
#   '4.8',
#   '47303',
#   '21M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 2, 2018',
#   '18.05.31+530',
#   '4.1 and up'],
#  ['Anonymous caller detection',
#   'BOOKS_AND_REFERENCE',
#   'NaN',
#   '161',
#   '2.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 13, 2018',
#   '1.0',
#   '2.3 and up'],
#  ['Ebook Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.1',
#   '85842',
#   '37M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 25, 2018',
#   '5.0.6',
#   '4.0 and up'],
#  ['Litnet - E-books',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '7831',
#   '15M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'July 4, 2018',
#   '1.2.3',
#   '4.0 and up'],
#  ['Read books online',
#   'BOOKS_AND_REFERENCE',
#   '4.1',
#   '91615',
#   '23M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Books & Reference',
#   'June 29, 2018',
#   '3.12',
#   '4.1 and up'],
#  ['English to Urdu Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '4620',
#   '19M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'November 23, 2017',
#   '2.0',
#   '4.0.3 and up'],
#  ['eBoox: book reader fb2 epub zip',
#   'BOOKS_AND_REFERENCE',
#   '4.7',
#   '21336',
#   '23M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 20, 2018',
#   '1.28',
#   '3.0 and up'],
#  ['English Persian Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '26875',
#   '73M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 1, 2018',
#   '6.0.8',
#   '4.0.3 and up'],
#  ['Flybook',
#   'BOOKS_AND_REFERENCE',
#   '3.9',
#   '1778',
#   '4.9M',
#   '500,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Books & Reference',
#   'October 16, 2014',
#   '1.0.3',
#   '2.1 and up'],
#  ['All Maths Formulas',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '2709',
#   '6.8M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 11, 2018',
#   '1.9',
#   '4.4 and up'],
#  ['Ancestry',
#   'BOOKS_AND_REFERENCE',
#   '4.3',
#   '64513',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['HTC Help',
#   'BOOKS_AND_REFERENCE',
#   '4.2',
#   '8342',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 28, 2017',
#   '9.00.950462',
#   '7.0 and up'],
#  ['English translation from Bengali',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '527',
#   '2.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'March 31, 2018',
#   '14.0',
#   '4.0 and up'],
#  ['Pdf Book Download - Read Pdf Book',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '1322',
#   '3.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 28, 2018',
#   '6.0',
#   '4.0.3 and up'],
#  ['Free Book Reader',
#   'BOOKS_AND_REFERENCE',
#   '3.4',
#   '1680',
#   '4.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 20, 2016',
#   '3.05',
#   '4.0.3 and up'],
#  ['eBoox new: Reader for fb2 epub zip books',
#   'BOOKS_AND_REFERENCE',
#   '4.9',
#   '2739',
#   '21M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 17, 2018',
#   '2.0',
#   '3.0 and up'],
#  ['Only 30 days in English, the guideline is guaranteed',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '1065',
#   '2.3M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 16, 2018',
#   '1.5',
#   '3.0 and up'],
#  ['Moon+ Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '233757',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ["SH-02J Owner's Manual (Android 8.0)",
#   'BOOKS_AND_REFERENCE',
#   'NaN',
#   '2',
#   '7.2M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 15, 2018',
#   '3.0',
#   '6.0 and up'],
#  ['English-Myanmar Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '8788',
#   '10M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 28, 2018',
#   '2.5.3',
#   '4.0 and up'],
#  ['Golden Dictionary (EN-AR)',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '51269',
#   '6.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 19, 2018',
#   '7.0.4.6',
#   '4.2 and up'],
#  ['All Language Translator Free',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '30105',
#   '2.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 29, 2018',
#   '1.15',
#   '4.0.3 and up'],
#  ['Azpen eReader',
#   'BOOKS_AND_REFERENCE',
#   '3.5',
#   '156',
#   '42M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'February 15, 2018',
#   '3.1.7.9',
#   '2.2 and up'],
#  ['URBANO V 02 instruction manual',
#   'BOOKS_AND_REFERENCE',
#   'NaN',
#   '114',
#   '7.3M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 7, 2015',
#   '1.1',
#   '5.1 and up'],
#  ['Visual Voicemail by MetroPCS',
#   'BUSINESS',
#   '4.1',
#   '16129',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Indeed Job Search',
#   'BUSINESS',
#   '4.3',
#   '674730',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'May 21, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Uber Driver',
#   'BUSINESS',
#   '4.4',
#   '1254730',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['ADP Mobile Solutions',
#   'BUSINESS',
#   '4.3',
#   '85185',
#   '29M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 17, 2018',
#   '3.4.2',
#   '5.0 and up'],
#  ['Snag - Jobs Hiring Now',
#   'BUSINESS',
#   '4.3',
#   '32584',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'May 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Docs To Go™ Free Office Suite',
#   'BUSINESS',
#   '4.1',
#   '217730',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'April 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Google My Business',
#   'BUSINESS',
#   '4.4',
#   '70991',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 24, 2018',
#   '2.19.0.204537701',
#   '4.4 and up'],
#  ['USPS MOBILE®',
#   'BUSINESS',
#   '3.9',
#   '16589',
#   '9.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 14, 2018',
#   '4.9.10',
#   '4.0.3 and up'],
#  ['Job Search by ZipRecruiter',
#   'BUSINESS',
#   '4.8',
#   '148945',
#   '25M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 19, 2018',
#   '5.2.8',
#   '5.0 and up'],
#  ['Google Primer',
#   'BUSINESS',
#   '4.4',
#   '62272',
#   '18M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 26, 2018',
#   '3.550.2',
#   '4.1 and up'],
#  ['Alba Heaven - Alvarez Job Portal Services',
#   'BUSINESS',
#   '4.0',
#   '8941',
#   '12M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 31, 2018',
#   '4.6.30',
#   '4.0.3 and up'],
#  ['SuperLivePro',
#   'BUSINESS',
#   '4.3',
#   '46353',
#   '21M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'April 13, 2016',
#   '2.8',
#   '1.5 and up'],
#  ['OfficeSuite Pro + PDF (Trial)',
#   'BUSINESS',
#   '4.2',
#   '88073',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 9, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['My Space - Employment Center',
#   'BUSINESS',
#   '4.5',
#   '67000',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 17, 2018',
#   'Varies with device',
#   '4.3 and up'],
#  ['Box',
#   'BUSINESS',
#   '4.2',
#   '159872',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Polaris Office for LG',
#   'BUSINESS',
#   '4.2',
#   '30847',
#   '55M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'February 8, 2018',
#   '7.3.21',
#   '4.1 and up'],
#  ['Jobs in Alabama - Jobs in Alba',
#   'BUSINESS',
#   '4.1',
#   '11622',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 26, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Square Point of Sale - POS',
#   'BUSINESS',
#   '4.6',
#   '95912',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Plugin:AOT v5.0',
#   'BUSINESS',
#   '3.1',
#   '4034',
#   '23k',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'September 11, 2015',
#   '3.0.1.11 (Build 311)',
#   '2.2 and up'],
#  ['Kariyer.net',
#   'BUSINESS',
#   '3.9',
#   '45964',
#   '16M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 18, 2018',
#   '5.1.5',
#   '4.1 and up'],
#  ['SEEK Job Search',
#   'BUSINESS',
#   '4.3',
#   '14955',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Become a Job - Find a job or advertise',
#   'BUSINESS',
#   '4.1',
#   '6903',
#   '14M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 10, 2018',
#   '2.3.6',
#   '4.1 and up'],
#  ['ZOOM Cloud Meetings',
#   'BUSINESS',
#   '4.4',
#   '31614',
#   '37M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 20, 2018',
#   '4.1.28165.0716',
#   '4.0 and up'],
#  ['Easy Installer - Apps On SD',
#   'BUSINESS',
#   '4.1',
#   '23055',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 8, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['IndiaMART: Search Products, Buy, Sell & Trade',
#   'BUSINESS',
#   '4.5',
#   '207372',
#   '11M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   '12.2.4',
#   '4.0 and up'],
#  ['ViettelPost express delivery',
#   'BUSINESS',
#   '4.4',
#   '1225',
#   '25M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 1, 2018',
#   '1.0.6.8',
#   '4.1 and up'],
#  ['MyASUS - Service Center',
#   'BUSINESS',
#   '4.4',
#   '380837',
#   '7.3M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 4, 2018',
#   '3.4.5',
#   '4.2 and up'],
#  ['Job Korea - Career Jobs',
#   'BUSINESS',
#   '4.3',
#   '10600',
#   '6.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 1, 2018',
#   '2.5.6',
#   '4.0 and up'],
#  ['104 Looking for a job - looking for a job, looking for a job, looking for a '
#   'part-time job, health checkup, resume, treatment room',
#   'BUSINESS',
#   '4.4',
#   '74359',
#   '25M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 27, 2018',
#   '1.12.5',
#   '4.0 and up'],
#  ['Myanmar 2D/3D',
#   'BUSINESS',
#   '4.6',
#   '822',
#   '3.1M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 8, 2018',
#   '1.5',
#   '4.0.3 and up'],
#  ['sABN',
#   'BUSINESS',
#   '4.4',
#   '2287',
#   '1.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'March 26, 2018',
#   '4.9',
#   '2.2 and up'],
#  ['ATI Cargoes and Transportation',
#   'BUSINESS',
#   '4.7',
#   '4162',
#   '7.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 24, 2018',
#   '0.9.4',
#   '4.0.3 and up'],
#  ['Secure Folder',
#   'BUSINESS',
#   '3.8',
#   '14760',
#   '8.6M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'January 31, 2018',
#   '1.1.07.6',
#   '7.0 and up'],
#  ['UPS Mobile',
#   'BUSINESS',
#   '3.9',
#   '23243',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Y! Mobile menu',
#   'BUSINESS',
#   'NaN',
#   '9',
#   '1.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'April 9, 2018',
#   '1.0.5',
#   '6.0 and up'],
#  ['SignEasy | Sign and Fill PDF and other Documents',
#   'BUSINESS',
#   '4.3',
#   '8978',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Genius Scan - PDF Scanner',
#   'BUSINESS',
#   '4.4',
#   '42492',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 11, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Tiny Scanner - PDF Scanner App',
#   'BUSINESS',
#   '4.7',
#   '286897',
#   '39M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'May 30, 2017',
#   '1.2.6',
#   '3.0 and up'],
#  ['Fast Scanner : Free PDF Scan',
#   'BUSINESS',
#   '4.5',
#   '103755',
#   '14M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 11, 2018',
#   '3.9.2',
#   '4.1 and up'],
#  ['Mobile Doc Scanner (MDScan) Lite',
#   'BUSINESS',
#   '4.2',
#   '46505',
#   '19M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   '3.4.49',
#   '4.1 and up'],
#  ['TurboScan: scan documents and receipts in PDF',
#   'BUSINESS',
#   '4.7',
#   '11442',
#   '6.8M',
#   '100,000+',
#   'Paid',
#   '$4.99',
#   'Everyone',
#   'Business',
#   'March 25, 2018',
#   '1.5.2',
#   '4.0 and up'],
#  ['Tiny Scanner Pro: PDF Doc Scan',
#   'BUSINESS',
#   '4.8',
#   '10295',
#   '39M',
#   '100,000+',
#   'Paid',
#   '$4.99',
#   'Everyone',
#   'Business',
#   'April 11, 2017',
#   '3.4.6',
#   '3.0 and up'],
#  ['Zenefits',
#   'BUSINESS',
#   '4.2',
#   '296',
#   '14M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 15, 2018',
#   '3.2.1',
#   '4.1 and up'],
#  ['FreshBooks Classic',
#   'BUSINESS',
#   '4.1',
#   '1802',
#   '26M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'April 18, 2018',
#   '1.7.14',
#   '4.2 and up'],
#  ['Insightly CRM',
#   'BUSINESS',
#   '3.8',
#   '1383',
#   '51M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 12, 2018',
#   '3.24.1',
#   '5.0 and up'],
#  ['QuickBooks Accounting: Invoicing & Expenses',
#   'BUSINESS',
#   '4.3',
#   '23175',
#   '41M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 13, 2018',
#   '18.7',
#   '4.1 and up'],
#  ['HipChat - Chat Built for Teams',
#   'BUSINESS',
#   '3.8',
#   '5868',
#   '20M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 3, 2018',
#   '3.19.005',
#   '4.1 and up'],
#  ['Xero Accounting Software',
#   'BUSINESS',
#   '3.5',
#   '2111',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['MailChimp - Email, Marketing Automation',
#   'BUSINESS',
#   '4.1',
#   '5448',
#   '12M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 25, 2018',
#   '4.9.1',
#   '5.0 and up'],
#  ['Crew - Free Messaging and Scheduling',
#   'BUSINESS',
#   '4.6',
#   '4159',
#   '48M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 20, 2018',
#   '6.1.2',
#   '4.0.3 and up'],
#  ['Asana: organize team projects',
#   'BUSINESS',
#   '4.3',
#   '20815',
#   '10M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 26, 2018',
#   '6.4.4',
#   '5.0 and up'],
#  ['Google Analytics',
#   'BUSINESS',
#   '4.5',
#   '78662',
#   '22M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'February 13, 2018',
#   '3.7.5',
#   '4.4 and up'],
#  ['AdWords Express',
#   'BUSINESS',
#   '4.1',
#   '7149',
#   '11M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 31, 2018',
#   '2.6.158',
#   '4.0 and up'],
#  ['Accounting App - Zoho Books',
#   'BUSINESS',
#   '4.5',
#   '3079',
#   '8.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   '5.20.7',
#   '4.1 and up'],
#  ['Invoice & Time Tracking - Zoho',
#   'BUSINESS',
#   '4.6',
#   '5800',
#   '8.6M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   '5.20.7',
#   '4.1 and up'],
#  ['join.me - Simple Meetings',
#   'BUSINESS',
#   '4.0',
#   '6989',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 16, 2018',
#   '4.3.0.508',
#   '4.4 and up'],
#  ['Invoice 2go — Professional Invoices and Estimates',
#   'BUSINESS',
#   '4.2',
#   '16422',
#   '28M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 1, 2018',
#   '10.46.2',
#   '4.1 and up'],
#  ['Cisco Webex Meetings',
#   'BUSINESS',
#   '4.4',
#   '108741',
#   '28M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 20, 2018',
#   '11.1.0',
#   '4.3 and up'],
#  ['ScreenMeet. Easy Phone Meeting',
#   'BUSINESS',
#   '4.0',
#   '624',
#   '9.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'March 22, 2018',
#   '1.2.287',
#   '5.0 and up'],
#  ['Cisco Webex Teams',
#   'BUSINESS',
#   '4.2',
#   '1661',
#   '46M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   '3.0.4651',
#   '4.4 and up'],
#  ['Microsoft Remote Desktop',
#   'BUSINESS',
#   '4.2',
#   '97702',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 11, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Start Meeting',
#   'BUSINESS',
#   '4.1',
#   '308',
#   '14M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'May 29, 2018',
#   '3.1.4.0',
#   '4.0.3 and up'],
#  ['ClickMeeting Webinars',
#   'BUSINESS',
#   '3.8',
#   '5211',
#   '26M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 30, 2018',
#   '3.3.0',
#   '4.0 and up'],
#  ['BlueJeans for Android',
#   'BUSINESS',
#   '3.9',
#   '1058',
#   '23M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 29, 2018',
#   '2.22.397',
#   '5.0 and up'],
#  ['Skype for Business for Android',
#   'BUSINESS',
#   '3.9',
#   '78172',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Quick PDF Scanner + OCR FREE',
#   'BUSINESS',
#   '4.2',
#   '80804',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'February 26, 2018',
#   'Varies with device',
#   '4.0.3 and up'],
#  ['OfficeSuite : Free Office + PDF Editor',
#   'BUSINESS',
#   '4.3',
#   '1002859',
#   '35M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   '9.7.14188',
#   '4.1 and up'],
#  ['Slack',
#   'BUSINESS',
#   '4.4',
#   '51510',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
# ...
#   '3.3M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'November 3, 2017',
#   '1.2.4',
#   '4.2 and up'],
#  ['FP Runner',
#   'GAME',
#   '3.7',
#   '38',
#   '29M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Arcade',
#   'June 29, 2016',
#   '1.12',
#   '3.1 and up'],
#  ['Finger Scanner Gestures',
#   'TOOLS',
#   '4.2',
#   '2531',
#   '3.3M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'July 30, 2017',
#   '1.2.4',
#   '6.0 and up'],
#  ['FP Market',
#   'FAMILY',
#   'NaN',
#   '24',
#   '44k',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Education',
#   'June 17, 2012',
#   '1.0',
#   '1.6 and up'],
#  ['FP FCU',
#   'FINANCE',
#   '3.6',
#   '48',
#   '26M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'April 5, 2018',
#   '4.6.71',
#   '4.0.3 and up'],
#  ['Slickdeals: Coupons & Shopping',
#   'SHOPPING',
#   '4.5',
#   '33599',
#   '12M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Shopping',
#   'July 30, 2018',
#   '3.9',
#   '4.4 and up'],
#  ['SCM FPS Status',
#   'BUSINESS',
#   '4.2',
#   '123',
#   '3.3M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'April 28, 2018',
#   '3.5',
#   '2.3 and up'],
#  ['Hondata Mobile',
#   'MAPS_AND_NAVIGATION',
#   '4.3',
#   '334',
#   '676k',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Maps & Navigation',
#   'August 23, 2016',
#   '1.3',
#   '2.3.3 and up'],
#  ['FreedomPop Friends for Free Data',
#   'TOOLS',
#   '4.4',
#   '58',
#   '2.5M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'July 24, 2018',
#   '2017.07.24',
#   '4.1 and up'],
#  ['Fisher-Price® Smart Connect™',
#   'TOOLS',
#   '2.7',
#   '422',
#   '72M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'February 23, 2018',
#   '2.4.1',
#   '4.4 and up'],
#  ['Fingerprint Lock Screen Prank',
#   'TOOLS',
#   '4.1',
#   '10786',
#   '4.3M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'December 9, 2017',
#   '5.0',
#   '4.0 and up'],
#  ['FP NFC Rewrite',
#   'TOOLS',
#   'NaN',
#   '17',
#   '67k',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'January 29, 2016',
#   '1.1',
#   '4.0 and up'],
#  ['Fast Tract Diet',
#   'HEALTH_AND_FITNESS',
#   '4.4',
#   '35',
#   '2.4M',
#   '1,000+',
#   'Paid',
#   '$7.99',
#   'Everyone',
#   'Health & Fitness',
#   'August 8, 2018',
#   '1.9.3',
#   '4.2 and up'],
#  ['Greek Bible FP (Audio)',
#   'BOOKS_AND_REFERENCE',
#   'NaN',
#   '5',
#   '8.0M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 29, 2016',
#   '1.0.0',
#   '4.0.3 and up'],
#  ['The FP Shield',
#   'NEWS_AND_MAGAZINES',
#   'NaN',
#   '0',
#   '11M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'News & Magazines',
#   'February 1, 2018',
#   '1.1.0',
#   '4.4 and up'],
#  ['FP Разбитый дисплей',
#   'FAMILY',
#   '4.5',
#   '922',
#   '552k',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Entertainment',
#   'September 20, 2014',
#   '1.1',
#   '1.6 and up'],
#  ['FP Transportation',
#   'AUTO_AND_VEHICLES',
#   'NaN',
#   '1',
#   '885k',
#   '1+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'March 9, 2018',
#   '10.0.0',
#   '4.0 and up'],
#  ['Chat For Strangers - Video Chat',
#   'SOCIAL',
#   '3.4',
#   '622',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'May 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['FreedomPop Diagnostics',
#   'TOOLS',
#   '2.9',
#   '452',
#   '7.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'July 17, 2017',
#   '1.03.123.0713',
#   '4.0.3 and up'],
#  ['NFP 2018',
#   'EVENTS',
#   '4.8',
#   '8',
#   '16M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Events',
#   'January 9, 2018',
#   '1.0.3',
#   '4.2 and up'],
#  ['FQ Magazine',
#   'LIFESTYLE',
#   'NaN',
#   '1',
#   '12M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Lifestyle',
#   'December 12, 2016',
#   '1.0',
#   '4.1 and up'],
#  ['Modern Counter Terrorist FPS Shoot',
#   'GAME',
#   '4.0',
#   '795',
#   '41M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Action',
#   'August 29, 2017',
#   '1.2',
#   '2.3 and up'],
#  ['FQ METER',
#   'PRODUCTIVITY',
#   '3.9',
#   '17',
#   '2.4M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Productivity',
#   'April 23, 2017',
#   '1.1',
#   '4.0 and up'],
#  ['FQ Load Board for Transporters',
#   'BUSINESS',
#   'NaN',
#   '0',
#   '3.9M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'February 16, 2018',
#   '1.1.3',
#   '5.0 and up'],
#  ['FQ India',
#   'LIFESTYLE',
#   'NaN',
#   '0',
#   '8.9M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Lifestyle',
#   'July 31, 2018',
#   '7.2.2',
#   '4.1 and up'],
#  ['Miss FQ',
#   'NEWS_AND_MAGAZINES',
#   'NaN',
#   '0',
#   '36M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'News & Magazines',
#   'April 5, 2018',
#   '3.8',
#   '4.4 and up'],
#  ['FQ - Football Quiz',
#   'SPORTS',
#   'NaN',
#   '1',
#   '9.0M',
#   '1+',
#   'Free',
#   '0',
#   'Everyone',
#   'Sports',
#   'May 29, 2018',
#   '1.0',
#   '5.0 and up'],
#  ['Monster Ride Pro',
#   'GAME',
#   '5.0',
#   '1',
#   '24M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Racing',
#   'March 5, 2018',
#   '2.0',
#   '2.3 and up'],
#  ['BEBONCOOL GAMEPAD V1.0',
#   'GAME',
#   '3.9',
#   '404',
#   '2.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Arcade',
#   'August 30, 2017',
#   '1.2',
#   '4.0 and up'],
#  ['Union League',
#   'FAMILY',
#   '4.0',
#   '939',
#   '38M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Role Playing',
#   'June 8, 2018',
#   '1.0.0.96',
#   '4.1 and up'],
#  ['Fortune Quest: Savior',
#   'FAMILY',
#   '3.6',
#   '135',
#   '75M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Role Playing',
#   'June 1, 2018',
#   '1.022',
#   '4.4 and up'],
#  ['Modern Counter 3: FPS Multiplayers battlegro 3',
#   'FAMILY',
#   '4.1',
#   '17',
#   '50M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Strategy',
#   'March 16, 2018',
#   '15',
#   '4.1 and up'],
#  ['Modern Strike Online',
#   'GAME',
#   '4.3',
#   '834117',
#   '44M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Action',
#   'July 30, 2018',
#   '1.25.4',
#   '4.1 and up'],
#  ['Trine 2: Complete Story',
#   'GAME',
#   '3.8',
#   '252',
#   '11M',
#   '10,000+',
#   'Paid',
#   '$16.99',
#   'Teen',
#   'Action',
#   'February 27, 2015',
#   '2.22',
#   '5.0 and up'],
#  ['Modern Counter Terror Attack – Shooting Game',
#   'GAME',
#   '4.2',
#   '340',
#   '72M',
#   '50,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Action',
#   'October 27, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['Big Hunter',
#   'GAME',
#   '4.3',
#   '245455',
#   '84M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Action',
#   'May 31, 2018',
#   '2.8.6',
#   '4.0 and up'],
#  ['sugar, sugar',
#   'FAMILY',
#   '4.2',
#   '1405',
#   '9.5M',
#   '10,000+',
#   'Paid',
#   '$1.20',
#   'Everyone',
#   'Puzzle',
#   'June 5, 2018',
#   '2.7',
#   '2.3 and up'],
#  ['ChopAssistant',
#   'TOOLS',
#   '4.2',
#   '455',
#   '2.8M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'February 28, 2017',
#   '1.6',
#   '6.0 and up'],
#  ['Modern Counter Global Strike 3D',
#   'GAME',
#   '4.1',
#   '297',
#   '48M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Action',
#   'March 28, 2018',
#   '1.2',
#   '4.1 and up'],
#  ['Fountain Live Wallpaper HD – Dubai Wallpaper 3D',
#   'PERSONALIZATION',
#   'NaN',
#   '1',
#   '20M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Personalization',
#   'April 13, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['Modern Counter Global Strike 3D V2',
#   'GAME',
#   '4.0',
#   '368',
#   '48M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Action',
#   'March 28, 2018',
#   '1.7',
#   '4.1 and up'],
#  ['HipChat - beta version',
#   'COMMUNICATION',
#   '4.1',
#   '1035',
#   '20M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 7, 2018',
#   '3.20.001',
#   '4.1 and up'],
#  ['Winter Wonderland',
#   'GAME',
#   '4.0',
#   '1287',
#   '38M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Word',
#   'December 18, 2013',
#   '1.0',
#   '2.2 and up'],
#  ['Soccer Clubs Logo Quiz',
#   'GAME',
#   '4.2',
#   '21661',
#   '16M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Trivia',
#   'May 24, 2018',
#   '1.3.81',
#   '4.0 and up'],
#  ['Sid Story',
#   'GAME',
#   '4.4',
#   '28510',
#   '78M',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Card',
#   'August 1, 2018',
#   '2.6.6',
#   '4.0.3 and up'],
#  ['PopStar',
#   'FAMILY',
#   'NaN',
#   '13',
#   '5.7M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Casual',
#   'January 3, 2018',
#   '1.6',
#   '4.3 and up'],
#  ['Reindeer VPN - Proxy VPN',
#   'TOOLS',
#   '4.2',
#   '7339',
#   '4.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'May 10, 2018',
#   '1.74',
#   '4.1 and up'],
#  ['Inf VPN - Global Proxy & Unlimited Free WIFI VPN',
#   'TOOLS',
#   '4.7',
#   '61445',
#   '7.8M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'July 26, 2018',
#   '1.9.734',
#   '4.1 and up'],
#  ['Fuel Rewards® program',
#   'LIFESTYLE',
#   '4.6',
#   '32433',
#   '46M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Lifestyle',
#   'June 26, 2018',
#   '2.9.1',
#   '5.0 and up'],
#  ['Word Search Tab 1 FR',
#   'FAMILY',
#   'NaN',
#   '0',
#   '1020k',
#   '50+',
#   'Paid',
#   '$1.04',
#   'Everyone',
#   'Puzzle',
#   'February 6, 2012',
#   '1.1',
#   '3.0 and up'],
#  ['Fr Daoud Lamei',
#   'SOCIAL',
#   '4.7',
#   '2036',
#   '6.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 20, 2018',
#   '1.72',
#   '4.0.3 and up'],
#  ['FR Roster',
#   'TOOLS',
#   '4.1',
#   '174',
#   '12M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'July 30, 2018',
#   '6.04',
#   '4.4 and up'],
#  ['Fr Ignacio Outreach',
#   'FAMILY',
#   '4.9',
#   '52',
#   '19M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Education',
#   'January 19, 2018',
#   '1.0',
#   '4.4 and up'],
#  ['FR: My Famous Lover',
#   'FAMILY',
#   '4.0',
#   '185',
#   '28M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Entertainment',
#   'August 6, 2015',
#   '1.3.0',
#   '3.0 and up'],
#  ['Fatal Raid - No.1 Mobile FPS',
#   'GAME',
#   '4.3',
#   '56496',
#   '81M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Action',
#   'August 7, 2018',
#   '1.5.447',
#   '4.0 and up'],
#  ['Poker Pro.Fr',
#   'GAME',
#   '4.2',
#   '5442',
#   '17M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Card',
#   'May 22, 2018',
#   '4.1.3',
#   '2.3 and up'],
#  ['Scoreboard FR',
#   'LIFESTYLE',
#   '4.3',
#   '3',
#   '15M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Lifestyle',
#   'August 7, 2018',
#   '2.1',
#   '4.2 and up'],
#  ['SnakeBite911 FR',
#   'MEDICAL',
#   'NaN',
#   '1',
#   '42M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Medical',
#   'October 9, 2017',
#   '1.2',
#   '4.1 and up'],
#  ['My FR App',
#   'TOOLS',
#   'NaN',
#   '2',
#   '4.2M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'April 9, 2018',
#   '1.283.0037',
#   '2.3.3 and up'],
#  ['lesparticuliers.fr',
#   'LIFESTYLE',
#   'NaN',
#   '96',
#   '1.0M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Lifestyle',
#   'November 25, 2014',
#   '1.5',
#   '2.3 and up'],
#  ['Castle Clash: RPG War and Strategy FR',
#   'FAMILY',
#   '4.7',
#   '376223',
#   '24M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Strategy',
#   'July 18, 2018',
#   '1.4.2',
#   '4.1 and up'],
#  ['Fr Lupupa Sermons',
#   'BUSINESS',
#   '4.8',
#   '19',
#   '21M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 12, 2018',
#   '1.0',
#   '4.4 and up'],
#  ['FR Plus 1.6',
#   'AUTO_AND_VEHICLES',
#   'NaN',
#   '4',
#   '3.9M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 24, 2018',
#   '1.3.6',
#   '4.4W and up'],
#  ['Fr Agnel Pune',
#   'FAMILY',
#   '4.1',
#   '80',
#   '13M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Education',
#   'June 13, 2018',
#   '2.0.20',
#   '4.0.3 and up'],
#  ['DICT.fr Mobile',
#   'BUSINESS',
#   'NaN',
#   '20',
#   '2.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 17, 2018',
#   '2.1.10',
#   '4.1 and up'],
#  ['FR: My Secret Pets! ',
#   'FAMILY',
#   '4.0',
#   '785',
#   '31M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Entertainment',
#   'June 3, 2015',
#   '1.3.1',
#   '3.0 and up'],
#  ['Golden Dictionary (FR-AR)',
#   'BOOKS_AND_REFERENCE',
#   '4.2',
#   '5775',
#   '4.9M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 19, 2018',
#   '7.0.4.6',
#   '4.2 and up'],
#  ['FieldBi FR Offline',
#   'BUSINESS',
#   'NaN',
#   '2',
#   '6.8M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 6, 2018',
#   '2.1.8',
#   '4.1 and up'],
#  ['HTC Sense Input - FR',
#   'TOOLS',
#   '4.0',
#   '885',
#   '8.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Tools',
#   'October 30, 2015',
#   '1.0.612928',
#   '5.0 and up'],
#  ['Gold Quote - Gold.fr',
#   'FINANCE',
#   'NaN',
#   '96',
#   '1.5M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'May 19, 2016',
#   '2.3',
#   '2.2 and up'],
#  ['Fanfic-FR',
#   'BOOKS_AND_REFERENCE',
#   '3.3',
#   '52',
#   '3.6M',
#   '5,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'August 5, 2017',
#   '0.3.4',
#   '4.1 and up'],
#  ['Fr. Daoud Lamei',
#   'FAMILY',
#   '5.0',
#   '22',
#   '8.6M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Education',
#   'June 27, 2018',
#   '3.8.0',
#   '4.1 and up'],
#  ['Poop FR',
#   'FAMILY',
#   'NaN',
#   '6',
#   '2.5M',
#   '50+',
#   'Free',
#   '0',
#   'Everyone',
#   'Entertainment',
#   'May 29, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['PLMGSS FR',
#   'PRODUCTIVITY',
#   'NaN',
#   '0',
#   '3.1M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Productivity',
#   'December 1, 2017',
#   '1',
#   '4.4 and up'],
#  ['List iptv FR',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '1',
#   '2.9M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 22, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['Cardio-FR',
#   'MEDICAL',
#   'NaN',
#   '67',
#   '82M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Medical',
#   'July 31, 2018',
#   '2.2.2',
#   '4.4 and up'],
#  ['Naruto & Boruto FR',
#   'SOCIAL',
#   'NaN',
#   '7',
#   '7.7M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'February 2, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['Frim: get new friends on local chat rooms',
#   'SOCIAL',
#   '4.0',
#   '88486',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'March 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Fr Agnel Ambarnath',
#   'FAMILY',
#   '4.2',
#   '117',
#   '13M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Education',
#   'June 13, 2018',
#   '2.0.20',
#   '4.0.3 and up'],
#  ['Manga-FR - Anime Vostfr',
#   'COMICS',
#   '3.4',
#   '291',
#   '13M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Comics',
#   'May 15, 2017',
#   '2.0.1',
#   '4.0 and up'],
#  ['Bulgarian French Dictionary Fr',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '603',
#   '7.4M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 19, 2016',
#   '2.96',
#   '4.1 and up'],
#  ['News Minecraft.fr',
#   'NEWS_AND_MAGAZINES',
#   '3.8',
#   '881',
#   '2.3M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'News & Magazines',
#   'January 20, 2014',
#   '1.5',
#   '1.6 and up'],
#  ['payermonstationnement.fr',
#   'MAPS_AND_NAVIGATION',
#   'NaN',
#   '38',
#   '9.8M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Maps & Navigation',
#   'June 13, 2018',
#   '2.0.148.0',
#   '4.0 and up'],
#  ['FR Tides',
#   'WEATHER',
#   '3.8',
#   '1195',
#   '582k',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Weather',
#   'February 16, 2014',
#   '6.0',
#   '2.1 and up'],
#  ['Chemin (fr)',
#   'BOOKS_AND_REFERENCE',
#   '4.8',
#   '44',
#   '619k',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'March 23, 2014',
#   '0.8',
#   '2.2 and up'],
#  ['FR Calculator',
#   'FAMILY',
#   '4.0',
#   '7',
#   '2.6M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Education',
#   'June 18, 2017',
#   '1.0.0',
#   '4.1 and up'],
#  ['FR Forms',
#   'BUSINESS',
#   'NaN',
#   '0',
#   '9.6M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'September 29, 2016',
#   '1.1.5',
#   '4.0 and up'],
#  ['Sya9a Maroc - FR',
#   'FAMILY',
#   '4.5',
#   '38',
#   '53M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Education',
#   'July 25, 2017',
#   '1.48',
#   '4.1 and up'],
#  ['Fr. Mike Schmitz Audio Teachings',
#   'FAMILY',
#   '5.0',
#   '4',
#   '3.6M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Education',
#   'July 6, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['Parkinson Exercices FR',
#   'MEDICAL',
#   'NaN',
#   '3',
#   '9.5M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Medical',
#   'January 20, 2017',
#   '1.0',
#   '2.2 and up'],
#  ['The SCP Foundation DB fr nn5n',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '114',
#   'Varies with device',
#   '1,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Books & Reference',
#   'January 19, 2015',
#   'Varies with device',
#   'Varies with device'],
#  ['iHoroscope - 2018 Daily Horoscope & Astrology',
#   'LIFESTYLE',
#   '4.5',
#   '398307',
#   '19M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Lifestyle',
#   'July 25, 2018',
#   'Varies with device',
#   'Varies with device']]

# %%
len(android_clean)
# Out:
# 9659

# %%
len(already_added)
# Out:
# 9659

# %% [markdown]
# At the company, English is used to develop the apps because we cater to an English speaking audience. We therefore have to make sure our dataset contains only English apps.
#
# We can check each character in an app name to see if it is an English character. Using ord(), a built-in Python function, we will check each character to see whether it's ASCII (American Standard Code for Information Interchange system) number is 127 or less. This shows us that the character is English. If the ASCII numbr returned is greater than 127, then that character is non-English.
#
# We will devise a function that will check each string and if any character within that string is a non-English character, then return a boolean value of False that the string is non-English

# %%
len(android_clean[7940][0])
# Out:
# 6

# %%
for char in 'Docs To Go™ Free Office Suite':
    if ord(char) < 127:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
text = 'Instachat 😜'

for char in text:
    if ord(char) > 127:
        print(False)
# Out:
# False

# %%
# change the original function such that if the count of non-English characters, in a string, is 3 or over, then
# return the string as False otherwise return True. This will cater for characters such as emoticons and trademarks
# which are not non-English

def is_english(text):
    count = 0
    for char in text:
        if ord(char) > 127:
            count += 1
    if count >= 3:
        return False
    
    return True

# %%
is_english('angela')
# Out:
# True

# %%
is_english(android_clean[7940][0])
# Out:
# True

# %%
print(is_english(
'爱奇艺PPS -《欢乐颂2》电视剧热播'))
# Out:
# False

# %%
print(is_english('Instagram'))
print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
# Out:
# True
# True
# True

# %%
# extract the number of English apps in both the android and apple datasets

english_apple_app, english_android_app = [], []

for row in apple_data[1:]:
    name = row[1]
    if is_english(name):
        english_apple_app.append(row)

# %%
for row in android_clean:
    name = row[0]
    if is_english(name):
        english_android_app.append(row)

# %%
explore_data(english_apple_app, 0, 5, True)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# Number of rows: 6155
# Number of columns: 16

# %%
explore_data(english_android_app, 0, 5, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# Number of rows: 9597
# Number of columns: 13

# %%
print(header_google), print(header_apple)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
# (None, None)

# %%
free_apps_google, free_apps_apple = [], []

for row in english_apple_app:
    if row[4] == '0.0':
        free_apps_apple.append(row)
        
for row in english_android_app:
    if row[6] == 'Free':
        free_apps_google.append(row)

# %%
# explore the google and apple datasets that should now contain english free apps

explore_data(free_apps_apple, 0, 5, True)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# Number of rows: 3203
# Number of columns: 16

# %%
explore_data(free_apps_google, 0, 5, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# Number of rows: 8847
# Number of columns: 13

# %% [markdown]
# So now there {{len(free_apps_google)}} free apps in the google dataset and {{len(free_apps_apple)}} in the apple dataset respectively

# %% [markdown]
# # What sort of apps could be profitable ?
#
# The goal of this project is to determine the type of apps that would attract more users as our revenue is determined by the numbers of people using our apps.
#
# So far the following has been done to the two datasets:
#
# * Removed inaccurate data
# * Removed duplicate app entries
# * Removed non-English apps
# * Isolated the free apps
#
# The validation strategy that use to understand better our customers and the types of app that would appeal to them are:
#
# * Build a minimal Android version of the app, and add it to the Google Play store
# * If there is a good response to the app, then develop it further
# * If the app is profitable after 6 month, then an iOS version will be built and added to the Apple store
#
# Look through the dataset columns, of both datasets, to see which columns ones indicate the most common genres in each market

# %% [markdown]
# As you can see after inspecting a few rows of the apple dataset, and it's header, the prime_genre column would be a good frequency indicator:
# **{{header_apple}}**

# %% [markdown]
# And from the google dataset, the following columns could be used to indicate frequency, Genres and Category:     **{{header_google}}**
#
# We will generate frequency tables starting with a function, that has dataset and column index as arguments, and returns counts in percentages

# %%
def freq_table(dataset, index):
    freq_table = {}
    name_of_col = []
    length_of_dataset = len(dataset)
    for row in dataset:
        col = row[index]
        name_of_col.append(col)
    
    for col in name_of_col:
        if col in freq_table:
            freq_table[col] += 1/length_of_dataset * 100
        else:
            freq_table[col] = 1/length_of_dataset * 100
    return freq_table


def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)
    table_sorted = sorted(table_display, reverse = True)   
    
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

#prime_genre       
pprint.pprint(display_table(free_apps_apple, -5))  
print('')

#Category
pprint.pprint(display_table(free_apps_google, 1))
print('')

#Genres
pprint.pprint(display_table(free_apps_google, -4))
# Out:
# Games : 58.257883234468544
# Entertainment : 7.836403371838871
# Photo & Video : 4.995316890415236
# Education : 3.684046206681246
# Social Networking : 3.309397439900102
# Shopping : 2.591320636902909
# Utilities : 2.466437714642528
# Sports : 2.1542304089915745
# Music : 2.0605682172962885
# Health & Fitness : 2.029347486731193
# Productivity : 1.7483609116453351
# Lifestyle : 1.5610365282547631
# News : 1.3424914142990958
# Travel : 1.2488292226038098
# Finance : 1.0927255697783331
# Weather : 0.8741804558226663
# Food & Drink : 0.8117389946924759
# Reference : 0.5307524196066189
# Business : 0.5307524196066189
# Book : 0.37464876678114273
# Navigation : 0.18732438339057136
# Medical : 0.18732438339057136
# Catalogs : 0.1248829222603809
# None
#
# FAMILY : 19.249463094833935
# GAME : 9.483440714366473
# TOOLS : 8.454843449757053
# BUSINESS : 4.589126257488416
# PRODUCTIVITY : 3.899626992200732
# LIFESTYLE : 3.888323725556672
# FINANCE : 3.7074714592517117
# MEDICAL : 3.5492257262348716
# SPORTS : 3.4135865265061516
# PERSONALIZATION : 3.3231603933536715
# COMMUNICATION : 3.2440375268452515
# HEALTH_AND_FITNESS : 3.0744885271843514
# PHOTOGRAPHY : 2.9501525940996913
# NEWS_AND_MAGAZINES : 2.8032101277269112
# SOCIAL : 2.667570927998191
# TRAVEL_AND_LOCAL : 2.339776195320451
# SHOPPING : 2.249350062167971
# BOOKS_AND_REFERENCE : 2.136317395727371
# DATING : 1.8650389962699283
# VIDEO_PLAYERS : 1.7859161297615067
# MAPS_AND_NAVIGATION : 1.3903017972193987
# FOOD_AND_DRINK : 1.2433593308466158
# EDUCATION : 1.1303266644060135
# LIBRARIES_AND_DEMO : 0.9381711314569903
# AUTO_AND_VEHICLES : 0.9268678648129302
# ENTERTAINMENT : 0.8816547982366897
# HOUSE_AND_HOME : 0.8025319317282689
# WEATHER : 0.7912286650842087
# EVENTS : 0.7121057985757879
# PARENTING : 0.6555894653554873
# ART_AND_DESIGN : 0.6442861987114272
# COMICS : 0.6103763987792469
# BEAUTY : 0.5990731321351868
# None
#
# Tools : 8.443540183112994
# Entertainment : 6.081157454504395
# Education : 5.357748389284526
# Business : 4.589126257488416
# Productivity : 3.899626992200732
# Lifestyle : 3.877020458912612
# Finance : 3.7074714592517117
# Medical : 3.5492257262348716
# Sports : 3.4587995930823916
# Personalization : 3.3231603933536715
# Communication : 3.2440375268452515
# Action : 3.0970950604724714
# Health & Fitness : 3.0744885271843514
# Photography : 2.9501525940996913
# News & Magazines : 2.8032101277269112
# Social : 2.667570927998191
# Travel & Local : 2.328472928676391
# Shopping : 2.249350062167971
# Books & Reference : 2.136317395727371
# Simulation : 2.045891262574891
# Dating : 1.8650389962699283
# Arcade : 1.853735729625868
# Video Players & Editors : 1.7859161297615067
# Casual : 1.752006329829326
# Maps & Navigation : 1.3903017972193987
# Food & Drink : 1.2433593308466158
# Puzzle : 1.1303266644060135
# Racing : 0.9946874646772909
# Role Playing : 0.9381711314569903
# Libraries & Demo : 0.9381711314569903
# Auto & Vehicles : 0.9268678648129302
# Strategy : 0.9042613315248099
# House & Home : 0.8025319317282689
# Weather : 0.7912286650842087
# Events : 0.7121057985757879
# Adventure : 0.6668927319995475
# Comics : 0.5990731321351868
# Beauty : 0.5990731321351868
# Art & Design : 0.5990731321351868
# Parenting : 0.49734373233864565
# Card : 0.44082739911834506
# Trivia : 0.41822086583022483
# Casino : 0.41822086583022483
# Educational;Education : 0.3956143325421046
# Board : 0.3843110658980445
# Educational : 0.37300779925398436
# Education;Education : 0.339097999321804
# Word : 0.2599751328133832
# Casual;Pretend Play : 0.2373685995252629
# Music : 0.20345879959308247
# Racing;Action & Adventure : 0.16954899966090203
# Puzzle;Brain Games : 0.16954899966090203
# Entertainment;Music & Video : 0.16954899966090203
# Casual;Brain Games : 0.1356391997287216
# Casual;Action & Adventure : 0.1356391997287216
# Arcade;Action & Adventure : 0.12433593308466145
# Action;Action & Adventure : 0.10172939979654119
# Educational;Pretend Play : 0.09042613315248106
# Simulation;Action & Adventure : 0.07912286650842093
# Parenting;Education : 0.07912286650842093
# Entertainment;Brain Games : 0.07912286650842093
# Board;Brain Games : 0.07912286650842093
# Parenting;Music & Video : 0.0678195998643608
# Educational;Brain Games : 0.0678195998643608
# Casual;Creativity : 0.0678195998643608
# Art & Design;Creativity : 0.0678195998643608
# Education;Pretend Play : 0.05651633322030067
# Role Playing;Pretend Play : 0.04521306657624054
# Education;Creativity : 0.04521306657624054
# Role Playing;Action & Adventure : 0.03390979993218041
# Puzzle;Action & Adventure : 0.03390979993218041
# Entertainment;Creativity : 0.03390979993218041
# Entertainment;Action & Adventure : 0.03390979993218041
# Educational;Creativity : 0.03390979993218041
# Educational;Action & Adventure : 0.03390979993218041
# Education;Music & Video : 0.03390979993218041
# Education;Brain Games : 0.03390979993218041
# Education;Action & Adventure : 0.03390979993218041
# Adventure;Action & Adventure : 0.03390979993218041
# Video Players & Editors;Music & Video : 0.02260653328812027
# Sports;Action & Adventure : 0.02260653328812027
# Simulation;Pretend Play : 0.02260653328812027
# Puzzle;Creativity : 0.02260653328812027
# Music;Music & Video : 0.02260653328812027
# Entertainment;Pretend Play : 0.02260653328812027
# Casual;Education : 0.02260653328812027
# Board;Action & Adventure : 0.02260653328812027
# Trivia;Education : 0.011303266644060134
# Travel & Local;Action & Adventure : 0.011303266644060134
# Tools;Education : 0.011303266644060134
# Strategy;Education : 0.011303266644060134
# Strategy;Creativity : 0.011303266644060134
# Strategy;Action & Adventure : 0.011303266644060134
# Simulation;Education : 0.011303266644060134
# Role Playing;Brain Games : 0.011303266644060134
# Racing;Pretend Play : 0.011303266644060134
# Puzzle;Education : 0.011303266644060134
# Parenting;Brain Games : 0.011303266644060134
# Music & Audio;Music & Video : 0.011303266644060134
# Lifestyle;Pretend Play : 0.011303266644060134
# Lifestyle;Education : 0.011303266644060134
# Health & Fitness;Education : 0.011303266644060134
# Health & Fitness;Action & Adventure : 0.011303266644060134
# Entertainment;Education : 0.011303266644060134
# Communication;Creativity : 0.011303266644060134
# Comics;Creativity : 0.011303266644060134
# Casual;Music & Video : 0.011303266644060134
# Card;Brain Games : 0.011303266644060134
# Card;Action & Adventure : 0.011303266644060134
# Books & Reference;Education : 0.011303266644060134
# Art & Design;Pretend Play : 0.011303266644060134
# Art & Design;Action & Adventure : 0.011303266644060134
# Arcade;Pretend Play : 0.011303266644060134
# Adventure;Education : 0.011303266644060134
# None

# %% [markdown]
# In answer to the following question for the prime_genre column of the Apple dataset:
#
# ** What is the most common genre ? ** Games
# ** What is the runner-up ? ** Entertainment
#
# The most popular genre by far is the Games category (58%) while the second most popular is Entertainmeny
